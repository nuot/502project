# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
from pyspark import SparkContext

spark = SparkSession.builder \
    .appName("project")\
    .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.11:2.4.4")\
    .config("spark.sql.broadcastTimeout", "36000")\
    .getOrCreate()

sc = spark.sparkContext
sc
# Out:
# <SparkContext master=yarn appName=project>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-31-69-205.ec2.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from sparknlp.base import Finisher, DocumentAssembler
from sparknlp.annotator import (Tokenizer, Normalizer, 
                                LemmatizerModel, StopWordsCleaner)
from pyspark.ml import Pipeline

# %%
import nltk
nltk.download('stopwords')
nltk.download('words')

from nltk.corpus import stopwords

eng_stopwords = stopwords.words('english')
eng_stopwords.append('xxxx')
# Out:
# [nltk_data] Downloading package stopwords to /home/hadoop/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /home/hadoop/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
documentAssembler = DocumentAssembler() \
    .setInputCol('context1') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

# note normalizer defaults to changing all words to lowercase.
# Use .setLowercase(False) to maintain input case.
normalizer = Normalizer() \
    .setInputCols(['token']) \
    .setOutputCol('normalized') \
    .setLowercase(True)

# note that lemmatizer needs a dictionary. So I used the pre-trained
# model (note that it defaults to english)
lemmatizer = LemmatizerModel.pretrained() \
    .setInputCols(['normalized']) \
    .setOutputCol('lemma') \

stopwords_cleaner = StopWordsCleaner() \
    .setInputCols(['lemma']) \
    .setOutputCol('clean_lemma') \
    .setCaseSensitive(False) \
    .setStopWords(eng_stopwords)

# finisher converts tokens to human-readable output
finisher = Finisher() \
    .setInputCols(['clean_lemma']) \
    .setCleanAnnotations(False)
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]

# %%
pipeline = Pipeline() \
    .setStages([
        documentAssembler,
        tokenizer,
        normalizer,
        lemmatizer,
        stopwords_cleaner,
        finisher
    ])

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

schema = StructType([
    StructField("article_type", StringType(), True),
    StructField("np1", StringType(), True),
    StructField("np2", StringType(), True),
    StructField("context", StringType(), True),
    StructField("source", StringType(), True),
    StructField("category", StringType(), True),
    StructField("location", StringType(), True),
    StructField("time", StringType(), True),])

# %%
df = spark.read.csv("s3://anly502project/data/part-r-00000",sep = "\t",header=False,schema=schema)
df_2 = spark.read.csv("s3://anly502project/data/part-r-00001",sep = "\t",header=False,schema=schema)

# %%
#### Data Schema
df.printSchema()
df_2.printSchema()
# Out:
# root
#  |-- article_type: string (nullable = true)
#  |-- np1: string (nullable = true)
#  |-- np2: string (nullable = true)
#  |-- context: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- time: string (nullable = true)
#
# root
#  |-- article_type: string (nullable = true)
#  |-- np1: string (nullable = true)
#  |-- np2: string (nullable = true)
#  |-- context: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- time: string (nullable = true)

# %%
import functools 

def unionAll(dfs):
    return functools.reduce(lambda df1,df2: df1.union(df2.select(df1.columns)), dfs)

# %%
unioned_df = unionAll([df, df_2])

# %%
#### show combined
unioned_df.show(10)
# Out:
# +------------+---------------+---+--------------------+-------------+--------------------+--------------------+-----+
# |article_type|            np1|np2|             context|       source|            category|            location| time|
# +------------+---------------+---+--------------------+-------------+--------------------+--------------------+-----+
# |     article|    Dark Knight|  E|  arg1 and Wall arg2|             |intlnews topstor ...|      , kerala india|14299|
# |     article|    Carotenoids|  E|arg1 and caroteno...|             |topstor,health,sc...|                   ,|14660|
# |     article|    Communities|  E|arg1 mobilised in...|             |    politics topstor|                   ,|14026|
# |     article|    Carotenoids|  E|arg1 and caroteno...|             |topstor,health,sc...|                   ,|14660|
# |            |     Coast bias|  E|arg2 is for East ...|             |      sports topstor| columbus, ohio u...|13956|
# |     article|Commerce office|  E|arg1 at DDD Linco...|             |topstor,lifestle,...| canton, ohio uni...|14363|
# |     article| 75-minute mark|  E|arg1 in a pulsati...|Yahoo! Sports|      topstor,sports|                   ,|14779|
# |     article| Brigham Circle|  E|      arg2 past arg1|             |             topstor| boston, massachu...|14434|
# |            | Brigham Circle|  E| arg2 trains at arg1|             |localnews headlin...| boston, massachu...|13862|
# |     article| Brigham Circle|  E|arg2 line service...|             |             topstor| boston, massachu...|14344|
# +------------+---------------+---+--------------------+-------------+--------------------+--------------------+-----+
# only showing top 10 rows

# %%
from pyspark.sql.functions import split
split_col = split(unioned_df['category'], ',')
unioned_df = unioned_df.withColumn('category', split_col.getItem(0))

# %%
split_col_2 = split(unioned_df['category'], ' ')
unioned_df = unioned_df.withColumn('category', split_col_2.getItem(0))

# %%
split_col_3 = split(unioned_df['category'], '_')
unioned_df = unioned_df.withColumn('category', split_col_3.getItem(0))

# %%
split_col_4 = split(unioned_df['category'], '-')
unioned_df = unioned_df.withColumn('category', split_col_4.getItem(0))

# %%
#### Show data frame after filtering the category
unioned_df.show(10)
# Out:
# +------------+---------------+---+--------------------+-------------+---------+--------------------+-----+
# |article_type|            np1|np2|             context|       source| category|            location| time|
# +------------+---------------+---+--------------------+-------------+---------+--------------------+-----+
# |     article|    Dark Knight|  E|  arg1 and Wall arg2|             | intlnews|      , kerala india|14299|
# |     article|    Carotenoids|  E|arg1 and caroteno...|             |  topstor|                   ,|14660|
# |     article|    Communities|  E|arg1 mobilised in...|             | politics|                   ,|14026|
# |     article|    Carotenoids|  E|arg1 and caroteno...|             |  topstor|                   ,|14660|
# |            |     Coast bias|  E|arg2 is for East ...|             |   sports| columbus, ohio u...|13956|
# |     article|Commerce office|  E|arg1 at DDD Linco...|             |  topstor| canton, ohio uni...|14363|
# |     article| 75-minute mark|  E|arg1 in a pulsati...|Yahoo! Sports|  topstor|                   ,|14779|
# |     article| Brigham Circle|  E|      arg2 past arg1|             |  topstor| boston, massachu...|14434|
# |            | Brigham Circle|  E| arg2 trains at arg1|             |localnews| boston, massachu...|13862|
# |     article| Brigham Circle|  E|arg2 line service...|             |  topstor| boston, massachu...|14344|
# +------------+---------------+---+--------------------+-------------+---------+--------------------+-----+
# only showing top 10 rows

# %%
from pyspark.sql.functions import concat, col, lit

unioned_df1 = unioned_df.select(concat(col("np1"), lit(' '),col("context")).alias('context1'))
unioned_df1.show()
# Out:
# +--------------------+
# |            context1|
# +--------------------+
# |Dark Knight arg1 ...|
# |Carotenoids arg1 ...|
# |Communities arg1 ...|
# |Carotenoids arg1 ...|
# |Coast bias arg2 i...|
# |Commerce office a...|
# |75-minute mark ar...|
# |Brigham Circle ar...|
# |Brigham Circle ar...|
# |Brigham Circle ar...|
# |Drill Sergeant ar...|
# |Brigham Circle ar...|
# |Brigham Circle ar...|
# |Brigham Circle ar...|
# |Brigham Circle ar...|
# |Cold arg2 Cape co...|
# |Cook arg1 Off is ...|
# |Boob arg1 How my ...|
# |2002 arg2 Street ...|
# |Boob arg1 How my ...|
# +--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import monotonically_increasing_id

df1 = unioned_df.withColumn("id", monotonically_increasing_id())

df2 = unioned_df1.withColumn("id", monotonically_increasing_id())


df3 = df2.join(df1, "id", "outer").drop("id")

df3.show()
# Out:
# +--------------------+------------+------------------+---+--------------------+--------------------+---------+--------------------+-----+
# |            context1|article_type|               np1|np2|             context|              source| category|            location| time|
# +--------------------+------------+------------------+---+--------------------+--------------------+---------+--------------------+-----+
# |Dane arg1 gain In...|     article|              Dane|  E|arg1 gain In Grou...|                    | intlnews|                   ,|14223|
# |Dubai arg2 arlier...|            |             Dubai|  E|arg2 arlier in th...|                    |localnews| nampa, idaho uni...|13892|
# |Coffee arg1 Tycoo...|            |            Coffee|  E|arg1 Tycoon is ra...|     Blogcritics.org|  topstor|                  , |13765|
# |10 years arg2 for...|     article|          10 years|  E|arg2 for Everyone...|TheCelebrityCafe.com|  topstor|    ,  united states|14669|
# |100-acre parcel a...|     article|   100-acre parcel|  E|arg1 in planning ...|Douglas County Ne...|  topstor| castle rock, col...|14577|
# |100-acre parcel a...|     article|   100-acre parcel|  E|arg1 in planning ...|Douglas County Ne...|  topstor| castle rock, col...|14576|
# |BMW arg1 plans to...|     article|               BMW|  E|arg1 plans to lea...|                    |localnews| detroit, michiga...|14263|
# |50 arg1 years tha...|     article|                50|  E|arg1 years that e...|                    |   health|                   ,|14183|
# |Charlie arg2 news...|     article|           Charlie|  E| arg2 news said arg1|                    |localnews|      ,  philippines|14035|
# |Bhengu arg2 Mabam...|     article|            Bhengu|  E|arg2 Mabambo and ...|                    |  topstor|          cape town,|14566|
# |Bernardino arg2 s...|     article|        Bernardino|  E|arg2 streets in S...|The Press-Enterprise|localnews| riverside, calif...|14023|
# |Bugs arg1 is rate...|     article|              Bugs|  E|  arg1 is rated arg2|   dBusinessNews.com|  topstor|                   ,|14427|
# |2 arg2 Concourse ...|     article|                 2|  E|arg2 Concourse of...|                    |  topstor| st. louis, misso...|14736|
# |April arg1 DD in ...|            |             April|  E| arg1 DD in Lot arg2|                    |localnews|forsyth north car...|13625|
# |AFC Asian Cup 201...|       photo|AFC Asian Cup 2011|  E|arg1 Final qualif...|         Yahoo! News|  topstor|                   ,|14272|
# |800 block arg1 of...|            |         800 block|  E| arg1 of Avenue arg2|                    |localnews|   billings, montana|13724|
# |31 years arg1 on ...|    cronkite|          31 years|  E| arg1 on Avenue arg2|The Press-Enterprise|   cirgc2| riverside, calif...|14489|
# |2-1 win arg1 over...|     article|           2-1 win|  E|arg1 over Cameroo...|                    |  topstor| san jose, califo...|14780|
# |Alias 2 arg2 Ink ...|     article|           Alias 2|  E|arg2 Ink deftness...|                    |  topstor|                   ,|14411|
# |2010 World arg1 C...|       photo|        2010 World|  E| arg1 Cup group arg2|         Yahoo! News|  topstor|                   ,|14779|
# +--------------------+------------+------------------+---+--------------------+--------------------+---------+--------------------+-----+
# only showing top 20 rows

# %%
#### Filter out the null and empty category 
df3 =df3.filter(df3.category.isNotNull())
df3 = df3.filter(df3.category != '')

# %%
import pyspark.sql as sql
count_df = df3.groupBy("category").count()
count_df.createOrReplaceTempView("count_df")
count_rank_df = spark.sql("SELECT category, count FROM count_df ORDER BY count DESC LIMIT 15")

# %%
count_rank_df.show(10)
# Out:
# +-------------+--------+
# |     category|   count|
# +-------------+--------+
# |      topstor|85027590|
# |    localnews|40174779|
# |       sports|22925153|
# |     business|20017107|
# | nationalnews| 5073191|
# |     intlnews| 4252106|
# |    technolog| 2546612|
# |entertainment| 2359067|
# |     politics| 2092784|
# |     lifestle| 1785076|
# +-------------+--------+
# only showing top 10 rows

# %%
df3.createOrReplaceTempView("unioned_df")
count_rank_df.createOrReplaceTempView("count_rank_df")
df_final = spark.sql("SELECT * FROM unioned_df WHERE unioned_df.category IN (SELECT category FROM count_rank_df)")

# %%
df_final.show(10)

# %%
categories = [
 'politics',
'science',
'health',
'technolog',
'entertainment']

# %%
from pyspark.sql.functions import explode, col

# initialize {company: {word counts}} dictionary
category_word_counts_dict = {category: {} for category in categories}

for category in categories:
    print(category)
    # get complaint narratives
    category_df = df_final.filter(df_final['category'] == category)
    data = category_df.select('context')
    
    # process narratives into counts dictionary
    clean_data = pipeline.fit(data).transform(data)
    clean_data_exploded = clean_data.withColumn("exploded_text", explode(col("finished_clean_lemma")))
    counts = clean_data_exploded.groupby('exploded_text').count().toPandas()
    counts_dict = {counts.loc[i, 'exploded_text']: counts.loc[i, 'count'] for i in range(counts.shape[0])}
    
    # add counts to dictionary
    category_word_counts_dict[category] = counts_dict
# Out:
# politics
# science
# health
# technolog
# entertainment

# %%
category_word_counts_dict
# Out:
# {'politics': {'pitcher': 48,
#   'lawlor': 4,
#   'still': 3295,
#   'lieutenant': 68,
#   'reintegration': 11,
#   'nunez': 8,
#   'requirement': 533,
#   'thwart': 249,
#   'embrace': 777,
#   'travel': 1723,
#   'hope': 3179,
#   'input': 40,
#   'priority': 372,
#   'fiscally': 17,
#   'recognize': 927,
#   'medicare': 246,
#   'cramp': 16,
#   'inner': 53,
#   'roundabout': 3,
#   'online': 509,
#   'everyday': 70,
#   'barrier': 94,
#   'trail': 480,
#   'earl': 10,
#   'electrical': 191,
#   'atef': 3,
#   'art': 232,
#   'precautionary': 8,
#   'interaction': 41,
#   'hanna': 16,
#   'tarnish': 49,
#   'ransom': 47,
#   'vladimir': 118,
#   'sariev': 1,
#   'carnegie': 24,
#   'marxism': 2,
#   'elevate': 56,
#   'nyayo': 2,
#   'randomly': 144,
#   'spoil': 80,
#   'poach': 22,
#   'implore': 104,
#   'dts': 3,
#   'nauseate': 1,
#   'indigenous': 80,
#   'timetable': 227,
#   'peerage': 11,
#   'abruptness': 1,
#   'disassemble': 7,
#   'transaction': 82,
#   'indicator': 32,
#   'crest': 10,
#   'confidentiality': 50,
#   'persist': 79,
#   'degrade': 21,
#   'likelihood': 26,
#   'shipyard': 7,
#   'bushs': 2,
#   'gloria': 27,
#   'kaeomeechai': 3,
#   'jewelry': 7,
#   'poppy': 38,
#   'accumulation': 6,
#   'backdate': 10,
#   'kathmandu': 5,
#   'rejuvenate': 11,
#   'fog': 11,
#   'cautious': 159,
#   'ramrod': 1,
#   'outfit': 20,
#   'heeler': 6,
#   'clog': 21,
#   'wto': 34,
#   'voyage': 4,
#   'jettison': 11,
#   'oscar': 8,
#   'patton': 12,
#   'lacrosse': 33,
#   'fritter': 12,
#   'najis': 2,
#   'traditionalist': 15,
#   'occidental': 2,
#   'unequivocal': 14,
#   'vilmain': 2,
#   'honcho': 1,
#   'flagman': 2,
#   'viewpoint': 7,
#   'distil': 3,
#   'recommit': 43,
#   'scajola': 3,
#   'irreligious': 1,
#   'mannar': 6,
#   'marrow': 51,
#   'villarosa': 1,
#   'librarian': 1,
#   'navamin': 1,
#   'teknologi': 2,
#   'fuchs': 11,
#   'cosponsor': 16,
#   'carbonate': 4,
#   'meiners': 2,
#   'homeports': 2,
#   'cowell': 2,
#   'transparty': 1,
#   'schene': 1,
#   'usms': 1,
#   'iffy': 4,
#   'elsa': 2,
#   'hud': 52,
#   'driscoll': 4,
#   'vortex': 6,
#   'suozzi': 10,
#   'inflammatory': 3,
#   'creativity': 23,
#   'babin': 1,
#   'strawberry': 10,
#   'palins': 1,
#   'coulibaly': 1,
#   'terwilliger': 3,
#   'poetry': 6,
#   'liban': 1,
#   'itt': 5,
#   'cropland': 2,
#   'hse': 4,
#   'mendelsohn': 3,
#   'hobbs': 2,
#   'febrile': 1,
#   'blossom': 8,
#   'reassertion': 4,
#   'ligament': 10,
#   'countermeasure': 1,
#   'mooney': 2,
#   'destitute': 1,
#   'photovoltaic': 1,
#   'desecration': 6,
#   'ryanairs': 1,
#   'photocoagulation': 1,
#   'hygienist': 2,
#   'rwampara': 1,
#   'pushback': 1,
#   'bifurcate': 1,
#   'nourish': 1,
#   'premeditated': 10,
#   'shroud': 8,
#   'pringle': 2,
#   'bilney': 1,
#   'deftly': 3,
#   'militarized': 1,
#   'kae': 1,
#   'banditry': 2,
#   'machinist': 2,
#   'resister': 3,
#   'carlo': 1,
#   'forgetful': 1,
#   'diringer': 1,
#   'monte': 3,
#   'insipid': 2,
#   'imitation': 1,
#   'feign': 5,
#   'firesale': 1,
#   'synchronise': 2,
#   'amplifier': 4,
#   'antennae': 2,
#   'pant': 1,
#   'stupefaction': 1,
#   'nahr': 1,
#   'nicotine': 1,
#   'yurt': 4,
#   'didgeridoo': 2,
#   'veingrad': 2,
#   'newlywed': 1,
#   'cinches': 2,
#   'plaats': 4,
#   'bazaar': 2,
#   'giglio': 1,
#   'ppb': 1,
#   'lomaia': 2,
#   'rha': 6,
#   'miron': 1,
#   'include': 8093,
#   'oemig': 1,
#   'staff': 2088,
#   'launch': 2096,
#   'television': 568,
#   'operation': 1401,
#   'photograph': 69,
#   'often': 1145,
#   'conversation': 182,
#   'detain': 201,
#   'positive': 264,
#   'calderon': 34,
#   'import': 655,
#   'distributor': 18,
#   'slightly': 266,
#   'veiga': 1,
#   'spyware': 7,
#   'automaker': 194,
#   'goodman': 6,
#   'texarkana': 6,
#   'jurisdiction': 43,
#   'column': 115,
#   'productive': 46,
#   'bone': 55,
#   'lucy': 10,
#   'indictment': 34,
#   'drain': 85,
#   'brilliantly': 2,
#   'enhancement': 18,
#   'absurd': 11,
#   'outgoing': 206,
#   'naidenko': 2,
#   'qaeda': 252,
#   'turkic': 6,
#   'mulet': 1,
#   'chadian': 13,
#   'aig': 124,
#   'guar': 1,
#   'sceptical': 29,
#   'valerie': 71,
#   'motorist': 30,
#   'sopposedly': 1,
#   'vocal': 99,
#   'liaise': 15,
#   'hurry': 56,
#   'kiwi': 5,
#   'hipp': 4,
#   'expertise': 71,
#   'otc': 19,
#   'auction': 76,
#   'partially': 67,
#   'predominant': 8,
#   'thawi': 1,
#   'faud': 4,
#   'fraternal': 5,
#   'dushanbe': 7,
#   'wrongdoing': 92,
#   'dimiss': 2,
#   'unmanned': 26,
#   'consulate': 9,
#   'chaudhry': 37,
#   'finland': 1,
#   'retailer': 56,
#   'fraternity': 64,
#   'kafar': 1,
#   'henin': 2,
#   'chestnut': 3,
#   'rosato': 9,
#   'unwise': 3,
#   'nationalised': 7,
#   'speedway': 18,
#   'ard': 16,
#   'speedy': 22,
#   'thanit': 2,
#   'anupong': 1,
#   'wrestle': 51,
#   'rebirth': 10,
#   'boen': 2,
#   'irretrievable': 2,
#   'bota': 1,
#   'fungicide': 1,
#   'dromey': 1,
#   'tavaglione': 1,
#   'massacr': 12,
#   'fresnel': 1,
#   'scorn': 18,
#   'krueger': 1,
#   'cesspool': 2,
#   'col': 1,
#   'gadget': 9,
#   'bugg': 1,
#   'rupiah': 1,
#   'cabrera': 1,
#   'cobain': 1,
#   'endoscopic': 6,
#   'hurndall': 2,
#   'parton': 3,
#   'quarreled': 12,
#   'plausibly': 7,
#   'sigma': 20,
#   'dodie': 2,
#   'narcissistic': 2,
#   'hardy': 2,
#   'regularity': 2,
#   'tanweer': 2,
#   'heang': 2,
#   'lawyerly': 3,
#   'herschel': 6,
#   'beverage': 17,
#   'irwin': 7,
#   'morrell': 16,
#   'manipulative': 4,
#   'characterization': 3,
#   'prestwick': 2,
#   'ihdiv': 1,
#   'tosh': 25,
#   'tabriz': 1,
#   'ldv': 1,
#   'interferon': 1,
#   'orse': 3,
#   'thyroid': 3,
#   'stent': 2,
#   'roadbuilder': 1,
#   'dermatics': 2,
#   'lakota': 3,
#   'couto': 1,
#   'mbdca': 1,
#   'macho': 3,
#   'pasteurised': 2,
#   'wilfred': 4,
#   'ursula': 4,
#   'kamp': 2,
#   'mingkwan': 2,
#   'vespa': 1,
#   'tse': 3,
#   'tester': 3,
#   'grumet': 2,
#   'assad': 11,
#   'pyote': 1,
#   'rhythmic': 6,
#   'nyra': 2,
#   'conspicuous': 1,
#   'heelers': 1,
#   'craigslist': 2,
#   'hilslborough': 1,
#   'harrod': 1,
#   'sequel': 2,
#   'lumad': 1,
#   'bandow': 1,
#   'ascendant': 1,
#   'kousseri': 1,
#   'grisham': 6,
#   'druzhba': 5,
#   'labeed': 2,
#   'badaruddin': 1,
#   'scsr': 1,
#   'crust': 2,
#   'cuttings': 1,
#   'anoka': 9,
#   'senkser': 1,
#   'brownshirt': 1,
#   'calvin': 2,
#   'alliant': 2,
#   'bushner': 1,
#   'oper': 1,
#   'lisamarie': 3,
#   'agrarian': 1,
#   'nondisclosure': 1,
#   'nuvamsa': 1,
#   'ghulam': 4,
#   'neurosurgery': 22,
#   'mafia': 1,
#   'safiah': 1,
#   'wali': 1,
#   'undeterred': 1,
#   'explain': 695,
#   'cable': 148,
#   'senatorial': 49,
#   'johann': 7,
#   'watch': 1550,
#   'australia': 76,
#   'sail': 128,
#   'enmesh': 9,
#   'ferrioli': 1,
#   'disaster': 272,
#   'modernization': 62,
#   'postpone': 184,
#   'growth': 530,
#   'walden': 3,
#   'frustrate': 315,
#   'saliva': 6,
#   'achieve': 957,
#   'harry': 385,
#   'coin': 54,
#   'yokozuna': 1,
#   'equal': 278,
#   'chalk': 12,
#   'rockies': 3,
#   'greenland': 11,
#   'disarray': 22,
#   'vinegar': 3,
#   'clover': 2,
#   'lords': 118,
#   'hockey': 106,
#   'map': 161,
#   'gargantuan': 2,
#   'doctrine': 24,
#   'markey': 4,
#   'cook': 74,
#   'limb': 10,
#   'agonizingly': 2,
#   'intercept': 138,
#   'hemmes': 1,
#   'premiere': 11,
#   'plane': 156,
#   'cia': 337,
#   'evaluation': 26,
#   'fletcher': 28,
#   'decay': 6,
#   'paddy': 7,
#   'folder': 9,
#   'bloc': 298,
#   'greece': 16,
#   'dmv': 13,
#   'powerpoint': 6,
#   'militancy': 18,
#   'haunt': 60,
#   'incited': 23,
#   'kadyrov': 5,
#   'hutu': 4,
#   'sundance': 4,
#   'afterwards': 6,
#   'cotroceni': 12,
#   'stronghold': 125,
#   'muscular': 18,
#   'hub': 39,
#   'stabilisation': 9,
#   'underprivileged': 5,
#   'infusion': 16,
#   'kilmarnock': 1,
#   'najaf': 7,
#   'kagame': 5,
#   'mora': 12,
#   'oblivious': 5,
#   'weightman': 2,
#   'lex': 6,
#   'yamana': 2,
#   'westfield': 21,
#   'hometown': 38,
#   'emancipation': 3,
#   'futile': 11,
#   'dispersal': 10,
#   'disprove': 158,
#   'murky': 8,
#   'flaherty': 22,
#   'enrapture': 5,
#   'policymaking': 2,
#   'cofounded': 5,
#   'breezy': 2,
#   'disunited': 3,
#   'covertly': 4,
#   'rankings': 7,
#   'drip': 4,
#   'pensacola': 3,
#   'taskhiri': 2,
#   'jima': 1,
#   'musculoskeletal': 1,
#   'airlock': 3,
#   'itv': 6,
#   'apuzzo': 11,
#   'ottumwa': 1,
#   'chemistry': 12,
#   'brett': 4,
#   'refrigerator': 21,
#   'der': 11,
#   'misbehavior': 11,
#   'mckissick': 1,
#   'fax': 10,
#   'stockholm': 6,
#   'gere': 3,
#   'ilya': 1,
#   'phanomyong': 1,
#   'schoolgirl': 7,
#   'dickerson': 6,
#   'marat': 2,
#   'masimov': 1,
#   'mcgaha': 3,
#   'demeaning': 1,
#   'adulteration': 1,
#   'dung': 62,
#   'dorset': 9,
#   'parmjit': 2,
#   'wrightsville': 4,
#   'plong': 1,
#   'dws': 2,
#   'coker': 1,
#   'karami': 6,
#   'dehydrate': 1,
#   'hadnott': 1,
#   'vgb': 1,
#   'sepah': 2,
#   'iftikhar': 12,
#   'iosiper': 1,
#   'pulido': 5,
#   'mame': 3,
#   'candice': 1,
#   'lujan': 1,
#   'newton': 3,
#   'wearer': 2,
#   'antispyware': 2,
#   'lough': 1,
#   'skedaddle': 1,
#   'galactic': 1,
#   'dekorte': 4,
#   'ruggiero': 1,
#   'viper': 1,
#   'adnoddau': 1,
#   'krendler': 1,
#   'sian': 8,
#   'unjustifiably': 1,
#   'windsurfing': 2,
#   'ct': 4,
#   'crites': 2,
#   'uml': 1,
#   'institutionally': 1,
#   'eponymous': 1,
#   'mughal': 1,
#   'spats': 1,
#   'julian': 9,
#   'papa': 1,
#   'farm': 2224,
#   'mirroring': 16,
#   'eligibility': 247,
#   'suicide': 754,
#   'prevent': 2532,
#   'opposition': 2442,
#   'stringent': 70,
#   'slow': 1224,
#   'turf': 30,
#   'intact': 45,
#   'valley': 893,
#   'film': 154,
#   'coral': 14,
#   'catapult': 27,
#   'incur': 120,
#   'undetected': 9,
#   'lifeboat': 2,
#   'accusation': 189,
#   'terra': 11,
#   'extension': 144,
#   'uncirculated': 1,
#   'arar': 1,
#   'harrisburg': 13,
#   'en': 90,
#   'bench': 53,
#   'typically': 371,
#   'wolfe': 3,
#   'gillard': 44,
#   'ronnie': 19,
#   'oakland': 13,
#   'shiite': 418,
#   'divulge': 17,
#   'portugal': 9,
#   'shut': 304,
#   'abrahams': 25,
#   'pao': 7,
#   'pipeline': 81,
#   'exhort': 28,
#   'rhode': 179,
#   'perspective': 23,
#   'gasoline': 93,
#   'settlement': 256,
#   'collare': 2,
#   'yearn': 6,
#   'juicy': 23,
#   'borneo': 4,
#   'character': 89,
#   'boulevard': 33,
#   'det': 1,
#   'roadside': 154,
#   'incompatible': 5,
#   'obsolete': 46,
#   'botnets': 2,
#   'mideast': 81,
#   'ira': 39,
#   'overthrow': 83,
#   'bangul': 2,
#   'jamaat': 4,
#   'globally': 12,
#   'covert': 43,
#   'gerry': 42,
#   'foregoing': 15,
#   'romantic': 11,
#   'chemotherapy': 2,
#   'infrastructional': 1,
#   'offload': 11,
#   'surf': 7,
#   'constabulary': 6,
#   'christianna': 4,
#   'servant': 37,
#   'unidos': 1,
#   'boomer': 42,
#   'demystify': 2,
#   'overprice': 2,
#   'impatiently': 20,
#   'goode': 7,
#   'staunchly': 35,
#   'anti': 2,
#   'cardboard': 86,
#   'vasily': 2,
#   'ascend': 12,
#   'midway': 18,
#   'cosatu': 1,
#   'nat': 1,
#   'wolper': 1,
#   'kendall': 13,
#   'fairford': 1,
#   'providence': 9,
#   'cotonou': 2,
#   'meteorology': 2,
#   'psa': 2,
#   'doi': 3,
#   'happ': 2,
#   'jar': 16,
#   'dive': 16,
#   'vaporize': 1,
#   'hercules': 2,
#   'evangelic': 2,
#   'biography': 44,
#   'wagner': 2,
#   'permissive': 2,
#   'stomach': 9,
#   'inglis': 1,
#   'blumstein': 1,
#   'zacharia': 1,
#   'disclaimer': 1,
#   'gymnastics': 1,
#   'communistic': 1,
#   'polonium': 5,
#   'grassic': 3,
#   'darrin': 2,
#   'filippone': 1,
#   'machang': 5,
#   'amnon': 1,
#   'asher': 4,
#   'murtaza': 1,
#   'toles': 1,
#   'worldnetdaily': 1,
#   'intricate': 5,
#   'babe': 11,
#   'bachelet': 1,
#   'comal': 1,
#   'petrochemical': 1,
#   'desrosiers': 1,
#   'dpa': 1,
#   'scurrilous': 1,
#   'comerford': 7,
#   'posthumous': 4,
#   'salima': 1,
#   'tiananmen': 5,
#   'parlayed': 6,
#   'teck': 2,
#   'extravaganza': 1,
#   'deuba': 1,
#   'cimpaye': 1,
#   'stove': 1,
#   'provocatively': 1,
#   'brownwood': 4,
#   'coonan': 4,
#   'envious': 2,
#   'barnert': 1,
#   'kerger': 3,
#   'sucre': 5,
#   'fallin': 2,
#   'breidling': 2,
#   'ardrossan': 2,
#   'zigzag': 1,
#   'cleburne': 2,
#   'hometrack': 1,
#   'bikalpa': 1,
#   'coasties': 2,
#   'garros': 11,
#   'alqaeda': 1,
#   'slatemaking': 1,
#   'sidique': 1,
#   'conte': 1,
#   'teamster': 1,
#   'pyle': 2,
#   'port': 349,
#   'grow': 2121,
#   'van': 121,
#   'debate': 2200,
#   'wall': 874,
#   'leave': 6793,
#   'resurrect': 144,
#   'revise': 418,
#   'ready': 912,
#   'lard': 19,
#   'boost': 1266,
#   'traffic': 328,
#   'expression': 23,
#   'israel': 736,
#   'ukraine': 80,
#   'dewan': 5,
#   'elliott': 17,
#   'trauma': 34,
#   'thick': 29,
#   'salmonella': 29,
#   'donald': 92,
#   'frazer': 7,
#   'holmes': 13,
#   'lockheed': 53,
#   'oversee': 602,
#   'adjutant': 21,
#   'abramoff': 111,
#   'cpi': 3,
#   'liquidity': 42,
#   'evil': 18,
#   'periodic': 15,
#   'atcs': 3,
#   'forge': 471,
#   'outing': 29,
#   'reliant': 21,
#   'diplomat': 157,
#   'dozen': 337,
#   'academy': 139,
#   'familiarity': 8,
#   'favorable': 265,
#   'disparaging': 22,
#   'trairong': 3,
#   'humanize': 2,
#   'diggs': 1,
#   'robertson': 34,
#   'dowling': 1,
#   'motorcycle': 68,
#   'wink': 8,
#   'brad': 83,
#   'lafourche': 5,
#   'symantec': 2,
#   'dnepr': 4,
#   'institutionalize': 12,
#   'battery': 47,
#   'patriarch': 15,
#   'vanessa': 4,
#   'heap': 7,
#   'crepe': 4,
#   'issuer': 4,
#   'bogazici': 1,
#   'imbalance': 28,
#   'snowmobile': 6,
#   'hurtle': 4,
#   'odienne': 2,
#   'remedy': 33,
#   'orthodoxy': 44,
#   'macaskill': 9,
#   'rebroadcast': 2,
#   'killer': 11,
#   'laf': 7,
#   'fastforward': 1155,
#   'natan': 1,
#   'csiro': 2,
#   'elective': 34,
#   'laureate': 26,
#   'miscegenation': 1,
#   'manipulation': 33,
#   'robotic': 18,
#   'kristol': 1,
#   'bernalillo': 11,
#   'extraordinarily': 6,
#   'archaeologist': 4,
#   'kaen': 2,
#   'luyang': 1,
#   'pi': 5,
#   'mason': 19,
#   'bluebird': 2,
#   'definitional': 1,
#   'stumpf': 2,
#   'marius': 1,
#   'videoconference': 2,
#   'nobl': 4,
#   'taipei': 12,
#   'consciously': 7,
#   'roller': 29,
#   'okaloosa': 5,
#   'narathiwat': 2,
#   'clunk': 7,
#   'detrick': 2,
#   'exemplar': 4,
#   'par': 11,
#   'charbagh': 1,
#   'mew': 2,
#   'kean': 6,
#   'swathing': 1,
#   'scary': 19,
#   'strkingly': 2,
#   'meg': 15,
#   'skinhead': 14,
#   'manhanga': 1,
#   'nowitzki': 6,
#   'schramski': 1,
#   'che': 7,
#   'utmost': 6,
#   'anongwan': 1,
#   'wolverine': 3,
#   'thirsty': 2,
#   'bertelsen': 1,
#   'logistic': 1,
#   'jeffco': 1,
#   'sprenger': 2,
#   'wrko': 1,
#   'sickler': 1,
#   'duynhoven': 3,
#   'ciotto': 1,
#   'mak': 2,
#   'brattleboro': 2,
#   'salihov': 1,
#   'pds': 2,
#   'wnaegele': 2,
#   'chamlong': 1,
#   'powerled': 2,
#   'augustinian': 1,
#   'elucidate': 2,
#   'chiuariu': 2,
#   'talibani': 1,
#   'spiszer': 1,
#   'sharqiyah': 2,
#   'saftoiu': 3,
#   'solomons': 1,
#   'faraday': 1,
#   'kenwright': 1,
#   'csr': 1,
#   'radel': 2,
#   'eitan': 1,
#   'rios': 3,
#   'ing': 1,
#   'grandiose': 1,
#   'bridgestreet': 1,
#   'leslye': 1,
#   'iba': 3,
#   'invariable': 1,
#   'nez': 1,
#   'octopus': 1,
#   'chock': 10,
#   'thom': 4,
#   'lithium': 2,
#   'obligatory': 1,
#   'torbay': 2,
#   'lvf': 1,
#   'knorr': 1,
#   'cicek': 1,
#   'bluejean': 2,
#   'scheck': 4,
#   'session': 457,
#   'among': 21127,
#   'day': 3993,
#   'intend': 679,
#   'joint': 513,
#   'dilemma': 69,
#   'renewable': 242,
#   'insistent': 9,
#   'jared': 11,
#   'hollins': 1,
#   'subject': 661,
#   'steer': 429,
#   'immunity': 72,
#   'hbos': 25,
#   'render': 64,
#   'neurological': 14,
#   'battlefield': 99,
#   'basically': 92,
#   'sense': 313,
#   'footballer': 8,
#   'soybean': 2,
#   'evac': 2,
#   'duffy': 6,
#   'drift': 127,
#   'nigeria': 27,
#   'nova': 13,
#   'preoccupied': 26,
#   'yucca': 44,
#   'umno': 151,
#   'hence': 26,
#   'graduate': 317,
#   'churchgoer': 1,
#   'rica': 66,
#   'concord': 20,
#   'quest': 35,
#   'documentation': 15,
#   'pause': 31,
#   'frankly': 14,
#   'lesbian': 7,
#   'accost': 18,
#   'havana': 10,
#   'bruton': 5,
#   'duddy': 39,
#   'argentine': 6,
#   'draconian': 12,
#   'thread': 2,
#   'panicky': 2,
#   'sermon': 16,
#   'infraction': 3,
#   'femas': 2,
#   'plouffe': 39,
#   'bme': 13,
#   'calobrisi': 4,
#   'wayne': 80,
#   'napoleons': 8,
#   'andreas': 1,
#   'spartan': 5,
#   'kabila': 35,
#   'intelligent': 24,
#   'rucker': 1,
#   'coastline': 5,
#   'pramoj': 2,
#   'rowdy': 7,
#   'surreal': 2,
#   'fundraise': 1,
#   'incentivise': 5,
#   'silverliner': 2,
#   'harmony': 9,
#   'chieftain': 2,
#   'levitt': 2,
#   'rupert': 8,
#   'uae': 9,
#   'vera': 4,
#   'fanatical': 5,
#   'servicers': 2,
#   'monticello': 6,
#   'ganter': 3,
#   'dade': 3,
#   'fragment': 17,
#   'californian': 19,
#   'khost': 10,
#   'heiligenstein': 1,
#   'cumber': 1,
#   'bancroft': 1,
#   'beshir': 2,
#   'espaillat': 2,
#   'outstrip': 16,
#   'clandestine': 7,
#   'unto': 3,
#   'dag': 2,
#   'loven': 11,
#   'newhouse': 31,
#   'charcoal': 2,
#   'forklift': 2,
#   'stanly': 1,
#   'chancellery': 1,
#   'pinellas': 19,
#   'santos': 18,
#   'piss': 2,
#   'annalise': 2,
#   'ember': 2,
#   'wapakoneta': 1,
#   'intelligentsia': 1,
#   'longitude': 1,
#   'coo': 2,
#   'gillani': 2,
#   'rotor': 2,
#   'mornington': 1,
#   'backlots': 2,
#   'tiyani': 2,
#   'moya': 1,
#   'dominick': 3,
#   'apra': 4,
#   'flynt': 7,
#   'falcon': 19,
#   'springboard': 2,
#   'cosponsoring': 6,
#   'spalding': 1,
#   'gottwalt': 6,
#   'ausley': 1,
#   'camouflage': 2,
#   'savagely': 1,
#   'adjuster': 30,
#   'schaer': 1,
#   'ination': 2,
#   'suk': 3,
#   'estrogen': 1,
#   'investi': 1,
#   'accompaniment': 1,
#   'cobalt': 1,
#   'briskly': 4,
#   'mathare': 1,
#   'internalise': 1,
#   'assasinate': 1,
#   'quie': 2,
#   'imo': 4,
#   'donnelly': 6,
#   'nazir': 1,
#   'nasonex': 2,
#   'schiller': 1,
#   'barea': 2,
#   'mcshane': 1,
#   'reregistering': 6,
#   'tempestuous': 1,
#   'wittingly': 1,
#   'adversiting': 6,
#   'trillo': 2,
#   'anzac': 3,
#   'emmons': 7,
#   'cc': 104,
#   'paochinda': 1,
#   'trask': 1,
#   'riverdance': 1,
#   'ignatia': 1,
#   'unar': 1,
#   'companhia': 1,
#   'wycombe': 1,
#   'zuckerman': 2,
#   'henry': 207,
#   'even': 3025,
#   'dem': 305,
#   'provocative': 23,
#   'naked': 16,
#   'ministry': 529,
#   'kevin': 168,
#   'circumvent': 92,
#   'briefly': 129,
#   'statewide': 535,
#   'fisa': 84,
#   ...},
#  'science': {'cautious': 11,
#   'hope': 574,
#   'electrical': 262,
#   'recognize': 226,
#   'implore': 2,
#   'requirement': 94,
#   'still': 662,
#   'ligament': 32,
#   'poach': 31,
#   'persist': 29,
#   'lacrosse': 2,
#   'countermeasure': 7,
#   'degrade': 17,
#   'cramp': 10,
#   'online': 497,
#   'spoil': 15,
#   'barrier': 107,
#   'art': 61,
#   'trail': 94,
#   'interaction': 131,
#   'vortex': 4,
#   'travel': 364,
#   'voyage': 3,
#   'marrow': 254,
#   'heinrich': 2,
#   'monte': 4,
#   'outfit': 27,
#   'methadone': 4,
#   'priority': 66,
#   'randomly': 32,
#   'strawberry': 15,
#   'indicator': 25,
#   'photovoltaic': 11,
#   'everyday': 51,
#   'staph': 4,
#   'cropland': 2,
#   'poppy': 3,
#   'transaction': 13,
#   'elevate': 73,
#   'input': 43,
#   'creativity': 10,
#   'embrace': 71,
#   'hydrate': 12,
#   'inflammatory': 65,
#   'accumulation': 29,
#   'inner': 68,
#   'iffy': 1,
#   'ransom': 8,
#   'inimical': 1,
#   'likelihood': 29,
#   'carnegie': 13,
#   'synchronise': 3,
#   'medicare': 29,
#   'clog': 10,
#   'fog': 8,
#   'reddish': 9,
#   'carbonate': 11,
#   'fossett': 1,
#   'intermountain': 2,
#   'jewelry': 3,
#   'reforestation': 11,
#   'confidentiality': 12,
#   'thwart': 27,
#   'consistenly': 1,
#   'amplifier': 7,
#   'photodetector': 1,
#   'earl': 3,
#   'mooney': 1,
#   'convergent': 3,
#   'shipyard': 3,
#   'patton': 3,
#   'shroud': 9,
#   'timetable': 2,
#   'nicotine': 26,
#   'indigenous': 25,
#   'backdate': 1,
#   'fiscally': 2,
#   'cosponsor': 1,
#   'fraim': 1,
#   'schaeffer': 4,
#   'nourish': 10,
#   'hanna': 5,
#   'pitcher': 18,
#   'platini': 15,
#   'shevchenko': 2,
#   'tarnish': 3,
#   'unequivocal': 4,
#   'carlo': 7,
#   'hse': 2,
#   'precautionary': 15,
#   'militarized': 1,
#   'vladimir': 13,
#   'dragao': 2,
#   'ppb': 1,
#   'lovelock': 1,
#   'leukocyte': 4,
#   'misogynist': 1,
#   'socialization': 1,
#   'hud': 1,
#   'petrie': 1,
#   'suzhou': 17,
#   'jettison': 5,
#   'zaporizhstal': 2,
#   'terwilliger': 1,
#   'jamb': 2,
#   'bolden': 2,
#   'bazaar': 1,
#   'guts': 1,
#   'feign': 1,
#   'gurion': 1,
#   'digester': 1,
#   'setae': 2,
#   'oscar': 1,
#   'newron': 1,
#   'argentino': 2,
#   'newlywed': 2,
#   'deleterious': 7,
#   'rejuvenate': 5,
#   'rakaia': 3,
#   'crest': 5,
#   'superintendency': 6,
#   'rudkovsky': 8,
#   'lieutenant': 3,
#   'librarian': 1,
#   'gaurav': 1,
#   'velutina': 3,
#   'pant': 4,
#   'antennae': 4,
#   'elsa': 1,
#   'parazynski': 1,
#   'epigenomics': 1,
#   'acidity': 2,
#   'ruben': 3,
#   'marxism': 1,
#   'recommit': 2,
#   'operation': 412,
#   'include': 3172,
#   'launch': 1167,
#   'brilliantly': 1,
#   'bone': 706,
#   'staff': 188,
#   'excitation': 17,
#   'slightly': 111,
#   'often': 534,
#   'drain': 107,
#   'positive': 121,
#   'automaker': 13,
#   'elisa': 11,
#   'predominant': 10,
#   'vocal': 57,
#   'import': 187,
#   'photograph': 80,
#   'stent': 34,
#   'crust': 13,
#   'drizzle': 6,
#   'speedy': 4,
#   'television': 83,
#   'expertise': 47,
#   'partially': 49,
#   'beverage': 5,
#   'vibrate': 39,
#   'outgoing': 4,
#   'hurry': 2,
#   'auction': 48,
#   'liaise': 3,
#   'distributor': 25,
#   'tivo': 2,
#   'airflow': 7,
#   'gadget': 9,
#   'enhancement': 18,
#   'tester': 2,
#   'romanoov': 1,
#   'retailer': 36,
#   'monesi': 2,
#   'irwin': 5,
#   'characterization': 10,
#   'motorist': 22,
#   'grisham': 6,
#   'rhythmic': 8,
#   'conspicuous': 1,
#   'unmanned': 12,
#   'chaudhry': 4,
#   'huygens': 3,
#   'transmute': 1,
#   'otc': 2,
#   'rapa': 1,
#   'kiwi': 3,
#   'speedway': 1,
#   'qaeda': 6,
#   'hardy': 2,
#   'richness': 3,
#   'chantry': 2,
#   'ghulam': 2,
#   'detain': 9,
#   'productive': 15,
#   'conversation': 26,
#   'pharmacology': 7,
#   'column': 7,
#   'plasticity': 2,
#   'rey': 7,
#   'alliant': 5,
#   'schweitzer': 35,
#   'herschel': 3,
#   'nausea': 10,
#   'indictment': 2,
#   'thyroid': 1,
#   'finland': 8,
#   'rupiah': 9,
#   'wrestle': 9,
#   'liquidiser': 1,
#   'darius': 1,
#   'piton': 1,
#   'malt': 2,
#   'superhawk': 2,
#   'cardiology': 6,
#   'rosset': 8,
#   'endoscopic': 12,
#   'infective': 6,
#   'fraternal': 4,
#   'jurisdiction': 3,
#   'bajii': 2,
#   'vespa': 3,
#   'chadian': 1,
#   'humanistic': 1,
#   'neurosurgery': 3,
#   'flammable': 1,
#   'fraternity': 7,
#   'finkbeiner': 2,
#   'goodman': 1,
#   'prestwick': 1,
#   'gimelbrant': 1,
#   'ktpa': 2,
#   'chestnut': 2,
#   'chickadee': 4,
#   'deaconess': 21,
#   'tyramine': 4,
#   'sandusky': 12,
#   'steese': 4,
#   'consulate': 1,
#   'lazio': 1,
#   'cabrera': 2,
#   'duffin': 2,
#   'remijan': 5,
#   'valerie': 1,
#   'assad': 1,
#   'lamination': 1,
#   'conflate': 2,
#   'mafia': 2,
#   'sceptical': 1,
#   'styrene': 1,
#   'interferon': 2,
#   'imager': 1,
#   'hedegaard': 2,
#   'oddly': 1,
#   'col': 2,
#   'map': 253,
#   'cable': 57,
#   'disaster': 74,
#   'watch': 251,
#   'cook': 74,
#   'limb': 38,
#   'achieve': 405,
#   'greenland': 102,
#   'explain': 296,
#   'greece': 11,
#   'growth': 390,
#   'ilya': 2,
#   'equal': 77,
#   'chemistry': 66,
#   'australia': 108,
#   'galactic': 76,
#   'haunt': 7,
#   'postpone': 28,
#   'sail': 48,
#   'refrigerator': 8,
#   'drip': 11,
#   'paddy': 6,
#   'rankings': 6,
#   'powerpoint': 1,
#   'sundance': 2,
#   'intercept': 19,
#   'plane': 86,
#   'dispersal': 22,
#   'decay': 37,
#   'rf': 8,
#   'premiere': 2,
#   'evaluation': 54,
#   'frustrate': 22,
#   'qwerk': 2,
#   'harry': 13,
#   'hub': 27,
#   'keyboard': 7,
#   'saline': 7,
#   'diverticula': 1,
#   'laterally': 1,
#   'riverbed': 1,
#   'ectoderm': 2,
#   'modernization': 7,
#   'muscular': 20,
#   'stronghold': 2,
#   'vinegar': 18,
#   'geral': 2,
#   'ernst': 1,
#   'clover': 6,
#   'wrightsville': 1,
#   'amp': 5,
#   'najaf': 1,
#   'fax': 5,
#   'ct': 14,
#   'musculoskeletal': 11,
#   'hoplon': 1,
#   'androgen': 12,
#   'tcd': 2,
#   'angiogenic': 1,
#   'gertraud': 2,
#   'hcfcs': 5,
#   'delmarva': 2,
#   'stockholm': 4,
#   'forhan': 6,
#   'futile': 2,
#   'retriever': 4,
#   'breezy': 6,
#   'airlock': 13,
#   'verheugen': 15,
#   'fletcher': 2,
#   'ove': 1,
#   'bhainsala': 1,
#   'infusion': 13,
#   'pensacola': 2,
#   'gall': 4,
#   'alison': 4,
#   'markey': 1,
#   'dung': 2,
#   'newton': 10,
#   'cia': 7,
#   'storrie': 1,
#   'goldfish': 2,
#   'murky': 1,
#   'coin': 15,
#   'everlasting': 1,
#   'ouder': 1,
#   'drugstore': 3,
#   'worldview': 1,
#   'dausa': 1,
#   'posen': 2,
#   'der': 9,
#   'walden': 6,
#   'pyunik': 1,
#   'weightman': 2,
#   'dores': 2,
#   'pollacco': 2,
#   'westfield': 3,
#   'purepower': 1,
#   'militancy': 1,
#   'viper': 1,
#   'buettner': 1,
#   'gargantuan': 7,
#   'phallic': 1,
#   'dehydrate': 2,
#   'chalk': 1,
#   'cisse': 1,
#   'adulteration': 1,
#   'underprivileged': 1,
#   'dorset': 4,
#   'hemmes': 2,
#   'hockey': 4,
#   'rockies': 2,
#   'candice': 1,
#   'sciencedude': 2,
#   'impressively': 1,
#   'supercold': 2,
#   'gizmodo': 1,
#   'doctrine': 4,
#   'stabilisation': 1,
#   'ift': 1,
#   'fratello': 1,
#   'qt': 1,
#   'lords': 4,
#   'ey': 1,
#   'bursage': 1,
#   'wearer': 3,
#   'despinic': 1,
#   'bloc': 3,
#   'dickson': 1,
#   'neem': 2,
#   'augustin': 1,
#   'pentinin': 3,
#   'enmesh': 1,
#   'gere': 2,
#   'disprove': 11,
#   'ingroup': 1,
#   'jima': 1,
#   'hometown': 2,
#   'covertly': 1,
#   'resection': 4,
#   'butterfield': 1,
#   'farm': 433,
#   'settlement': 80,
#   'film': 111,
#   'opposition': 116,
#   'typically': 151,
#   'prevent': 1282,
#   'slow': 410,
#   'coral': 146,
#   'stomach': 19,
#   'jar': 9,
#   'en': 13,
#   'dive': 47,
#   'lubricate': 12,
#   'servant': 5,
#   'valley': 190,
#   'incur': 55,
#   'chemotherapy': 30,
#   'undetected': 23,
#   'character': 11,
#   'suicide': 54,
#   'biography': 9,
#   'rhode': 43,
#   'extension': 70,
#   'gasoline': 79,
#   'intact': 17,
#   'macintosh': 16,
#   'ilm': 1,
#   'hipath': 1,
#   'shut': 90,
#   'shiite': 6,
#   'perspective': 26,
#   'cardboard': 8,
#   'antidepressant': 16,
#   'boomer': 4,
#   'anti': 3,
#   'pipeline': 34,
#   'borneo': 24,
#   'renovator': 1,
#   'terra': 12,
#   'wolfe': 5,
#   'boulevard': 19,
#   'stringent': 24,
#   'isbell': 1,
#   'papa': 1,
#   'turf': 7,
#   'ira': 63,
#   'catapult': 5,
#   'cahors': 1,
#   'globally': 25,
#   'roadside': 21,
#   'kamper': 2,
#   'doi': 1,
#   'posthumous': 3,
#   'surf': 19,
#   'portugal': 28,
#   'doosan': 1,
#   'petrochemical': 14,
#   'tupi': 1,
#   'neoplasm': 1,
#   'intricate': 12,
#   'eligibility': 10,
#   'wagner': 17,
#   'overthrow': 5,
#   'exhort': 4,
#   'juicy': 3,
#   'ronnie': 1,
#   'ascend': 5,
#   'srba': 4,
#   'irizar': 1,
#   'kendall': 11,
#   'accusation': 5,
#   'tysabri': 1,
#   'pygmy': 6,
#   'midway': 3,
#   'incompatible': 6,
#   'oakland': 3,
#   'babe': 2,
#   'garros': 7,
#   'covert': 5,
#   'interstellar': 7,
#   'nextsat': 4,
#   'anorexia': 6,
#   'reorganizes': 1,
#   'bench': 3,
#   'manninger': 1,
#   'hercules': 1,
#   'seafront': 6,
#   'uncirculated': 2,
#   'pao': 33,
#   'misremember': 4,
#   'divulge': 6,
#   'microdisplay': 3,
#   'blubber': 1,
#   'cuidado': 2,
#   'pocketdemo': 2,
#   'biomimetic': 3,
#   'mahboobnagar': 4,
#   'pathogenesis': 5,
#   'kerayong': 2,
#   'obsolete': 9,
#   'neste': 1,
#   'collare': 1,
#   'staunchly': 5,
#   'stalagmite': 2,
#   'spontaneously': 2,
#   'romantic': 4,
#   'mirroring': 2,
#   'providence': 5,
#   'lifeboat': 3,
#   'comal': 2,
#   'polonium': 1,
#   'shentong': 2,
#   'kleinberg': 2,
#   'waistline': 1,
#   'shahin': 4,
#   'yearn': 2,
#   'camcorder': 1,
#   'boyles': 1,
#   'fairbanks': 1,
#   'actionaid': 2,
#   'davie': 1,
#   'una': 1,
#   'isabella': 3,
#   'julian': 1,
#   'zigzag': 2,
#   'mideast': 1,
#   'tensile': 1,
#   'paho': 1,
#   'mova': 1,
#   'conte': 2,
#   'morbidity': 2,
#   'gastropharyngeal': 4,
#   'debate': 177,
#   'boost': 416,
#   'academy': 124,
#   'ready': 220,
#   'revise': 103,
#   'port': 116,
#   'motorcycle': 13,
#   'leave': 810,
#   'brightness': 27,
#   'expression': 123,
#   'pi': 6,
#   'traffic': 189,
#   'grow': 1221,
#   'battery': 121,
#   'oversee': 40,
#   'wall': 225,
#   'thick': 56,
#   'trine': 2,
#   'taipei': 3,
#   'mahyco': 1,
#   'israel': 150,
#   'periodic': 33,
#   'salmonella': 41,
#   'dozen': 42,
#   'issuer': 1,
#   'thirsty': 5,
#   'favorable': 148,
#   'familiarity': 7,
#   'lockheed': 82,
#   'robotic': 77,
#   'lafourche': 8,
#   'remedy': 21,
#   'symantec': 22,
#   'laureate': 18,
#   'phenomenome': 3,
#   'lithium': 1,
#   'ss': 2,
#   'mason': 16,
#   'infarction': 6,
#   'dimer': 3,
#   'brad': 4,
#   'robertson': 4,
#   'csr': 4,
#   'reliant': 2,
#   'ukraine': 18,
#   'snowmobile': 11,
#   'sulphate': 3,
#   'forge': 43,
#   'csiro': 12,
#   'trauma': 21,
#   'consciously': 3,
#   'okaloosa': 3,
#   'riegl': 3,
#   'killer': 37,
#   'elucidate': 12,
#   'crepe': 1,
#   'parietal': 4,
#   'heap': 2,
#   'rss': 3,
#   'augsburg': 1,
#   'archaeologist': 9,
#   'wolverine': 2,
#   'crosswalks': 1,
#   'centerville': 2,
#   'bernalillo': 3,
#   'scary': 9,
#   'resurrect': 26,
#   'van': 48,
#   'doradus': 1,
#   'imbalance': 6,
#   'outing': 7,
#   'par': 6,
#   'shoo': 3,
#   'exogenous': 1,
#   'extraordinarily': 5,
#   'piergiorgio': 1,
#   'elective': 33,
#   'averse': 2,
#   'elliott': 1,
#   'evil': 6,
#   'jadhav': 1,
#   'brandes': 1,
#   'manipulation': 2,
#   'marius': 3,
#   'holmes': 1,
#   'overactive': 3,
#   'octopus': 5,
#   'faraday': 1,
#   'diplomat': 2,
#   'donald': 4,
#   'meg': 2,
#   'inflight': 1,
#   'logistic': 2,
#   'hurtle': 5,
#   'abramoff': 2,
#   'ornl': 3,
#   'vanne': 1,
#   'roller': 4,
#   'patriarch': 2,
#   'utmost': 1,
#   'phosphor': 1,
#   'cpi': 5,
#   'liquidity': 1,
#   'epigenome': 1,
#   'philips': 1,
#   'tauer': 1,
#   'ing': 6,
#   'synaptopodin': 1,
#   'semel': 1,
#   'semiarid': 4,
#   'meiliang': 1,
#   'bernardo': 1,
#   'zebulon': 1,
#   'queller': 2,
#   'springbok': 1,
#   'szeliga': 2,
#   'louw': 1,
#   'robbin': 2,
#   'parbhandhak': 5,
#   'harmans': 2,
#   'maghull': 2,
#   'anouk': 2,
#   'rocketship': 1,
#   'dowling': 2,
#   'mj': 2,
#   'trudy': 2,
#   'steer': 69,
#   'intend': 120,
#   'day': 911,
#   'among': 1444,
#   'rupert': 2,
#   'render': 48,
#   'joint': 281,
#   'orbiter': 108,
#   'immunity': 16,
#   'renewable': 320,
#   'frankly': 1,
#   'estp': 1,
#   'enzyme': 70,
#   'sense': 101,
#   'subject': 188,
#   'basically': 17,
#   'yucca': 14,
#   'coastline': 17,
#   'drift': 15,
#   'outstrip': 19,
#   'neurological': 121,
#   'merkava': 1,
#   'hence': 13,
#   'vole': 11,
#   'graduate': 74,
#   'fragment': 40,
#   'birdseye': 2,
#   'session': 149,
#   'thread': 6,
#   'soybean': 36,
#   'taspo': 1,
#   'harmony': 15,
#   'perrone': 1,
#   'lesbian': 3,
#   'jared': 1,
#   'rica': 7,
#   'gvfi': 1,
#   'homology': 3,
#   'dilemma': 2,
#   'estrogen': 15,
#   'humidity': 5,
#   'relict': 1,
#   'cc': 9,
#   'beneficially': 2,
#   'kayani': 1,
#   'quest': 51,
#   'hbc': 1,
#   'rotor': 3,
#   'accost': 3,
#   'imo': 1,
#   'donnelly': 2,
#   'falcon': 9,
#   'andreas': 11,
#   'tomer': 2,
#   'nova': 24,
#   'psv': 13,
#   'battlefield': 6,
#   'technoserve': 1,
#   'californian': 18,
#   'nigeria': 4,
#   'ausra': 6,
#   'hrt': 6,
#   'perc': 1,
#   'intelligent': 50,
#   'cosponsoring': 1,
#   'pause': 15,
#   'stelios': 3,
#   'wayne': 21,
#   'mamaroneck': 2,
#   'rowdy': 1,
#   'hauler': 1,
#   'documentation': 7,
#   'melanesian': 3,
#   'argentine': 9,
#   'wasp': 7,
#   'coprolites': 1,
#   'charcoal': 6,
#   'ongaro': 3,
#   'panos': 1,
#   'zuckerman': 2,
#   'hoopa': 1,
#   'pinellas': 1,
#   'interstitial': 2,
#   'narayana': 1,
#   'compartmentation': 1,
#   'upriver': 2,
#   'longitude': 4,
#   'cobalt': 8,
#   'thundercloud': 2,
#   'iberville': 1,
#   'percival': 2,
#   'hanjiang': 8,
#   'multistage': 3,
#   'rookery': 22,
#   'overexpress': 2,
#   'sarcosine': 1,
#   'householder': 2,
#   'camouflage': 3,
#   'kounaves': 1,
#   'suk': 2,
#   'geophysicist': 2,
#   'placid': 2,
#   'uae': 2,
#   'preoccupied': 2,
#   'coo': 2,
#   'weisel': 3,
#   'peritoneal': 4,
#   'avw': 2,
#   'mccurtain': 1,
#   'hovell': 1,
#   'forklift': 1,
#   'popp': 2,
#   'infraction': 1,
#   'pierpoint': 2,
#   'bme': 1,
#   'ppiaf': 1,
#   'ginn': 2,
#   'buckholtz': 1,
#   'adobereg': 1,
#   'griesser': 1,
#   'even': 717,
#   'happen': 109,
#   'embryo': 76,
#   'stipulate': 6,
#   'breed': 261,
#   'accountability': 16,
#   'fishery': 86,
#   'alloy': 11,
#   'delhi': 30,
#   'production': 450,
#   'introduction': 32,
#   'dram': 2,
#   'landlocked': 20,
#   'infrared': 75,
#   'henry': 45,
#   'bbc': 13,
#   'fork': 27,
#   'showof': 6,
#   'cr': 1,
#   'tokyo': 61,
#   'honiara': 1,
#   'supervision': 11,
#   'dem': 2,
#   'ministry': 95,
#   'pride': 35,
#   'nitrate': 16,
#   'insulin': 97,
#   'unclear': 9,
#   'statewide': 31,
#   'haptic': 1,
#   'disperse': 22,
#   'uploads': 1,
#   'wheeler': 6,
#   'masisi': 1,
#   'alkane': 8,
#   'inos': 4,
#   'burner': 10,
#   'olympus': 6,
#   'diversion': 11,
#   'bc': 2,
#   'khamenei': 10,
#   'l': 26,
#   'circumvent': 10,
#   'astronomy': 22,
#   'yatala': 2,
#   'airspace': 4,
#   'amino': 32,
#   'eartbound': 3,
#   'randomize': 8,
#   'avert': 49,
#   'kevin': 36,
#   'sapodilla': 1,
#   'marketplace': 8,
#   'mangini': 1,
#   'asarco': 1,
#   'misse': 2,
#   'consonant': 1,
#   'zucker': 1,
#   'hester': 1,
#   'briefly': 26,
#   'oxbridge': 1,
#   'borna': 2,
#   'renaud': 2,
#   'antipsychotic': 1,
#   'oily': 6,
#   'fatten': 8,
#   'biscuit': 7,
#   'idmt': 2,
#   'honeycomb': 8,
#   'sensorpedia': 2,
#   'airfield': 1,
#   'probation': 8,
#   'overshot': 2,
#   'spallino': 1,
#   'idan': 3,
#   'priest': 1,
#   'hastings': 4,
#   'nonstick': 5,
#   'grouper': 9,
#   'drayton': 2,
#   'kidd': 1,
#   'retentive': 2,
#   'lasorda': 1,
#   'runabout': 3,
#   'bienville': 1,
#   'ammendments': 2,
#   'christoph': 1,
#   'defens': 1,
#   'piper': 1,
#   'tao': 8,
#   'preemie': 1,
#   'dunkirk': 1,
#   'mikongo': 1,
#   'donetsk': 2,
#   'salinas': 2,
#   'plamacytoid': 4,
#   'clockss': 1,
#   'helding': 1,
#   'diffusion': 4,
#   'para': 1,
#   'gila': 1,
#   'bif': 1,
#   'construccion': 1,
#   'calve': 1,
#   'upwardly': 2,
#   'ecofin': 2,
#   'qimonda': 3,
#   'programmatic': 2,
#   'brosch': 3,
#   'edgemont': 1,
#   'sagan': 1,
#   'fenwick': 2,
#   'pulsation': 2,
#   'carter': 18,
#   'whether': 840,
#   'wickwire': 2,
#   'space': 2084,
#   'ddd': 930,
#   'cripple': 11,
#   'throughout': 356,
#   'dopamine': 43,
#   'repair': 524,
#   'genetically': 88,
#   'cod': 25,
#   'lactobacilli': 1,
#   'fleet': 34,
#   'mountain': 210,
#   'midler': 1,
#   'floyd': 1,
#   'ahead': 198,
#   'uranium': 46,
#   'imply': 51,
#   'publicise': 2,
#   'alabama': 26,
#   'army': 102,
#   'overdrive': 2,
#   'fir': 8,
#   'iphone': 34,
#   'transmitter': 6,
#   'unix': 3,
#   'rift': 16,
#   'svalbard': 24,
#   'grim': 5,
#   'circle': 40,
#   'edythe': 4,
#   'coaster': 3,
#   'thornton': 8,
#   'flexible': 27,
#   'annex': 1,
#   'lampard': 1,
#   'pine': 29,
#   'casassa': 6,
#   'exclusive': 35,
#   'uninstalled': 1,
#   'ceasefire': 4,
#   'throng': 2,
#   'advective': 2,
#   'drone': 3,
#   'centerpiece': 6,
#   'lapatinib': 2,
#   'zambia': 5,
#   'disclosure': 5,
#   'catalpa': 1,
#   'isaac': 2,
#   'olsson': 1,
#   'embarrass': 1,
#   'dart': 16,
#   'samish': 3,
#   'ei': 1,
#   'edc': 2,
#   'celt': 1,
#   'uplift': 3,
#   'mccartney': 4,
#   'elicitors': 1,
#   'anglo': 3,
#   'acilius': 1,
#   'womb': 2,
#   'intercourse': 1,
#   'walleye': 1,
#   'nonalcoholic': 1,
#   'uscap': 4,
#   'convenience': 12,
#   'caribou': 5,
#   'geometry': 8,
#   'pr': 5,
#   'nitish': 1,
#   'vacancy': 2,
#   'sogaard': 1,
#   'uncharged': 2,
#   'meson': 2,
#   'luminosity': 5,
#   'lidia': 1,
#   'oems': 2,
#   'klesko': 6,
#   'nangoli': 2,
#   'metagenomics': 1,
#   'kazanian': 2,
#   'tsuneta': 1,
#   'buffon': 3,
#   'bohai': 1,
#   'irit': 4,
#   'submersible': 2,
#   'chattahoochee': 2,
#   'reacherd': 1,
#   'hairy': 1,
#   'claming': 1,
#   'stinson': 2,
#   'toxicologist': 2,
#   'steck': 1,
#   'wesleyan': 2,
#   'woodie': 1,
#   'steelmaking': 5,
#   'lemke': 2,
#   'quanta': 1,
#   'pancreatitis': 1,
#   'maud': 8,
#   'boardwalk': 1,
#   'lwr': 1,
#   'outlive': 1,
#   'outdoorsy': 1,
#   'legislature': 58,
#   'two': 2606,
#   'local': 1260,
#   'financial': 413,
#   'vulnerable': 132,
#   'scale': 126,
#   ...},
#  'health': {'still': 862,
#   'hope': 570,
#   'medicare': 444,
#   'ligament': 100,
#   'earl': 1,
#   'laxity': 1,
#   'marrow': 856,
#   'poach': 5,
#   'spoil': 48,
#   'interaction': 164,
#   'persist': 64,
#   'travel': 334,
#   'inverted': 9,
#   'elevate': 160,
#   'recognize': 466,
#   'barrier': 65,
#   'strawberry': 42,
#   'nunez': 12,
#   'librarian': 3,
#   'trail': 41,
#   'ransom': 6,
#   'everyday': 54,
#   'indigenous': 33,
#   'rejuvenate': 15,
#   'priority': 129,
#   'lieutenant': 8,
#   'bakoyiannis': 2,
#   'pitcher': 38,
#   'staph': 77,
#   'requirement': 151,
#   'online': 595,
#   'methadone': 11,
#   'electrical': 132,
#   'input': 31,
#   'creativity': 1,
#   'inflammatory': 206,
#   'indicator': 41,
#   'oscar': 18,
#   'imitation': 2,
#   'fritter': 1,
#   'sharifuddin': 2,
#   'synchronise': 7,
#   'tarnish': 20,
#   'clog': 79,
#   'embrace': 64,
#   'thwart': 36,
#   'likelihood': 71,
#   'kathmandu': 4,
#   'inner': 130,
#   'premeditated': 7,
#   'randomly': 73,
#   'accumulation': 22,
#   'nicotine': 187,
#   'art': 203,
#   'megapixel': 1,
#   'nwfp': 11,
#   'nanofibres': 1,
#   'shipyard': 2,
#   'jewelry': 3,
#   'undertreatment': 10,
#   'soumya': 2,
#   'socialization': 8,
#   'hse': 2,
#   'transaction': 44,
#   'bardhan': 1,
#   'poetry': 2,
#   'nourish': 3,
#   'outfit': 17,
#   'timetable': 1,
#   'viewpoint': 7,
#   'hidy': 6,
#   'fog': 1,
#   'jitender': 2,
#   'approvable': 4,
#   'kavya': 1,
#   'precautionary': 20,
#   'hanna': 7,
#   'mendelsohn': 2,
#   'cautious': 14,
#   'hygienist': 3,
#   'fluorescein': 4,
#   'baidi': 5,
#   'morinda': 2,
#   'crest': 6,
#   'mtor': 1,
#   'bazaar': 7,
#   'implore': 3,
#   'morgenstern': 2,
#   'degrade': 10,
#   'hydrate': 4,
#   'blaster': 10,
#   'carnegie': 12,
#   'nextrx': 2,
#   'koftas': 1,
#   'peerage': 6,
#   'guts': 10,
#   'noncaregivers': 1,
#   'gallin': 2,
#   'touchworks': 2,
#   'fossett': 2,
#   'mahant': 1,
#   'petrie': 3,
#   'carbonate': 10,
#   'backdate': 3,
#   'hobbs': 2,
#   'feign': 7,
#   'machinist': 1,
#   'cosponsor': 1,
#   'cosmeceuticals': 1,
#   'sabong': 1,
#   'jaintia': 1,
#   'antennae': 3,
#   'sedar': 4,
#   'vladimir': 4,
#   'digibind': 1,
#   'tumkur': 3,
#   'hud': 1,
#   'yummi': 1,
#   'febrile': 1,
#   'traditionalist': 2,
#   'confidentiality': 15,
#   'deicison': 1,
#   'zolotoi': 1,
#   'wto': 8,
#   'smokefree': 5,
#   'cowell': 2,
#   'leukocyte': 8,
#   'mooney': 2,
#   'packagent': 2,
#   'voyage': 4,
#   'navapur': 2,
#   'surgisource': 1,
#   'cramp': 10,
#   'acidity': 2,
#   'sarathkumar': 1,
#   'sagar': 3,
#   'gurion': 1,
#   'newron': 10,
#   'zilina': 2,
#   'rapidarc': 6,
#   'newlywed': 1,
#   'mannino': 2,
#   'driscoll': 1,
#   'countermeasure': 1,
#   'overbilled': 2,
#   'gloria': 1,
#   'reforestation': 1,
#   'shroud': 4,
#   'disassemble': 1,
#   'distil': 3,
#   'neiphiu': 2,
#   'kkr': 3,
#   'gratification': 1,
#   'fiscally': 1,
#   'kausar': 1,
#   'pant': 5,
#   'vortex': 1,
#   'heher': 2,
#   'amplifier': 5,
#   'guangken': 1,
#   'cilengitide': 2,
#   'intratumoral': 1,
#   'ruben': 1,
#   'deleterious': 5,
#   'honcho': 2,
#   'isoflavones': 1,
#   'samhsa': 3,
#   'include': 7171,
#   'retailer': 78,
#   'jurisdiction': 9,
#   'staff': 529,
#   'chestnut': 3,
#   'bone': 2572,
#   'slightly': 140,
#   'operation': 480,
#   'often': 1250,
#   'otc': 16,
#   'rimonabant': 3,
#   'beverage': 75,
#   'everincreasing': 1,
#   'mehta': 3,
#   'drain': 33,
#   'koshland': 2,
#   'finland': 4,
#   'sethi': 1,
#   'detain': 55,
#   'jakon': 2,
#   'launch': 702,
#   'television': 109,
#   'import': 436,
#   'expertise': 55,
#   'predominant': 12,
#   'partially': 155,
#   'conversation': 27,
#   'enhancement': 33,
#   'vocal': 76,
#   'tse': 1,
#   'serrano': 3,
#   'excitation': 2,
#   'vibrate': 41,
#   'drizzle': 4,
#   'tester': 3,
#   'productive': 13,
#   'absurd': 2,
#   'qaeda': 12,
#   'bullous': 1,
#   'chaudhry': 9,
#   'photograph': 26,
#   'positive': 344,
#   'chadian': 6,
#   'calderon': 6,
#   'automaker': 24,
#   'distributor': 24,
#   'cardiology': 36,
#   'shonali': 1,
#   'fraternity': 25,
#   'stent': 274,
#   'characterization': 24,
#   'cleanings': 2,
#   'consulate': 4,
#   'prestwick': 2,
#   'pharmacology': 26,
#   'lucy': 4,
#   'auction': 22,
#   'hurry': 8,
#   'outgoing': 19,
#   'kiwi': 7,
#   'newspersons': 2,
#   'wali': 1,
#   'speedy': 13,
#   'deaconess': 45,
#   'sigma': 3,
#   'irwin': 3,
#   'conspicuous': 5,
#   'endoscopic': 94,
#   'thyroid': 34,
#   'unmanned': 9,
#   'biventricular': 1,
#   'infective': 1,
#   'valerie': 6,
#   'lloydminster': 2,
#   'zoellner': 1,
#   'liaise': 3,
#   'basant': 2,
#   'hardy': 1,
#   'plac': 1,
#   'selvey': 1,
#   'tyramine': 2,
#   'cabrera': 4,
#   'interferon': 2,
#   'fraternal': 7,
#   'schweitzer': 1,
#   'nausea': 17,
#   'wrestle': 14,
#   'aig': 5,
#   'column': 5,
#   'guar': 2,
#   'airflow': 5,
#   'dough': 2,
#   'plasticity': 5,
#   'looseness': 2,
#   'shank': 2,
#   'agrarian': 3,
#   'neurosurgery': 18,
#   'rajat': 1,
#   'nicolson': 2,
#   'rosset': 13,
#   'cobain': 1,
#   'goodman': 4,
#   'valeant': 2,
#   'cfm': 1,
#   'resistor': 1,
#   'scorn': 3,
#   'vineland': 1,
#   'radek': 1,
#   'cognizant': 2,
#   'ghulam': 3,
#   'motorist': 5,
#   'fawn': 2,
#   'sceptical': 1,
#   'spyware': 1,
#   'pasteurised': 2,
#   'madhepura': 3,
#   'krueger': 2,
#   'wrongdoing': 2,
#   'nondisclosure': 1,
#   'colo': 4,
#   'prevalance': 16,
#   'rhythmic': 4,
#   'immucell': 2,
#   'valente': 2,
#   'cipp': 1,
#   'gencrest': 1,
#   'ebv': 4,
#   'dermatics': 9,
#   'anoka': 1,
#   'socio': 2,
#   'imager': 2,
#   'reinject': 1,
#   'col': 1,
#   'galactose': 1,
#   'speedway': 8,
#   'indictment': 1,
#   'macho': 5,
#   'occult': 3,
#   'transmute': 1,
#   'ruia': 1,
#   'circumferentially': 1,
#   'zilla': 1,
#   'flammable': 1,
#   'crust': 1,
#   'elisa': 1,
#   'morrell': 2,
#   'smirnoff': 1,
#   'undeterred': 1,
#   'amaryl': 1,
#   'alliant': 5,
#   'biase': 1,
#   'sail': 20,
#   'harry': 19,
#   'plane': 53,
#   'map': 116,
#   'limb': 91,
#   'vinegar': 20,
#   'achieve': 789,
#   'explain': 440,
#   'equal': 171,
#   'cook': 232,
#   'growth': 622,
#   'australia': 129,
#   'watch': 329,
#   'rankings': 29,
#   'powerpoint': 4,
#   'postpone': 37,
#   'der': 18,
#   'hometown': 6,
#   'bloc': 14,
#   'flaherty': 3,
#   'hockey': 28,
#   'refrigerator': 15,
#   'ct': 58,
#   'disaster': 111,
#   'rf': 8,
#   'premiere': 6,
#   'carboxyhemoglobin': 3,
#   'hybridoma': 4,
#   'androgen': 24,
#   'mumbaikers': 1,
#   'underprivileged': 6,
#   'decay': 21,
#   'evaluation': 70,
#   'clover': 2,
#   'sundance': 3,
#   'agartala': 1,
#   'incited': 4,
#   'chennai': 24,
#   'chemistry': 68,
#   'cia': 6,
#   'qt': 6,
#   'resection': 25,
#   'cable': 32,
#   'stronghold': 7,
#   'afterwards': 7,
#   'frustrate': 36,
#   'dickerson': 3,
#   'galactic': 8,
#   'coin': 11,
#   'gere': 4,
#   'oncotype': 2,
#   'promacta': 5,
#   'amp': 4,
#   'pensacola': 3,
#   'suvrajit': 1,
#   'chalk': 5,
#   'ravishankar': 2,
#   'lark': 2,
#   'siddhivinayak': 1,
#   'doctrine': 2,
#   'cizmar': 1,
#   'schoolgirl': 8,
#   'drugstore': 14,
#   'ift': 2,
#   'markey': 2,
#   'yuvraj': 3,
#   'armpit': 2,
#   'musculoskeletal': 51,
#   'infusion': 62,
#   'gall': 14,
#   'wasa': 2,
#   'verheugen': 10,
#   'pyi': 1,
#   'brochette': 1,
#   'spigelman': 2,
#   'villarreal': 1,
#   'lakra': 1,
#   'celexa': 2,
#   'dung': 11,
#   'paddy': 10,
#   'hypertrophic': 4,
#   'lords': 1,
#   'pentinin': 2,
#   'palmerston': 1,
#   'xecutive': 1,
#   'alison': 2,
#   'haunt': 8,
#   'modernization': 30,
#   'rockies': 2,
#   'hub': 21,
#   'intercept': 8,
#   'mahaboobnagar': 1,
#   'muscular': 27,
#   'ectoderm': 2,
#   'riverbed': 1,
#   'ernst': 18,
#   'centene': 1,
#   'tanespimycin': 24,
#   'stockholm': 3,
#   'keyboard': 6,
#   'dmv': 2,
#   'wearer': 4,
#   'drip': 7,
#   'westfield': 1,
#   'greenland': 12,
#   'hiato': 1,
#   'patinkin': 2,
#   'saline': 2,
#   'fletcher': 2,
#   'desferrioxamine': 2,
#   'marfan': 2,
#   'expiratory': 1,
#   'saliva': 19,
#   'adulteration': 3,
#   'brett': 12,
#   'impressively': 4,
#   'glassheim': 1,
#   'fax': 6,
#   'greece': 5,
#   'suchy': 1,
#   'lakhiserai': 4,
#   'thiruvananthapuram': 5,
#   'newton': 2,
#   'dausa': 1,
#   'goldfish': 3,
#   'sobesky': 2,
#   'disarray': 1,
#   'pyke': 1,
#   'bonderman': 1,
#   'aua': 4,
#   'lamaison': 2,
#   'raptiva': 4,
#   'dehydrate': 1,
#   'tcd': 2,
#   'tdsat': 3,
#   'mela': 2,
#   'johann': 1,
#   'brfs': 1,
#   'gurgle': 2,
#   'marat': 1,
#   'hemmes': 1,
#   'hasd': 1,
#   'strummer': 2,
#   'covertly': 1,
#   'washona': 2,
#   'neurobiologist': 1,
#   'arbovirus': 2,
#   'madhukarrao': 1,
#   'angiogenic': 1,
#   'bioimaging': 2,
#   'gertraud': 1,
#   'forhan': 42,
#   'emts': 1,
#   'retriever': 3,
#   'stabilisation': 1,
#   'vallabhbhai': 2,
#   'progestins': 1,
#   'dimple': 1,
#   'prevent': 3027,
#   'character': 26,
#   'typically': 322,
#   'stomach': 62,
#   'farm': 572,
#   'psa': 36,
#   'en': 16,
#   'shut': 59,
#   'brite': 1,
#   'opposition': 178,
#   'suicide': 178,
#   'extension': 44,
#   'seitz': 2,
#   'slow': 672,
#   'incur': 77,
#   'antidepressant': 73,
#   'lubricate': 13,
#   'eligibility': 31,
#   'film': 187,
#   'srba': 4,
#   'chemotherapy': 154,
#   'rhode': 56,
#   'julian': 4,
#   'spontaneously': 2,
#   'globally': 30,
#   'servant': 16,
#   'roadside': 85,
#   'jamaat': 1,
#   'valley': 174,
#   'dive': 22,
#   'lifeboat': 1,
#   'stringent': 42,
#   'accusation': 12,
#   'boulevard': 25,
#   'biography': 2,
#   'louisa': 2,
#   'dpa': 2,
#   'gerry': 3,
#   'pipeline': 26,
#   'terra': 3,
#   'gasoline': 25,
#   'intricate': 13,
#   'settlement': 112,
#   'anti': 6,
#   'macintosh': 8,
#   'purulia': 3,
#   'bench': 34,
#   'bokaro': 3,
#   'stalagmite': 1,
#   'pndt': 4,
#   'providence': 16,
#   'portugal': 1,
#   'tysabri': 4,
#   'weatherill': 5,
#   'jar': 17,
#   'undetected': 9,
#   'neoplasm': 2,
#   'waistline': 5,
#   'boomer': 46,
#   'intact': 30,
#   'satia': 1,
#   'najafgarh': 2,
#   'cahors': 1,
#   'oakland': 7,
#   'selvam': 2,
#   'inglis': 3,
#   'tensile': 1,
#   'kendall': 1,
#   'centerview': 2,
#   'mova': 1,
#   'norditropin': 1,
#   'coral': 10,
#   'intradermal': 2,
#   'stromboli': 1,
#   'wolfe': 3,
#   'catapult': 2,
#   'perspective': 11,
#   'parlayed': 9,
#   'tri': 2,
#   'gillard': 2,
#   'kinematic': 5,
#   'midway': 9,
#   'romantic': 5,
#   'extravaganza': 2,
#   'pathogenesis': 6,
#   'turf': 4,
#   'borneo': 4,
#   'stove': 6,
#   'gaur': 8,
#   'shiite': 11,
#   'frunesco': 1,
#   'ira': 1,
#   'staunchly': 2,
#   'nat': 1,
#   'overthrow': 2,
#   'pediarix': 3,
#   'stromedix': 2,
#   'garuda': 7,
#   'excisable': 4,
#   'morbidity': 24,
#   'anorexia': 8,
#   'wagner': 6,
#   'tejaswani': 2,
#   'garros': 10,
#   'solesome': 1,
#   'exhort': 4,
#   'ciliopathic': 2,
#   'integrase': 2,
#   'filmfare': 2,
#   'camcorder': 4,
#   'ascend': 10,
#   'topoisomerase': 2,
#   'demystify': 2,
#   'mirroring': 2,
#   'sherrin': 1,
#   'mideast': 1,
#   'cathie': 1,
#   'obsolete': 10,
#   'soundwave': 1,
#   'bachelet': 4,
#   'divulge': 1,
#   'incompatible': 8,
#   'ronnie': 5,
#   'stoda': 1,
#   'seniormost': 1,
#   'abundantly': 1,
#   'stoldt': 1,
#   'vaporize': 1,
#   'yearn': 1,
#   'cardboard': 2,
#   'ulmert': 1,
#   'pmt': 1,
#   'babe': 1,
#   'firrhill': 2,
#   'petrochemical': 1,
#   'asher': 6,
#   'sahar': 3,
#   'geovax': 1,
#   'silverton': 2,
#   'reorganizes': 2,
#   'anomalous': 2,
#   'unimpaired': 7,
#   'surf': 6,
#   'kerayong': 1,
#   'gymnastics': 1,
#   'shrinkwrapped': 1,
#   'apna': 1,
#   'heren': 2,
#   'walgreens': 1,
#   'valortim': 1,
#   'retest': 1,
#   'offload': 1,
#   'saratoga': 2,
#   'akashwani': 1,
#   'van': 74,
#   'revise': 133,
#   'grow': 1139,
#   'wall': 184,
#   'mishra': 4,
#   'jadhav': 3,
#   'ready': 159,
#   'leave': 1701,
#   'port': 46,
#   'boost': 468,
#   'ultimo': 9,
#   'favorable': 56,
#   'salmonella': 255,
#   'brad': 13,
#   'academy': 430,
#   'debate': 317,
#   'remedy': 39,
#   'imbalance': 20,
#   'expression': 136,
#   'synaptopodin': 1,
#   'cholerae': 2,
#   'dozen': 54,
#   'trauma': 140,
#   'parietal': 18,
#   'holmes': 17,
#   'stockyard': 20,
#   'elective': 190,
#   'israel': 92,
#   'robertson': 18,
#   'cirsis': 1,
#   'karshaka': 1,
#   'traffic': 199,
#   'augustinian': 2,
#   'broom': 1,
#   'oversee': 103,
#   'donald': 22,
#   'evil': 5,
#   'robotic': 31,
#   'crittenden': 1,
#   'liquidity': 10,
#   'lafourche': 4,
#   'csiro': 7,
#   'videoconference': 1,
#   'laureate': 15,
#   'infarction': 26,
#   'battery': 35,
#   'roller': 16,
#   'musculature': 4,
#   'lockheed': 12,
#   'forge': 39,
#   'humanize': 1,
#   'brightness': 2,
#   'crepe': 8,
#   'ing': 3,
#   'marges': 1,
#   'elliott': 8,
#   'par': 28,
#   'pinto': 2,
#   'diplomat': 2,
#   'extraordinarily': 10,
#   'mason': 11,
#   'vanessa': 2,
#   'consciously': 52,
#   'periodic': 40,
#   'logistic': 8,
#   'thick': 28,
#   'biobank': 1,
#   'shinde': 3,
#   'cpi': 3,
#   'elucidate': 18,
#   'issuer': 2,
#   'decongest': 2,
#   'heap': 1,
#   'patriarch': 3,
#   'summerised': 4,
#   'winslet': 3,
#   'dewan': 3,
#   'motorcycle': 19,
#   'rss': 3,
#   'thirsty': 3,
#   'archaeologist': 2,
#   'killer': 68,
#   'rios': 1,
#   'rhythmically': 1,
#   'overactive': 14,
#   'macaskill': 2,
#   'reliant': 4,
#   'octopus': 1,
#   'seema': 4,
#   'ukraine': 7,
#   'chamorro': 2,
#   'philips': 15,
#   'resurrect': 3,
#   'bruiser': 5,
#   'stabilizer': 7,
#   'exemplar': 1,
#   'gasket': 3,
#   'pi': 6,
#   'indiramma': 2,
#   'iba': 1,
#   'marad': 4,
#   'scary': 7,
#   'glivec': 4,
#   'chock': 3,
#   'ilsi': 1,
#   'familiarity': 9,
#   'mathura': 1,
#   'taipei': 1,
#   'pantomiming': 1,
#   'moonbi': 2,
#   'nashik': 4,
#   'wink': 1,
#   'lithium': 1,
#   'ppgi': 1,
#   'sulphate': 1,
#   'manipulation': 5,
#   'salutas': 1,
#   'salivart': 1,
#   'prabhu': 1,
#   'symantec': 1,
#   'pallipurath': 1,
#   'louw': 3,
#   'kean': 2,
#   'nocht': 8,
#   'outing': 4,
#   'collegeville': 2,
#   'lengyel': 1,
#   'monotherapy': 7,
#   'relearn': 1,
#   'ss': 3,
#   'stumpf': 1,
#   'chamara': 1,
#   'pushpavanam': 1,
#   'queller': 2,
#   'morayfield': 2,
#   'frazer': 3,
#   'matsui': 2,
#   'lagan': 4,
#   'orthodoxy': 1,
#   'dogra': 1,
#   'trudy': 10,
#   'lipoplasty': 3,
#   'exogenous': 3,
#   'biofocus': 2,
#   'amsler': 1,
#   'leggett': 2,
#   'pu': 2,
#   'dinarello': 1,
#   'semiarid': 1,
#   'immunde': 1,
#   'epigenome': 2,
#   'among': 9499,
#   'day': 1546,
#   'intelligent': 33,
#   'concord': 2,
#   'santos': 16,
#   'intend': 145,
#   'sermon': 1,
#   'graduate': 102,
#   'subject': 436,
#   'session': 189,
#   'sense': 120,
#   'joint': 581,
#   'basically': 12,
#   'render': 49,
#   'neurological': 599,
#   'mpsj': 2,
#   'immunity': 13,
#   'forklift': 3,
#   'outstrip': 10,
#   'renewable': 38,
#   'kyler': 1,
#   'vole': 3,
#   'steer': 41,
#   'hence': 15,
#   'estrogen': 73,
#   'alpenglow': 1,
#   'kataria': 2,
#   'cc': 3,
#   'dade': 3,
#   'cerner': 5,
#   'specifurn': 2,
#   'enzyme': 193,
#   'risc': 1,
#   'traumacad': 1,
#   'spartan': 3,
#   'nigeria': 9,
#   'lesbian': 6,
#   'marcopolo': 1,
#   'ultrarapid': 1,
#   'octane': 12,
#   'andreas': 3,
#   'bandleader': 1,
#   'pause': 9,
#   'wayne': 58,
#   'atal': 8,
#   'yamaha': 6,
#   'verdant': 2,
#   'rowdy': 2,
#   'accost': 6,
#   'donnelly': 8,
#   'quest': 7,
#   'fragment': 9,
#   'pramod': 2,
#   'umno': 10,
#   'drift': 4,
#   'camouflage': 3,
#   'zikim': 1,
#   'vera': 4,
#   'rica': 15,
#   'uae': 8,
#   'kumba': 2,
#   'cosponsoring': 4,
#   'documentation': 9,
#   'harmony': 7,
#   'reston': 1,
#   'thread': 14,
#   'technoserve': 2,
#   'battlefield': 7,
#   'californian': 18,
#   'peritoneal': 6,
#   'draconian': 4,
#   'orbiter': 4,
#   'footballer': 4,
#   'falcon': 2,
#   'lacroix': 1,
#   'coastline': 1,
#   'soybean': 12,
#   'valpey': 1,
#   'clandestine': 4,
#   'eyeforpharma': 4,
#   'yucca': 3,
#   'portrayes': 1,
#   'mathare': 2,
#   'oxycyte': 2,
#   'overexpress': 10,
#   'suk': 3,
#   'humidity': 4,
#   'northview': 2,
#   'macias': 2,
#   'doodle': 1,
#   'ppsor': 1,
#   'hanjiang': 2,
#   'rupert': 7,
#   'roache': 1,
#   'bme': 4,
#   'nova': 5,
#   'rekha': 2,
# ...
#   'librarian': 44,
#   'anime': 181,
#   'creativity': 49,
#   'distil': 59,
#   'melodic': 106,
#   'transference': 1,
#   'nicotine': 6,
#   'cheyenne': 14,
#   'interaction': 44,
#   'input': 74,
#   'magsasara': 2,
#   'bratters': 1,
#   'dts': 6,
#   'requirement': 147,
#   'randomly': 35,
#   'solemnity': 10,
#   'fog': 37,
#   'protoss': 4,
#   'rha': 4,
#   'foxy': 26,
#   'cautious': 28,
#   'crest': 14,
#   'deftly': 33,
#   'ruben': 27,
#   'carlo': 31,
#   'samis': 1,
#   'photovoltaic': 9,
#   'transaction': 45,
#   'magicscore': 1,
#   'degrade': 50,
#   'didactic': 2,
#   'indicator': 21,
#   'tarnish': 55,
#   'ineluctably': 2,
#   'thwart': 62,
#   'vortex': 14,
#   'barrier': 98,
#   'misogynist': 4,
#   'poetry': 122,
#   'lyrical': 40,
#   'earl': 148,
#   'inimical': 2,
#   'ligament': 100,
#   'jewelry': 116,
#   'boyf': 2,
#   'indigenous': 90,
#   'jrotc': 2,
#   'soundscan': 13,
#   'gloria': 37,
#   'gagosian': 9,
#   'lacrosse': 19,
#   'harasser': 1,
#   'hanna': 51,
#   'oberriter': 2,
#   'foamlike': 1,
#   'izzie': 2,
#   'poppy': 22,
#   'fossett': 12,
#   'gaurav': 6,
#   'acidity': 2,
#   'giglio': 2,
#   'bazaar': 4,
#   'inverted': 3,
#   'rize': 1,
#   'clog': 28,
#   'iffy': 2,
#   'hulchul': 2,
#   'sharona': 1,
#   'tumkur': 1,
#   'salma': 10,
#   'shipyard': 5,
#   'shroud': 41,
#   'siple': 3,
#   'aruba': 9,
#   'vladimir': 31,
#   'brauhaus': 1,
#   'tweety': 2,
#   'hobbs': 7,
#   'silvercity': 1,
#   'formby': 4,
#   'didi': 2,
#   'honcho': 32,
#   'unmodified': 2,
#   'barenboim': 10,
#   'guerin': 9,
#   'reassertion': 10,
#   'synchronise': 5,
#   'socialization': 1,
#   'viewpoint': 9,
#   'confidentiality': 168,
#   'pacquiao': 6,
#   'pant': 8,
#   'elongate': 3,
#   'visalia': 3,
#   'nemcova': 7,
#   'inanity': 3,
#   'unequivocal': 2,
#   'implore': 9,
#   'unlined': 3,
#   'buendia': 1,
#   'suzhou': 4,
#   'zushi': 1,
#   'rapidarc': 2,
#   'mooney': 6,
#   'azera': 1,
#   'blaster': 11,
#   'lamott': 2,
#   'bookshelf': 1,
#   'antennae': 3,
#   'verte': 1,
#   'lawlor': 2,
#   'mccourt': 5,
#   'miron': 2,
#   'granado': 1,
#   'morgenstern': 2,
#   'undescribable': 2,
#   'guts': 23,
#   'ransom': 42,
#   'convergent': 5,
#   'staph': 3,
#   'marrow': 17,
#   'pinciotti': 1,
#   'pushback': 1,
#   'carbonate': 3,
#   'mmorpgs': 3,
#   'disassemble': 3,
#   'phlip': 8,
#   'nabubura': 1,
#   'cbgb': 3,
#   'timetable': 9,
#   'makakaapekto': 1,
#   'shabana': 6,
#   'bordernig': 1,
#   'delas': 2,
#   'precautionary': 47,
#   'medicare': 10,
#   'muchmusic': 1,
#   'whiteshell': 4,
#   'eguinea': 2,
#   'premeditated': 1,
#   'trina': 14,
#   'frostfell': 1,
#   'heinrich': 11,
#   'destitute': 4,
#   'isp': 2,
#   'flatus': 1,
#   'preamp': 2,
#   'didgeridoo': 1,
#   'insipid': 5,
#   'luffy': 1,
#   'slaver': 1,
#   'mccarthyism': 1,
#   'kavya': 2,
#   'chien': 2,
#   'overbilled': 2,
#   'tapdance': 3,
#   'inflammatory': 4,
#   'accumulation': 2,
#   'kitsios': 2,
#   'reintegration': 1,
#   'traditionalist': 2,
#   'battlefront': 2,
#   'kokey': 1,
#   'kornicki': 1,
#   'guernsey': 2,
#   'machebeuf': 1,
#   'honkytonk': 1,
#   'ramrod': 1,
#   'kiyoshi': 1,
#   'reddish': 4,
#   'sagawa': 2,
#   'pote': 3,
#   'vanden': 16,
#   'bolden': 3,
#   'kefta': 1,
#   'wtih': 1,
#   'kitchener': 10,
#   'brant': 1,
#   'fritter': 27,
#   'linguini': 13,
#   'habanero': 7,
#   'sabayon': 1,
#   'dinnerstein': 1,
#   'flaccid': 2,
#   'chibi': 1,
#   'jaeha': 8,
#   'hydrate': 4,
#   'likelihood': 7,
#   'nunez': 21,
#   'chairez': 14,
#   'godsmack': 2,
#   'gyngell': 4,
#   'lorenzi': 3,
#   'mudhoney': 1,
#   'nederlanders': 1,
#   'orn': 2,
#   'combatively': 2,
#   'puddleducks': 3,
#   'jitender': 2,
#   'brushmarks': 3,
#   'schaeffer': 1,
#   'julfa': 1,
#   'methadone': 2,
#   'smokefree': 2,
#   'torontonian': 1,
#   'ashkenaz': 2,
#   'takamura': 1,
#   'customflix': 1,
#   'feign': 22,
#   'guli': 1,
#   'fiscally': 1,
#   'argentino': 2,
#   'geass': 12,
#   'benanti': 2,
#   'malary': 2,
#   'sourcebook': 1,
#   'desecration': 4,
#   'kinciaid': 2,
#   'veronika': 1,
#   'trimpe': 1,
#   'mcinulty': 4,
#   'zallo': 1,
#   'abrio': 1,
#   'abisalovich': 1,
#   'backdate': 3,
#   'valrene': 4,
#   'masasama': 1,
#   'elsa': 3,
#   'boekhout': 2,
#   'kathmandu': 1,
#   'quillwork': 3,
#   'resister': 1,
#   'payglobal': 2,
#   'terrifically': 9,
#   'gua': 8,
#   'peerage': 1,
#   'tollbooths': 4,
#   'hud': 12,
#   'allegorize': 1,
#   'fozzie': 4,
#   'megalomaniacal': 6,
#   'mendelsohn': 4,
#   'dolphyesque': 4,
#   'intermountain': 3,
#   'gurion': 2,
#   'syndi': 1,
#   'bava': 1,
#   'telecomview': 1,
#   'soundness': 2,
#   'manggar': 4,
#   'cinven': 1,
#   'aleck': 3,
#   'cuernavaca': 1,
#   'deleterious': 1,
#   'rashy': 1,
#   'windsurfer': 1,
#   'yoshi': 2,
#   'respectably': 2,
#   'tillis': 4,
#   'pringle': 10,
#   'often': 1699,
#   'include': 21346,
#   'hardy': 131,
#   'staff': 662,
#   'launch': 3342,
#   'television': 2335,
#   'auction': 639,
#   'calvin': 16,
#   'sequel': 356,
#   'column': 151,
#   'operation': 773,
#   'sigma': 23,
#   'distributor': 89,
#   'bone': 119,
#   'wrestle': 190,
#   'photograph': 620,
#   'cobain': 21,
#   'chestnut': 36,
#   'rhythmic': 218,
#   'goodman': 54,
#   'advil': 6,
#   'vibrate': 34,
#   'vocal': 1288,
#   'valerie': 48,
#   'slightly': 384,
#   'wilfred': 4,
#   'truculent': 1,
#   'witt': 1,
#   'outgoing': 84,
#   'calexico': 4,
#   'drain': 61,
#   'import': 255,
#   'dierks': 303,
#   'undeterred': 1,
#   'airflow': 4,
#   'rebirth': 14,
#   'retailer': 157,
#   'positive': 449,
#   'irretrievable': 3,
#   'lucy': 109,
#   'thyroid': 8,
#   'kiwi': 49,
#   'conversation': 114,
#   'jurisdiction': 13,
#   'jansons': 2,
#   'shank': 20,
#   'aig': 16,
#   'automaker': 114,
#   'apne': 14,
#   'rosato': 2,
#   'partially': 34,
#   'attard': 2,
#   'marley': 99,
#   'conspicuous': 12,
#   'productive': 10,
#   'regularity': 4,
#   'dough': 33,
#   'tester': 10,
#   'beverage': 123,
#   'crust': 47,
#   'occult': 12,
#   'brilliantly': 33,
#   'otc': 3,
#   'collectable': 3,
#   'weirdo': 8,
#   'qaeda': 30,
#   'gadget': 16,
#   'steinkellner': 6,
#   'herschel': 4,
#   'wrongdoing': 28,
#   'brusque': 1,
#   'mafia': 51,
#   'drizzle': 224,
#   'richness': 12,
#   'detain': 132,
#   'fawn': 6,
#   'irwin': 26,
#   'macho': 31,
#   'oddly': 28,
#   'expertise': 36,
#   'sommelier': 50,
#   'egomaniac': 2,
#   'indictment': 21,
#   'lazio': 5,
#   'unmanned': 2,
#   'gatecrash': 31,
#   'nonflammable': 1,
#   'gemma': 20,
#   'hurry': 37,
#   'agrarian': 4,
#   'quarreled': 4,
#   'jergens': 1,
#   'shrunken': 7,
#   'elisa': 12,
#   'whur': 1,
#   'rajat': 9,
#   'daringly': 3,
#   'speedy': 36,
#   'fraternal': 35,
#   'fraternity': 102,
#   'rey': 3,
#   'scifi': 4,
#   'rakestraw': 1,
#   'consulate': 31,
#   'mehta': 24,
#   'delirious': 10,
#   'smirnoff': 4,
#   'absurd': 28,
#   'recher': 4,
#   'companionable': 3,
#   'darius': 7,
#   'transmute': 3,
#   'predominant': 4,
#   'dvcpro': 1,
#   'motorist': 11,
#   'parton': 52,
#   'groo': 1,
#   'lakota': 7,
#   'mcninja': 1,
#   'col': 1,
#   'buttita': 1,
#   'koenig': 27,
#   'mccrary': 8,
#   'speedway': 50,
#   'minolta': 1,
#   'diorama': 20,
#   'cabrera': 6,
#   'vollmann': 2,
#   'calderon': 33,
#   'manipulative': 10,
#   'airg': 3,
#   'deaconess': 1,
#   'endoscopic': 3,
#   'cleanings': 2,
#   'enhancement': 42,
#   'ursula': 8,
#   'sanguine': 2,
#   'yusni': 2,
#   'sushila': 1,
#   'diabate': 2,
#   'fain': 7,
#   'bingle': 3,
#   'nickolas': 3,
#   'mulet': 3,
#   'ranaan': 4,
#   'characterization': 4,
#   'heelers': 1,
#   'pasteurised': 2,
#   'malt': 10,
#   'unimpeachable': 3,
#   'fittingly': 8,
#   'quillen': 2,
#   'looseness': 2,
#   'maguda': 1,
#   'tivo': 20,
#   'dalyn': 1,
#   'whiteboard': 2,
#   'nextune': 3,
#   'spyware': 10,
#   'ableton': 20,
#   'ratedr': 2,
#   'chadian': 1,
#   'rueful': 3,
#   'angelis': 4,
#   'minisode': 2,
#   'hordichuk': 2,
#   'saviano': 1,
#   'scorn': 13,
#   'hipp': 4,
#   'schweitzer': 3,
#   'leland': 6,
#   'extemporized': 1,
#   'sheilah': 1,
#   'philology': 9,
#   'camphire': 1,
#   'vesuvio': 4,
#   'kourtney': 3,
#   'mervis': 1,
#   'calley': 2,
#   'clodfelter': 2,
#   'peattie': 1,
#   'massacr': 33,
#   'insound': 1,
#   'rewarm': 1,
#   'zerquetscherin': 2,
#   'damnation': 6,
#   'dreesen': 2,
#   'belladrum': 1,
#   'belz': 2,
#   'sandusky': 1,
#   'gunbuster': 2,
#   'finland': 3,
#   'mushref': 2,
#   'aponick': 2,
#   'cincnnati': 1,
#   'ravikumar': 2,
#   'glycolic': 1,
#   'bugg': 1,
#   'unflappable': 108,
#   'vineland': 2,
#   'unwise': 2,
#   'lismore': 2,
#   'radek': 1,
#   'nyra': 6,
#   'kyo': 1,
#   'tosh': 1,
#   'nausea': 2,
#   'upends': 2,
#   'fusek': 6,
#   'jakon': 40,
#   'flammable': 6,
#   'colo': 12,
#   'sagutin': 4,
#   'surrealistic': 2,
#   'panchthar': 1,
#   'chavis': 5,
#   'chaudhry': 4,
#   'zoellner': 2,
#   'floaty': 10,
#   'pensive': 5,
#   'heedlessly': 4,
#   'convection': 1,
#   'indigenes': 2,
#   'kurush': 2,
#   'cachora': 2,
#   'bushner': 3,
#   'henin': 1,
#   'rosenzweig': 2,
#   'suntan': 1,
#   'talanga': 1,
#   'lamers': 1,
#   'conflate': 2,
#   'valente': 2,
#   'sethi': 1,
#   'frizz': 1,
#   'strummy': 1,
#   'ujazdowski': 3,
#   'assad': 2,
#   'wholefood': 1,
#   'runyonesque': 6,
#   'lapidus': 8,
#   'vespa': 18,
#   'humanistic': 1,
#   'acdelco': 1,
#   'liron': 1,
#   'perforamnces': 8,
#   'madhepura': 2,
#   'grisham': 5,
#   'bagavathar': 1,
#   'narcissistic': 1,
#   'santis': 10,
#   'welterweight': 6,
#   'esun': 4,
#   'asolo': 2,
#   'cuttings': 1,
#   'wali': 1,
#   'springboro': 2,
#   'sceptical': 1,
#   'canoodle': 4,
#   'veres': 6,
#   'abashova': 2,
#   'mallinder': 1,
#   'yungang': 1,
#   'ldv': 2,
#   'inviolably': 1,
#   'abacela': 2,
#   'rupiah': 1,
#   'lempira': 1,
#   'menahem': 1,
#   'postive': 2,
#   'tittilating': 1,
#   'hardstone': 1,
#   'greutert': 1,
#   'restlessly': 1,
#   'krueger': 1,
#   'rubinoos': 2,
#   'cabal': 2,
#   'anhalf': 1,
#   'hargreaves': 1,
#   'liaise': 2,
#   'peiyan': 6,
#   'facttracker': 1,
#   'benullo': 2,
#   'husseini': 1,
#   'logistically': 1,
#   'streeter': 7,
#   'keyboard': 141,
#   'watch': 2161,
#   'gau': 3,
#   'der': 51,
#   'airlock': 4,
#   'worldview': 4,
#   'premiere': 1571,
#   'cable': 762,
#   'cook': 665,
#   'sundance': 642,
#   'postpone': 322,
#   'harry': 990,
#   'dehydrate': 4,
#   'bloc': 53,
#   'decay': 14,
#   'coker': 3,
#   'gere': 98,
#   'terrifyingly': 2,
#   'map': 345,
#   'vinegar': 75,
#   'plane': 282,
#   'limb': 19,
#   'newton': 106,
#   'varoli': 9,
#   'australia': 627,
#   'fletcher': 158,
#   'explain': 669,
#   'stronghold': 12,
#   'dickson': 37,
#   'mackie': 47,
#   'ernster': 3,
#   'salter': 2,
#   'hockey': 177,
#   'lords': 51,
#   'jah': 3,
#   'gaylord': 33,
#   'achieve': 951,
#   'muscular': 61,
#   'haunt': 328,
#   'itv': 85,
#   'frustrate': 63,
#   'equal': 351,
#   'disaster': 114,
#   'oblivious': 18,
#   'alia': 2,
#   'growth': 387,
#   'evaluation': 40,
#   'memling': 2,
#   'nerf': 5,
#   'sail': 197,
#   'cia': 75,
#   'chalk': 18,
#   'paddy': 11,
#   'townsville': 3,
#   'murky': 48,
#   'coin': 65,
#   'everlasting': 12,
#   'hometown': 201,
#   'julienne': 5,
#   'drip': 127,
#   'hub': 53,
#   'tanith': 176,
#   'nighy': 16,
#   'fax': 75,
#   'sandal': 28,
#   'demeaning': 8,
#   'militancy': 1,
#   'greece': 32,
#   'enmesh': 7,
#   'schoolgirl': 14,
#   'preleaked': 1,
#   'amp': 50,
#   'citadeltheatre': 2,
#   'mughal': 3,
#   'chemistry': 25,
#   'vigilantism': 3,
#   'doctrine': 15,
#   'flaherty': 21,
#   'cartier': 8,
#   'stockholm': 18,
#   'dimple': 4,
#   'terview': 1,
#   'alison': 66,
#   'sian': 10,
#   'covertly': 56,
#   'najaf': 2,
#   'viper': 16,
#   'westfield': 15,
#   'strummer': 4,
#   'breezy': 22,
#   'snopp': 4,
#   'yamana': 2,
#   'disprove': 55,
#   'boogie': 38,
#   'ascione': 2,
#   'stagg': 4,
#   'brett': 58,
#   'johann': 23,
#   'laine': 3,
#   'womanizer': 13,
#   'ladysmith': 4,
#   'hagar': 31,
#   'versace': 30,
#   'refrigerator': 24,
#   'mixtape': 16,
#   'awasthi': 4,
#   'rankings': 9,
#   'ionescu': 1,
#   'emancipation': 7,
#   'afterwards': 32,
#   'ernst': 10,
#   'infusion': 3,
#   'ct': 9,
#   'candice': 11,
#   'rf': 1,
#   'intercept': 27,
#   'folder': 6,
#   'mela': 3,
#   'deliverance': 1,
#   'walden': 20,
#   'gurgle': 14,
#   'impressively': 13,
#   'retriever': 11,
#   'greenland': 9,
#   'modernization': 8,
#   'galactic': 49,
#   'ruggiero': 2,
#   'patinkin': 37,
#   'drugstore': 11,
#   'eggers': 1,
#   'chennai': 29,
#   'luchino': 5,
#   'forhan': 6,
#   'pihl': 1,
#   'wearer': 1,
#   'beauvoir': 1,
#   'marat': 1,
#   'enrapture': 9,
#   'jima': 30,
#   'lark': 10,
#   'silpada': 1,
#   'selcuk': 1,
#   'rachleff': 4,
#   'gall': 3,
#   'groundbreakers': 6,
#   'cofounded': 3,
#   'dorset': 1,
#   'eponymous': 18,
#   'vendemmia': 1,
#   'northglenn': 3,
#   'powerpoint': 5,
#   'armpit': 2,
#   'kfog': 1,
#   'bagpiper': 1,
#   'palmerston': 8,
#   'sigrid': 4,
#   'miji': 1,
#   'huseyin': 2,
#   'rockies': 21,
#   'dung': 2,
#   'gamepanel': 1,
#   'incited': 44,
#   'misbehavior': 21,
#   'disarray': 4,
#   'dmv': 2,
#   'intoxicatingly': 1,
#   'garrone': 2,
#   'garces': 6,
#   'napapabalitang': 2,
#   'elementaries': 2,
#   'pastrana': 1,
#   'gini': 3,
#   'clover': 9,
#   'liveautographs': 1,
#   'mora': 1,
#   'saline': 1,
#   'gripmeister': 1,
#   'neeraj': 2,
#   'wench': 4,
#   'gargantuan': 7,
#   'shemp': 4,
#   'blandishments': 1,
#   'nebbishy': 2,
#   'saliva': 1,
#   'pyke': 2,
#   'idonije': 1,
#   'pulido': 2,
#   'mame': 13,
#   'posen': 2,
#   'futile': 5,
#   'tagliapietra': 2,
#   'quantitive': 1,
#   'sheffer': 1,
#   'kenzie': 3,
#   'englehart': 80,
#   'lex': 1,
#   'ilya': 1,
#   'tilsley': 2,
#   'villarreal': 3,
#   'markey': 5,
#   'goldfish': 1,
#   'saffire': 1,
#   'pasteurizer': 1,
#   'anticheat': 1,
#   'hemmes': 3,
#   'offsider': 3,
#   'carpoolers': 1,
#   'definately': 1,
#   'warburton': 2,
#   'gulliksson': 1,
#   'fenton': 7,
#   'minetta': 2,
#   'vinyasa': 3,
#   'italic': 43,
#   'refueled': 4,
#   'unconsummated': 3,
#   'schtick': 1,
#   'concours': 1,
#   'cinemanila': 4,
#   'ameera': 4,
#   'atsuko': 4,
#   'igaming': 2,
#   'flevvah': 1,
#   'eurobeat': 1,
#   'mytho': 2,
#   'ove': 2,
#   'balachander': 1,
#   'narnian': 3,
#   'pensacola': 5,
#   'fourpiece': 1,
#   'gruene': 1,
#   'laterally': 2,
#   'citic': 2,
#   'stilller': 1,
#   'garabedian': 3,
#   'heike': 40,
#   'stadler': 3,
#   'carmelo': 1,
#   'hiller': 5,
#   'hillhouse': 8,
#   'langoustine': 1,
#   'coz': 1,
#   'helheim': 1,
#   'shingisai': 1,
#   'flavourful': 2,
#   'wiggy': 1,
#   'agonizingly': 1,
#   'farr': 1,
#   'cryogenically': 1,
#   'schaghticoke': 1,
#   'yuvraj': 1,
#   'giersch': 1,
#   'bonneted': 1,
#   'mkt': 1,
#   'danilo': 1,
#   'transcosmos': 1,
#   'inspur': 3,
#   'markosky': 1,
#   'senatorial': 1,
#   'spadina': 8,
#   'girdler': 1,
#   'cardia': 2,
#   'gautama': 2,
#   'toand': 1,
#   'unjustifiably': 3,
#   'caudell': 4,
#   'dispersal': 1,
#   'galler': 1,
#   'moonee': 2,
#   'brillante': 1,
#   'sfgate': 2,
#   'jarum': 1,
#   'dmitriy': 1,
#   'sherrick': 4,
#   'spats': 3,
#   'mitsuda': 1,
#   'hellfor': 174,
#   'manged': 1,
#   'antonina': 2,
#   'stabilisation': 1,
#   'kacey': 1,
#   'phallic': 3,
#   'bravura': 1,
#   'underprivileged': 1,
#   'rampersad': 2,
#   'thulin': 2,
#   'picketers': 2,
#   'kyaw': 7,
#   'film': 14380,
#   'kendall': 98,
#   'character': 1119,
#   'julian': 219,
#   'opposition': 442,
#   'oakland': 53,
#   'silang': 20,
#   'surf': 364,
#   'valley': 827,
#   'farm': 512,
#   'papa': 50,
#   'stringent': 28,
#   'biography': 51,
#   'shut': 247,
#   'mideast': 10,
#   'dive': 334,
#   'flambe': 1,
#   'typically': 226,
#   'intricate': 127,
#   'stomach': 32,
#   'toppings': 7,
#   'catapult': 73,
#   'bench': 28,
#   'filmfare': 1,
#   'matlin': 6,
#   'asher': 5,
#   'parlayed': 17,
#   'kleinberg': 1,
#   'roadside': 65,
#   'globally': 40,
#   'slow': 991,
#   'yearn': 45,
#   'incur': 65,
#   'prevent': 1699,
#   'settlement': 224,
#   'portugal': 16,
#   'suicide': 289,
#   'psa': 8,
#   'gerry': 30,
#   'jar': 68,
#   'gasoline': 43,
#   'accusation': 62,
#   'en': 301,
#   'gillard': 16,
#   'midway': 49,
#   'romantic': 410,
#   'babe': 49,
#   'stove': 10,
#   'extravaganza': 76,
#   'divulge': 24,
#   'juicy': 63,
#   'intact': 24,
#   'genially': 4,
#   'cardboard': 52,
#   'wagner': 84,
#   'boulevard': 276,
#   'karel': 5,
#   'ronnie': 68,
#   'janelle': 2,
#   'fabyan': 18,
#   'extension': 82,
#   'kranj': 4,
#   'nat': 20,
#   'exhort': 3,
#   'conte': 6,
#   'wauconda': 1,
#   'wolfe': 19,
#   'schlitz': 2,
#   'fairbanks': 3,
#   'davie': 4,
#   'shiite': 92,
#   'ira': 34,
#   'disclaimer': 4,
#   'overthrow': 31,
#   'sublimate': 3,
#   'anti': 10,
#   'toughman': 9,
#   'rhode': 34,
#   'providence': 57,
#   'balki': 1,
#   'ebenezer': 6,
#   'constabulary': 2,
#   'workcreated': 3,
#   'bachelet': 2,
#   'perspective': 40,
#   'cyrstal': 1,
#   'una': 6,
#   'interstellar': 33,
#   'eligibility': 26,
#   'servant': 22,
#   'pipeline': 47,
#   'kamper': 1,
#   'impatiently': 3,
#   'tiananmen': 16,
#   'butterfield': 32,
#   'dougal': 1,
#   'borneo': 1,
#   'beyondtheultimate': 1,
#   'webbie': 2,
#   'covert': 26,
#   'vivek': 9,
#   'terra': 79,
#   'shabbo': 2,
#   'demystify': 6,
#   'coral': 44,
#   'kainan': 1,
#   'damashek': 1,
#   'succinctly': 5,
#   'garuda': 5,
#   'electricritters': 1,
#   'boomer': 70,
#   'posthumous': 97,
#   'bereshit': 1,
#   'isabella': 35,
#   'pancit': 2,
#   'spontaneously': 3,
#   'lubricate': 4,
#   'ascend': 43,
#   'basa': 3,
#   'saratoga': 14,
#   ...}}

# %%
def term_frequency(BoW_dict):
    tot_words = sum(BoW_dict.values())
    freq_dict = {word: BoW_dict[word]/tot_words for word in BoW_dict.keys()}
    return freq_dict

# %%
from math import log

def inverse_document_frequency(list_of_dicts):
    tot_docs = len(list_of_dicts)
    words = set([w for w_dict in list_of_dicts for w in w_dict.keys()])
    idf_dict = {word: log(float(tot_docs)/(1.0+ sum([1 for w_dict in list_of_dicts if word in w_dict.keys()]))) for word in words}
    return idf_dict

# %%
def tf_idf(list_of_dicts):
    words = set([w for w_dict in list_of_dicts for w in w_dict.keys()])
    tf_idf_dicts = []
    idfs = inverse_document_frequency(list_of_dicts)
    for w_dict in list_of_dicts:
        w_dict.update({word: 0 for word in words if word not in w_dict.keys()})
        tf = term_frequency(w_dict)
        tf_idf_dicts.append({word: tf[word]*idfs[word] for word in words})
    return tf_idf_dicts

# %%
list_of_word_dicts = [category_word_counts_dict[category] for category in categories]
tf_idf_by_category_list = tf_idf(list_of_word_dicts)
tf_idf_by_category_dict = {c: tf_dict for c, tf_dict in zip(categories, tf_idf_by_category_list)}

# %%
tf_idf_by_category_dict
# Out:
# {'politics': {'treason': 0.0,
#   'bayartsaihan': 0.0,
#   'lundeen': 1.3075067388148017e-07,
#   'addiction': -4.200024191105487e-07,
#   'orac': 0.0,
#   'cimo': 1.1726666115596369e-07,
#   'pingfederate': 0.0,
#   'bartlett': -3.0333508046872964e-06,
#   'realignment': 0.0,
#   'txi': 0.0,
#   'curbside': 0.0,
#   'subrogated': 1.1726666115596369e-07,
#   'merger': -1.166673386418191e-06,
#   'yeast': 0.0,
#   'beltre': 0.0,
#   'futureheads': 0.0,
#   'roadcasting': 0.0,
#   'attract': -4.246691126562215e-05,
#   'jaipuria': 0.0,
#   'yeng': 0.0,
#   'propulsion': 0.0,
#   'creditable': 0.0,
#   'mazzaro': 0.0,
#   'smo': 0.0,
#   'navigator': 0.0,
#   'gutless': 0.0,
#   'unknownst': 0.0,
#   'thurbert': 0.0,
#   'silas': 0.0,
#   'journalist': -4.9000282229564025e-06,
#   'cmss': 0.0,
#   'namedto': 0.0,
#   'allium': 0.0,
#   'nasa': -6.066701609374593e-07,
#   'jdm': 0.0,
#   'bisphenol': 0.0,
#   'xmlhttp': 0.0,
#   'tompetty': 0.0,
#   'aurorae': 0.0,
#   'wilmerhale': 5.863333057798185e-07,
#   'barrymore': 0.0,
#   'spiderland': 0.0,
#   'benigni': 0.0,
#   'ronald': -4.3166915297473064e-06,
#   'casahl': 0.0,
#   'allmon': 1.1726666115596369e-07,
#   'pnds': 0.0,
#   'dodea': 1.1726666115596369e-07,
#   'masaharu': 0.0,
#   'aleier': 0.0,
#   'ethicists': 0.0,
#   'ulrich': 0.0,
#   'portrait': -1.0966729832330994e-06,
#   'segue': 0.0,
#   'oveta': 1.1726666115596369e-07,
#   'ivanchuk': 0.0,
#   'xoma': 0.0,
#   'filofax': 0.0,
#   'googleearth': 1.1726666115596369e-07,
#   'snowmelt': 0.0,
#   'veridigm': 0.0,
#   'radioed': 0.0,
#   'androgenic': 0.0,
#   'automobile': -7.70004435036006e-07,
#   'minutely': 0.0,
#   'arxiv': 0.0,
#   'hiroshige': 2.3453332231192738e-07,
#   'snowcapped': 0.0,
#   'grecian': 0.0,
#   'berresse': 0.0,
#   'cafeteria': -2.3333467728363818e-07,
#   'audioslave': 0.0,
#   'keeble': 0.0,
#   'vinnee': 0.0,
#   'jumblatt': 7.035999669357821e-07,
#   'traipse': 2.8557856486859775e-08,
#   'gx': 0.0,
#   'dmitri': 1.3075067388148017e-07,
#   'bracewell': 1.3075067388148017e-07,
#   'excitatory': 0.0,
#   'prabhadevi': 0.0,
#   'foetal': 0.0,
#   'rosso': 0.0,
#   'daim': 1.4278928243429887e-07,
#   'perloff': 0.0,
#   'goc': 0.0,
#   'glutathione': 0.0,
#   'beiden': 0.0,
#   'prix': 0.0,
#   'defenceless': 0.0,
#   'misse': 0.0,
#   'renfrew': 0.0,
#   'allowspecialization': 0.0,
#   'luxe': 0.0,
#   'sn': 0.0,
#   'overdo': 2.8557856486859775e-08,
#   'thermistor': 0.0,
#   'djin': 0.0,
#   'analyze': -2.8700165305887494e-06,
#   'cohabitation': 0.0,
#   'triggerman': 5.863333057798185e-07,
#   'mchattie': 0.0,
#   'sodsri': 2.3453332231192738e-07,
#   'tonix': 0.0,
#   'exxonmobil': 5.711571297371955e-08,
#   'exuviae': 0.0,
#   'finnegan': 0.0,
#   'sohna': 0.0,
#   'melrose': 0.0,
#   'demilitarization': 0.0,
#   'selhurst': 0.0,
#   'deciphers': 0.0,
#   'freewheeling': 0.0,
#   'intech': 0.0,
#   'hilden': 0.0,
#   'kmri': 0.0,
#   'systemc': 0.0,
#   'dowe': 5.863333057798185e-07,
#   'voce': 0.0,
#   'viking': -9.333387091345527e-08,
#   'shinzo': -4.4333588683891255e-07,
#   'magnitude': -1.306674192788374e-06,
#   'chiruthaigal': 0.0,
#   'coy': 0.0,
#   'populist': 0.0,
#   'obstetrics': 0.0,
#   'inactivity': 0.0,
#   'earthworm': 0.0,
#   'elm': 5.711571297371955e-08,
#   'sunol': 0.0,
#   'rathod': 0.0,
#   'liters': -1.1666733864181909e-07,
#   'reynold': 0.0,
#   'multichannelnews': 0.0,
#   'barren': 0.0,
#   'mutedly': 0.0,
#   'cross': -1.5376755232991755e-05,
#   'calty': 0.0,
#   'reyvateils': 0.0,
#   'edition': -3.9666895138218494e-07,
#   'dss': 0.0,
#   'rucker': 2.8557856486859775e-08,
#   'medvinskaya': 0.0,
#   'soweto': 6.537533694074009e-08,
#   'creenergy': 0.0,
#   'detulio': 1.1726666115596369e-07,
#   'intracluster': 0.0,
#   'schlitze': 0.0,
#   'fourier': 0.0,
#   'khazaie': 1.1726666115596369e-07,
#   'hamid': 0.0,
#   'medimmune': 0.0,
#   'footner': 0.0,
#   'soleduck': 0.0,
#   'framerates': 0.0,
#   'lusk': 0.0,
#   'mavado': 0.0,
#   'poti': 1.3075067388148017e-07,
#   'kamvar': 0.0,
#   'transnational': -4.900028222956403e-07,
#   'bainca': 0.0,
#   'cruisetour': 0.0,
#   'deepika': 0.0,
#   'biggart': 1.1726666115596369e-07,
#   'securum': 1.1726666115596369e-07,
#   'solemnity': 0.0,
#   'openmind': 0.0,
#   'ehsan': 0.0,
#   'zaglebie': 0.0,
#   'woodchip': 0.0,
#   'exterior': -3.0333508046872967e-07,
#   'pascazi': 0.0,
#   'appakova': 0.0,
#   'caipirinhas': 0.0,
#   'herringbone': 0.0,
#   'henrion': 0.0,
#   'rescan': 0.0,
#   'extender': 2.8557856486859775e-08,
#   'saartjie': 0.0,
#   'behavioral': -4.200024191105487e-07,
#   'marlin': 0.0,
#   'monetise': 0.0,
#   'rasta': 2.6150134776296034e-07,
#   'porsche': 0.0,
#   'ganda': 1.3075067388148017e-07,
#   'quidditch': 0.0,
#   'brindle': 1.3075067388148017e-07,
#   'kingsford': 8.567356946057933e-08,
#   'heith': 6.537533694074009e-08,
#   'electromigration': 0.0,
#   'neuromuscular': 0.0,
#   'deviled': 0.0,
#   'wagnerian': 0.0,
#   'matthea': 0.0,
#   'sbt': 0.0,
#   'prien': 1.1726666115596369e-07,
#   'ruell': 0.0,
#   'logi': 0.0,
#   'acessory': 0.0,
#   'harborfields': 2.3453332231192738e-07,
#   'vendetta': 0.0,
#   'oxnam': 0.0,
#   'kordestan': 4.6906664462385475e-07,
#   'gamekit': 0.0,
#   'chinese': -1.8363439102222326e-05,
#   'disengage': 2.6150134776296034e-07,
#   'ignornat': 1.1726666115596369e-07,
#   'bharatnatyam': 0.0,
#   'kambon': 0.0,
#   'anat': 0.0,
#   'dawei': 6.537533694074009e-08,
#   'consol': 0.0,
#   'italcementi': 1.1726666115596369e-07,
#   'ta': -2.3333467728363818e-08,
#   'drobo': 0.0,
#   'lambaste': 2.8557856486859775e-08,
#   'kosmotras': 0.0,
#   'thioke': 0.0,
#   'gouri': 0.0,
#   'tizzy': 0.0,
#   'michelob': 0.0,
#   'maryland': -4.410025400660762e-06,
#   'blithe': 0.0,
#   'ammar': 4.854835602766162e-07,
#   'diario': 0.0,
#   'maathai': 0.0,
#   'coverboy': 0.0,
#   'madius': 3.5179998346789105e-07,
#   'epip': 0.0,
#   'nazko': 0.0,
#   'betters': 0.0,
#   'qtv': 0.0,
#   'mazuz': 1.1726666115596369e-07,
#   'ajavon': 0.0,
#   'jabber': 0.0,
#   'dereje': 2.3453332231192738e-07,
#   'dern': 0.0,
#   'mathewson': 0.0,
#   'vigilantism': 0.0,
#   'baton': -3.616687497896392e-06,
#   'camilla': 0.0,
#   'ornamental': 0.0,
#   'specialty': -1.8900108859974693e-06,
#   'creative': -8.633383059494612e-07,
#   'msms': 1.1726666115596369e-07,
#   'arbuckle': 0.0,
#   'redpoint': 0.0,
#   'zysblat': 0.0,
#   'saucedo': 0.0,
#   'grammy': 0.0,
#   'dorsey': 1.3075067388148017e-07,
#   'week': -8.93905148673618e-05,
#   'ataturk': 1.1726666115596369e-07,
#   'romatic': 0.0,
#   'coppergate': 0.0,
#   'irresponsible': -8.866717736778251e-07,
#   'codex': 0.0,
#   'sartin': 0.0,
#   'hiura': 0.0,
#   'leprosarium': 0.0,
#   'loewe': 0.0,
#   'willett': 1.372882075755542e-06,
#   'taplejung': 0.0,
#   'embarrassing': -2.473347579206565e-06,
#   'bloopers': 0.0,
#   'linecard': 0.0,
#   'lahat': 0.0,
#   'legume': -2.3333467728363818e-08,
#   'roberta': 2.8557856486859775e-08,
#   'pixeljunk': 0.0,
#   'haaren': 0.0,
#   'herein': 0.0,
#   'lenneth': 0.0,
#   'insulation': -2.56668145012002e-07,
#   'unaccountable': 1.142314259474391e-07,
#   'kampyo': 0.0,
#   'undeserved': 0.0,
#   'campoz': 0.0,
#   'estelle': 2.8557856486859775e-08,
#   'awry': 0.0,
#   'weckerle': 0.0,
#   'pinyons': 0.0,
#   'dinovo': 0.0,
#   'polymath': 0.0,
#   'guyana': 2.8557856486859775e-08,
#   'gazpacho': 0.0,
#   'ldc': 0.0,
#   'inclues': 0.0,
#   'glogowski': 2.3453332231192738e-07,
#   'pixsense': 0.0,
#   'humm': 0.0,
#   'junho': 1.1726666115596369e-07,
#   'caesarea': 0.0,
#   'stackless': 0.0,
#   'masaoka': 0.0,
#   'crewmember': 0.0,
#   'lothians': 1.9612601082222028e-07,
#   'robaina': 2.3453332231192738e-07,
#   'henrico': 6.537533694074009e-08,
#   'aditya': 0.0,
#   'plaxce': 0.0,
#   'definition': -4.900028222956403e-07,
#   'kahaulelio': 0.0,
#   'next': -7.121374350696637e-05,
#   'elven': 0.0,
#   'heinous': -9.333387091345527e-08,
#   'collette': 0.0,
#   'stablemate': 0.0,
#   'aryeh': 0.0,
#   'ruc': 9.381332892477095e-07,
#   'marsh': -2.800016127403658e-07,
#   'vrm': 0.0,
#   'valenti': 0.0,
#   'segregationist': 3.2687668470370043e-07,
#   'bock': 0.0,
#   'voyageurs': 0.0,
#   'silverado': 0.0,
#   'gator': 0.0,
#   'cholesterol': -1.6333427409854674e-07,
#   'ludwigshafen': 1.3075067388148017e-07,
#   'dupri': 0.0,
#   'underspend': 3.5179998346789105e-07,
#   'netstore': 0.0,
#   'backload': 0.0,
#   'isaak': 0.0,
#   'verbruggen': 0.0,
#   'princia': 0.0,
#   'donnington': 0.0,
#   'kabylie': 4.6906664462385475e-07,
#   'unevolved': 0.0,
#   'warlick': 0.0,
#   'librettist': 0.0,
#   'posen': 0.0,
#   'robillard': 0.0,
#   'batsto': 0.0,
#   'hadless': 0.0,
#   'ragusa': 0.0,
#   'desalination': 0.0,
#   'impossibility': 0.0,
#   'impute': 0.0,
#   'readsoft': 0.0,
#   'rsalte': 0.0,
#   'resent': 0.0,
#   'regulation': -1.033672620366517e-05,
#   'cinemedia': 0.0,
#   'blend': -1.166673386418191e-06,
#   'acclamation': 5.230026955259207e-07,
#   'safeway': 0.0,
#   'banoo': 0.0,
#   'overselling': 0.0,
#   'tif': 5.14041416763476e-07,
#   'flyhalf': 0.0,
#   'sustainability': -7.70004435036006e-07,
#   'unflashy': 0.0,
#   'produce': -4.3656918119768705e-05,
#   'halili': 0.0,
#   'ince': 0.0,
#   'horacio': 0.0,
#   'mayberry': 3.9225202164444057e-07,
#   'cummins': -9.333387091345527e-08,
#   'habitue': 0.0,
#   'showiest': 0.0,
#   'karamanlis': 0.0,
#   'dicko': 0.0,
#   'extrajudicial': 3.9225202164444057e-07,
#   'tatsuo': 0.0,
#   'retransmit': 0.0,
#   'redshift': 0.0,
#   'constructive': 0.0,
#   'shallot': 0.0,
#   'pray': -4.200024191105487e-07,
#   'presimulation': 0.0,
#   'godspell': 0.0,
#   'fontlab': 0.0,
#   'glycerin': 0.0,
#   'aptly': 0.0,
#   'fonterra': 1.7134713892115866e-07,
#   'wiesenthal': 1.9612601082222028e-07,
#   'tel': -9.333387091345527e-07,
#   'decryption': 0.0,
#   'morayfield': 0.0,
#   'brecker': 0.0,
#   'dishslayer': 0.0,
#   'bastian': 0.0,
#   'socceroos': 1.3075067388148017e-07,
#   'bulldozer': 8.567356946057933e-08,
#   'gareth': -4.6666935456727636e-08,
#   'edyta': 0.0,
#   'acorn': -8.633383059494612e-07,
#   'manitoulin': 0.0,
#   'yelm': 0.0,
#   'km': -3.266685481970935e-07,
#   'troop': -4.802027658497274e-05,
#   'oilseed': 0.0,
#   'makhtar': 1.1726666115596369e-07,
#   'purmal': 0.0,
#   'sunley': 0.0,
#   'itacg': 2.3453332231192738e-07,
#   'spinned': 0.0,
#   'internist': 0.0,
#   'stabbings': 0.0,
#   'siem': 0.0,
#   'bursary': 1.4278928243429887e-07,
#   'gaussianity': 0.0,
#   'thorp': 0.0,
#   'opos': 0.0,
#   'lenient': 0.0,
#   'nozick': 0.0,
#   'fillip': 2.8557856486859775e-08,
#   'nina': -9.333387091345527e-08,
#   'conflate': 0.0,
#   'anglican': 0.0,
#   'yadkin': 6.537533694074009e-08,
#   'equiment': 0.0,
#   'dynamin': 0.0,
#   'adegokeorganizers': 0.0,
#   'endeavored': 0.0,
#   'tdk': 0.0,
#   'bot': 0.0,
#   'crackle': 0.0,
#   'laureen': 0.0,
#   'wolfblock': 3.5179998346789105e-07,
#   'shatalin': 0.0,
#   'snakeskin': 2.3453332231192738e-07,
#   'treacy': 1.3075067388148017e-07,
#   'firebomb': 1.3075067388148017e-07,
#   'invacare': 0.0,
#   'harpp': 1.1726666115596369e-07,
#   'hermia': 0.0,
#   'boroujerdi': 2.3453332231192738e-07,
#   'rosenblum': 0.0,
#   'istart': 0.0,
#   'qaraghuli': 1.1726666115596369e-07,
#   'centreman': 0.0,
#   'marvin': -4.6666935456727636e-08,
#   'dela': 0.0,
#   'clockspeed': 0.0,
#   'gozo': 0.0,
#   'pixielike': 0.0,
#   'supreses': 2.3453332231192738e-07,
#   'rubins': 0.0,
#   'sholom': 0.0,
#   'olea': 0.0,
#   'farzad': 0.0,
#   'uracan': 0.0,
#   'kiefer': 0.0,
#   'irrigate': -1.8666774182691054e-07,
#   'wtttv': 0.0,
#   'dawood': 0.0,
#   'himatangi': 0.0,
#   'embark': -1.656676208713831e-06,
#   'puri': 0.0,
#   'om': 0.0,
#   'buckcherry': 0.0,
#   'bray': -1.400008063701829e-07,
#   'scurato': 0.0,
#   'lldpe': 0.0,
#   'yesteday': 1.1726666115596369e-07,
#   'gonzales': -4.363358465204034e-06,
#   'iroquois': 5.711571297371955e-08,
#   'margaux': 0.0,
#   'andha': 0.0,
#   'slithery': 0.0,
#   'flaw': -1.0966729832330994e-06,
#   'nihon': 0.0,
#   'sigman': 1.1726666115596369e-07,
#   'pram': 0.0,
#   'nachtmystium': 0.0,
#   'maxian': 0.0,
#   'mircosoft': 0.0,
#   'refresher': 0.0,
#   'hilary': -2.3333467728363818e-07,
#   'betts': 8.567356946057933e-08,
#   'ebo': 0.0,
#   'susan': -2.310013305108018e-06,
#   'sciac': 0.0,
#   'perpendicularly': 0.0,
#   'honcho': 0.0,
#   'embarassment': 1.1726666115596369e-07,
#   'darigold': 1.1726666115596369e-07,
#   'irrestible': 0.0,
#   'vito': 0.0,
#   'stempeutics': 0.0,
#   'saprang': 2.3453332231192738e-07,
#   'biohazard': 0.0,
#   'infoworld': 0.0,
#   'probibits': 0.0,
#   'kellyn': 0.0,
#   'maile': 2.3453332231192738e-07,
#   'hitchcock': 0.0,
#   'boepd': 0.0,
#   'pistola': 0.0,
#   'stancavage': 0.0,
#   'lockdown': 0.0,
#   'bogenschutz': 1.1726666115596369e-07,
#   'avelino': 0.0,
#   'nclba': 0.0,
#   'appignanesi': 0.0,
#   'feldmayer': 0.0,
#   'crap': 0.0,
#   'zelda': 0.0,
#   'deficiency': -2.3333467728363818e-07,
#   'murder': -8.00337943082879e-06,
#   'collooney': 1.1726666115596369e-07,
#   'tunneling': 0.0,
#   'parramatta': 0.0,
#   'pbdes': 0.0,
#   'zyvox': 0.0,
#   'strand': -1.6333427409854675e-06,
#   'karsten': 0.0,
#   'talmud': 0.0,
#   'teterboro': 2.6150134776296034e-07,
#   'visavis': 0.0,
#   'macedon': 0.0,
#   'ichat': 0.0,
#   'mandak': 0.0,
#   'bhadrakumar': 1.1726666115596369e-07,
#   'levyatan': 0.0,
#   'insult': -1.4000080637018291e-06,
#   'zulte': 0.0,
#   'bristle': 0.0,
#   'comres': 1.1726666115596369e-07,
#   'langa': 0.0,
#   'mirvat': 0.0,
#   'jehovah': 0.0,
#   'aiglx': 0.0,
#   'maliciously': 1.9990499540801844e-07,
#   'burgh': 1.3075067388148017e-07,
#   'bhumibol': 3.9225202164444057e-07,
#   'attune': -3.0333508046872967e-07,
#   'ogerman': 0.0,
#   'lasalle': 1.7134713892115866e-07,
#   'hyperinflation': 7.035999669357821e-07,
#   'hydrochloride': 0.0,
#   'utterance': 0.0,
#   'naxos': 0.0,
#   'ustream': 0.0,
#   'qabalan': 1.1726666115596369e-07,
#   'trustedplaces': 0.0,
#   'burring': 0.0,
#   'unsheathing': 0.0,
#   'dft': 4.5762735858518065e-07,
#   'symposium': -7.000040318509145e-08,
#   'dhanush': 0.0,
#   'naqshbandi': 3.5179998346789105e-07,
#   'shoot': -1.197006894465064e-05,
#   'treadmill': 0.0,
#   'okuda': 0.0,
#   'vlx': 0.0,
#   'seni': 1.3075067388148017e-07,
#   'quarterbacked': 2.3453332231192738e-07,
#   'sportsmanship': 0.0,
#   'rollerskate': 0.0,
#   'baskins': 1.1726666115596369e-07,
#   'vestas': 0.0,
#   'podemos': 7.035999669357821e-07,
#   'synopsis': 0.0,
#   'abney': 6.537533694074009e-08,
#   'timeless': 0.0,
#   'corn': -1.026672580048008e-06,
#   'macbu': 0.0,
#   'sajdak': 0.0,
#   'flea': -1.1666733864181909e-07,
#   'guard': -1.766343507037141e-05,
#   'nicealarm': 0.0,
#   'innopath': 0.0,
#   'avuncular': 0.0,
#   'cocula': 0.0,
#   'mandir': 0.0,
#   'claypool': 0.0,
#   'loehr': 0.0,
#   'marketising': 4.6906664462385475e-07,
#   'let': -3.752021610720902e-05,
#   'arraytrack': 0.0,
#   'naslund': 0.0,
#   'reporter': -1.6706762893508493e-05,
#   'pedernales': 0.0,
#   'donnelley': 0.0,
#   'econ': 5.883780324666608e-07,
#   'prospectivity': 0.0,
#   'fiftysomething': 0.0,
#   'metabolically': 0.0,
#   'caner': 0.0,
#   'verisign': 0.0,
#   'nintendogs': 0.0,
#   'serologic': 0.0,
#   'constructively': 8.208666280917459e-07,
#   'mahina': 0.0,
#   'cuthbert': 5.711571297371955e-08,
#   'mesopotamia': 0.0,
#   'terso': 0.0,
#   'unmined': 0.0,
#   'sell': -3.292352296472135e-05,
#   'magmatic': 0.0,
#   'telly': 0.0,
#   'dum': 1.3075067388148017e-07,
#   'ferrostaal': 0.0,
#   'minnelli': 0.0,
#   'talisman': 0.0,
#   'wadmalaw': 0.0,
#   'broadcaster': -5.366697577523679e-07,
#   'phosphatase': 0.0,
#   'extralegal': 0.0,
#   'opeth': 0.0,
#   'bai': 0.0,
#   'proffer': -4.200024191105487e-07,
#   'neptune': 8.567356946057933e-08,
#   'ifct': 1.1726666115596369e-07,
#   'kishkinta': 0.0,
#   'inexpense': 0.0,
#   'gratuity': 0.0,
#   'gosney': 0.0,
#   'iness': 0.0,
#   'ketke': 0.0,
#   'viroporins': 0.0,
#   'gor': 0.0,
#   'tanyard': 2.3453332231192738e-07,
#   'mailenable': 0.0,
#   'microholdings': 0.0,
#   'chipbond': 0.0,
#   'zhuang': 0.0,
#   'brygg': 0.0,
#   'yashvir': 0.0,
#   'pegritz': 0.0,
#   'yashomati': 0.0,
#   'degreed': 0.0,
#   'mobilinux': 0.0,
#   'cloepfil': 0.0,
#   'franjieh': 5.230026955259207e-07,
#   'yaki': 0.0,
#   'aichi': 0.0,
#   'adderall': 0.0,
#   'anatomist': 0.0,
#   'freespire': 0.0,
#   'klitschko': 0.0,
#   'tva': 1.142314259474391e-07,
#   'eetimes': 0.0,
#   'ulduar': 0.0,
#   'topix': 0.0,
#   'kennebec': 0.0,
#   'hoolock': 0.0,
#   'multigeographic': 0.0,
#   'cambias': 0.0,
#   'sudhakar': 0.0,
#   'wenye': 0.0,
#   'lactational': 6.537533694074009e-08,
#   'gimmicky': 0.0,
#   'batu': 1.7134713892115866e-07,
#   'maiwand': 1.1726666115596369e-07,
#   'fazakerley': 0.0,
#   'godtube': 0.0,
#   'jeff': -1.960011289182561e-06,
#   'divert': -2.473347579206565e-06,
#   'sanitising': 0.0,
#   'asiad': 0.0,
#   'baratta': 4.6906664462385475e-07,
#   'chancel': 0.0,
#   'microarrays': 2.8557856486859775e-08,
#   'moraine': 0.0,
#   'toktogonova': 1.1726666115596369e-07,
#   'colly': 6.537533694074009e-08,
#   'dixon': 0.0,
#   'capacity': -3.0333508046872964e-06,
#   'vaiko': 0.0,
#   'gantry': 0.0,
#   'liaohe': 0.0,
#   'pieper': 6.537533694074009e-08,
#   'daria': 0.0,
#   'encysive': 0.0,
#   'indochina': 1.3075067388148017e-07,
#   'netevents': 0.0,
#   'ner': 0.0,
#   'caserta': 1.3075067388148017e-07,
#   'suddenly': -2.0066782246392884e-06,
#   'pentium': 0.0,
#   'nobuyoshi': 0.0,
#   'gratifyingly': 0.0,
#   'briony': 1.3075067388148017e-07,
#   'ancestry': -2.3333467728363818e-08,
#   'rlc': 0.0,
#   'thiboust': 0.0,
#   'docusphere': 0.0,
#   'maori': -1.3766745959734653e-06,
#   'monarchical': 1.1726666115596369e-07,
#   'ettinger': 1.1726666115596369e-07,
#   'stickball': 0.0,
#   'edwards': -2.0626785471873618e-05,
#   'simpligrid': 0.0,
#   'berggruen': 0.0,
#   'warble': 0.0,
#   'der': -2.56668145012002e-07,
#   'positivity': 0.0,
#   'fixation': -2.3333467728363818e-08,
#   'poyner': 6.537533694074009e-08,
#   'mundo': 0.0,
#   'teheran': 0.0,
#   'beehive': 0.0,
#   'janasakthi': 0.0,
#   'rickroll': 0.0,
#   'intermingle': 0.0,
#   'enterix': 0.0,
#   'outstrip': -3.733354836538211e-07,
#   'mair': 1.142314259474391e-07,
#   'kittyhawk': 0.0,
#   'comcast': 0.0,
#   'artiste': 0.0,
#   'pinakapambatang': 0.0,
#   'crevasses': 0.0,
#   'braggart': 0.0,
#   'irate': 0.0,
#   'jaroslav': 0.0,
#   'departure': -2.8000161274036582e-06,
#   'indigestion': 0.0,
#   'florentine': 0.0,
#   'speers': 0.0,
#   'gorgeous': -1.1666733864181909e-07,
#   'treneman': 1.1726666115596369e-07,
#   'consuegra': 0.0,
#   'hymen': 0.0,
#   'gleason': 8.567356946057933e-08,
#   'portelli': 0.0,
#   'maudlin': 0.0,
#   'dinarello': 0.0,
#   'jakim': 3.5179998346789105e-07,
#   'makakatrabaho': 0.0,
#   'randalls': 0.0,
#   'mannie': 0.0,
#   'borderless': 1.1726666115596369e-07,
#   'apg': 0.0,
#   'reserpine': 0.0,
#   'eilers': 0.0,
#   'lieberman': 0.0,
#   'lorayne': 0.0,
#   'ravichandran': 0.0,
#   'platform': -8.236714108112428e-06,
#   'curuenavuli': 0.0,
#   'intelligently': 0.0,
#   'adenopathy': 0.0,
#   'benja': 0.0,
#   'christchuch': 0.0,
#   'misinformation': -1.400008063701829e-07,
#   'melanie': 0.0,
#   'emacs': 0.0,
#   'inadvertent': -4.200024191105487e-07,
#   'googlemaps': 0.0,
#   'torino': 0.0,
#   'gamesradar': 0.0,
#   'rajput': 0.0,
#   'infiniteight': 0.0,
#   'ortman': 4.6906664462385475e-07,
#   'indiewire': 0.0,
#   'touchscreen': 0.0,
#   'woitasek': 0.0,
#   'amazonian': 0.0,
#   'tropic': 0.0,
#   'blindingly': 6.537533694074009e-08,
#   'rtts': 0.0,
#   'voyager': 0.0,
#   'lime': 0.0,
#   'cubavera': 0.0,
#   'devise': -2.2166794341945627e-06,
#   'nonprescription': 0.0,
#   'maryo': 0.0,
#   'anthrax': 0.0,
#   'havering': 1.2899332727156007e-06,
#   'ummeed': 0.0,
#   'jolty': 0.0,
#   'tuong': 0.0,
#   'hibbs': 0.0,
#   'topbraid': 0.0,
#   'milgram': 0.0,
#   'diy': -2.3333467728363818e-08,
#   'wahiawa': 2.3453332231192738e-07,
#   'million': -0.00013958080395107237,
#   'hrp': 0.0,
#   'iconography': 0.0,
#   'banco': 0.0,
#   'brinksmanship': 0.0,
#   'callea': 0.0,
#   'freeform': 0.0,
#   'lapiga': 0.0,
#   'meeks': 5.883780324666608e-07,
#   'immunocompatent': 0.0,
#   'hazily': 0.0,
#   'alpenfest': 0.0,
#   'warily': 0.0,
#   'schlumberger': 0.0,
#   'traktor': 0.0,
#   'norwegian': -3.266685481970935e-07,
#   'panyu': 0.0,
#   'chiba': 0.0,
#   'inactivate': 0.0,
#   'durability': -2.1000120955527435e-07,
#   'surinder': 0.0,
#   'json': 0.0,
#   'grumpy': 5.711571297371955e-08,
#   'srimuang': 1.1726666115596369e-07,
#   'slipstitch': 0.0,
#   'saftoiu': 3.5179998346789105e-07,
#   'hwpen': 0.0,
#   'hozan': 0.0,
#   'printable': 0.0,
#   'distributary': 0.0,
#   'clouseau': 0.0,
#   'netvanta': 0.0,
#   'concepcion': 0.0,
#   'manacle': 0.0,
#   'hyaluronic': 0.0,
#   'aplindore': 0.0,
#   'tregs': 0.0,
#   'brentano': 0.0,
#   'pinnarayi': 0.0,
#   'neeta': 0.0,
#   'riaz': 4.6906664462385475e-07,
#   'bofors': 0.0,
#   'capitalist': -4.4333588683891255e-07,
#   'rotation': -2.1000120955527435e-07,
#   'evangelize': 0.0,
#   'schefter': 0.0,
#   'ccp': 0.0,
#   'phosphorous': 0.0,
#   'manolo': 0.0,
#   'menu': -4.900028222956403e-07,
#   'vcenter': 0.0,
#   'touchpad': 0.0,
#   'cheeburger': 0.0,
#   'unsightly': 0.0,
#   'botnet': 0.0,
#   'iab': 0.0,
#   'fathomless': 0.0,
#   'trainwreck': 0.0,
#   'wabo': 0.0,
#   'kong': -1.4466749991585568e-06,
#   'nathaniel': 8.567356946057933e-08,
#   'ruksun': 0.0,
#   'mcquivey': 0.0,
#   'colao': 0.0,
#   'newshour': 5.230026955259207e-07,
#   'acca': 0.0,
#   'jodhpur': 0.0,
#   'unreturned': 0.0,
#   'chessplaying': 0.0,
#   'outcompete': 0.0,
#   'inductive': 0.0,
#   'tracklist': 0.0,
#   'korban': 0.0,
#   'upmo': 0.0,
#   'documenta': 0.0,
#   'bog': -1.2600072573316462e-06,
#   'neustel': 0.0,
#   'omneon': 0.0,
#   'nemhiripiri': 0.0,
#   'tameika': 5.863333057798185e-07,
#   'machinist': 5.711571297371955e-08,
#   'dariya': 0.0,
#   'workbook': 6.537533694074009e-08,
#   'noice': 0.0,
#   'pivotal': 0.0,
#   'tarry': 0.0,
#   'hotwire': 0.0,
#   'toxicants': 0.0,
#   'lyne': 0.0,
#   'sharqiyah': 2.3453332231192738e-07,
#   'nema': 0.0,
#   'stn': 0.0,
#   'mcbain': 0.0,
#   'deftones': 0.0,
#   'outernational': 0.0,
#   'slasher': 0.0,
#   'lifestyle': -6.300036286658231e-07,
#   'marketable': 0.0,
#   'yesterdayover': 1.1726666115596369e-07,
#   'reconven': 5.711571297371955e-08,
#   'maul': -2.3333467728363818e-07,
#   'powerdsine': 0.0,
#   'insularisation': 0.0,
#   'marzuq': 0.0,
#   'sansho': 0.0,
#   'harass': -1.1433399186898271e-06,
#   'durang': 0.0,
#   'mailroom': 5.711571297371955e-08,
#   'silkcentral': 0.0,
#   'cra': 1.4278928243429887e-07,
#   'hdv': 0.0,
#   'extension': -3.3600193528843896e-06,
#   'ingestion': 0.0,
#   'gatland': 0.0,
#   'misbegotten': 0.0,
#   'outside': -4.561692940895127e-05,
#   'tichenor': 0.0,
#   'citizenry': 0.0,
#   'memorabilia': 5.711571297371955e-08,
#   'guinn': 6.537533694074009e-08,
#   'allard': -1.400008063701829e-07,
#   'upmc': 0.0,
#   'sublimely': 0.0,
#   'sharifnia': 0.0,
#   'pfds': 0.0,
#   'frock': 0.0,
#   'blackmailer': 0.0,
#   'racialised': 0.0,
#   'tae': 0.0,
#   'yeltsin': 7.035999669357821e-07,
#   'childabuse': 0.0,
#   'bourdelle': 0.0,
#   'saluja': 0.0,
#   'noncorporate': 0.0,
#   'clerical': 0.0,
#   'urairat': 1.1726666115596369e-07,
#   'netvigil': 0.0,
#   'immerse': -4.6666935456727636e-08,
#   'empathise': 0.0,
#   'abell': 0.0,
#   'parasitic': -2.3333467728363818e-08,
#   'conceptual': -4.4333588683891255e-07,
#   'theosophical': 0.0,
#   'performicssearch': 0.0,
#   'medisec': 0.0,
#   'lonnquest': 1.1726666115596369e-07,
#   'powerbroker': 2.6150134776296034e-07,
#   'hr': -6.066701609374593e-07,
#   'invariably': -1.6333427409854674e-07,
#   'pinout': 0.0,
#   'valerie': -1.656676208713831e-06,
#   'escapade': 0.0,
#   'lexi': 0.0,
#   'spot': -6.113368544831321e-06,
#   'klebold': 0.0,
#   'peete': 0.0,
#   'jhumpa': 0.0,
#   'padmasree': 0.0,
#   'reconsider': -4.666693545672764e-06,
#   'jakovina': 0.0,
#   'koodankulam': 0.0,
#   'flac': 0.0,
#   'hurlbirt': 0.0,
#   'troublshooting': 0.0,
#   'hospitalist': 0.0,
#   'sheehan': 2.6150134776296034e-07,
#   'vine': 0.0,
#   'britian': 0.0,
#   'emoney': 0.0,
#   'hackler': 2.3453332231192738e-07,
#   'lavaca': 2.3453332231192738e-07,
#   'tyramine': 0.0,
#   'udhav': 0.0,
#   'osdl': 0.0,
#   'masonry': 6.537533694074009e-08,
#   'nonnegotiable': 0.0,
#   'tibotec': 0.0,
#   'mimetic': 0.0,
#   'unmoved': 4.5762735858518065e-07,
#   'serialization': 0.0,
#   'doszip': 0.0,
#   'worldweaver': 0.0,
#   'ghteen': 0.0,
#   'baabda': 1.3075067388148017e-07,
#   'cutter': 3.998099908160369e-07,
#   'tshwane': 0.0,
#   'opsware': 0.0,
#   'gad': 0.0,
#   'orthofix': 0.0,
#   'gpt': 0.0,
#   'myoblast': 0.0,
#   'marine': -2.7743493129024582e-05,
#   'pronged': 0.0,
#   'acclimate': 0.0,
#   'gloc': 0.0,
#   'sibanda': 1.1726666115596369e-07,
#   'grandparent': -4.6666935456727636e-08,
#   'cipla': 0.0,
#   'pevion': 0.0,
#   'binj': 0.0,
#   'parekura': 0.0,
#   'castelli': 0.0,
#   'plot': -4.736693948857855e-06,
#   'malign': 0.0,
#   'elektronik': 0.0,
#   'lesley': -4.6666935456727636e-08,
#   'rivetting': 0.0,
#   'kakihara': 0.0,
#   'sideswipe': 0.0,
#   'vaporetto': 0.0,
#   'baig': 2.8557856486859775e-08,
#   'partnerfirst': 0.0,
#   'js': 0.0,
#   'minsheng': 0.0,
#   'pakistani': -8.026712898557153e-06,
#   'softballs': 2.3453332231192738e-07,
#   'mancini': 0.0,
#   'saqr': 1.1726666115596369e-07,
#   'yorkdale': 0.0,
#   'violat': 0.0,
#   'contributory': 6.537533694074009e-08,
#   'mediasense': 0.0,
#   'taiex': 0.0,
#   'ruk': 0.0,
#   'variational': 0.0,
#   'porchester': 0.0,
#   'hartney': 0.0,
#   ...},
#  'science': {'treason': 0.0,
#   'bayartsaihan': 0.0,
#   'lundeen': 0.0,
#   'addiction': -3.564927746748055e-06,
#   'orac': 0.0,
#   'cimo': 0.0,
#   'pingfederate': 0.0,
#   'bartlett': -1.8281680752554128e-07,
#   'realignment': 0.0,
#   'txi': 0.0,
#   'curbside': 0.0,
#   'subrogated': 0.0,
#   'merger': -1.553942863967101e-06,
#   'yeast': 0.0,
#   'beltre': 0.0,
#   'futureheads': 0.0,
#   'roadcasting': 0.0,
#   'attract': -1.590506225472209e-05,
#   'jaipuria': 0.0,
#   'yeng': 0.0,
#   'propulsion': 0.0,
#   'creditable': 0.0,
#   'mazzaro': 0.0,
#   'smo': 0.0,
#   'navigator': 0.0,
#   'gutless': 0.0,
#   'unknownst': 0.0,
#   'thurbert': 0.0,
#   'silas': 0.0,
#   'journalist': -1.005492441390477e-06,
#   'cmss': 0.0,
#   'namedto': 0.0,
#   'allium': 0.0,
#   'nasa': -4.734955314911519e-05,
#   'jdm': 0.0,
#   'bisphenol': 0.0,
#   'xmlhttp': 0.0,
#   'tompetty': 0.0,
#   'aurorae': 2.756339118293924e-06,
#   'wilmerhale': 0.0,
#   'barrymore': 0.0,
#   'spiderland': 0.0,
#   'benigni': 0.0,
#   'ronald': -1.4625344602043302e-06,
#   'casahl': 0.0,
#   'allmon': 0.0,
#   'pnds': 0.0,
#   'dodea': 0.0,
#   'masaharu': 0.0,
#   'aleier': 0.0,
#   'ethicists': 0.0,
#   'ulrich': 0.0,
#   'portrait': -9.140840376277064e-08,
#   'segue': 0.0,
#   'oveta': 0.0,
#   'ivanchuk': 0.0,
#   'xoma': 2.5610660467506006e-07,
#   'filofax': 0.0,
#   'googleearth': 0.0,
#   'snowmelt': 5.122132093501202e-06,
#   'veridigm': 0.0,
#   'radioed': 0.0,
#   'androgenic': 0.0,
#   'automobile': -1.553942863967101e-06,
#   'minutely': 0.0,
#   'arxiv': 4.5938985304898723e-07,
#   'hiroshige': 0.0,
#   'snowcapped': 0.0,
#   'grecian': 0.0,
#   'berresse': 0.0,
#   'cafeteria': -1.8281680752554128e-07,
#   'audioslave': 0.0,
#   'keeble': 0.0,
#   'vinnee': 0.0,
#   'jumblatt': 0.0,
#   'traipse': 3.3562453383346953e-07,
#   'gx': 0.0,
#   'dmitri': 0.0,
#   'bracewell': 0.0,
#   'excitatory': 9.187797060979745e-07,
#   'prabhadevi': 0.0,
#   'foetal': 1.0244264187002402e-06,
#   'rosso': 0.0,
#   'daim': 0.0,
#   'perloff': 0.0,
#   'goc': 0.0,
#   'glutathione': 0.0,
#   'beiden': 0.0,
#   'prix': 0.0,
#   'defenceless': 0.0,
#   'misse': 9.187797060979745e-07,
#   'renfrew': 0.0,
#   'allowspecialization': 0.0,
#   'luxe': 0.0,
#   'sn': 1.0244264187002402e-06,
#   'overdo': 0.0,
#   'thermistor': 0.0,
#   'djin': 0.0,
#   'analyze': -2.888505558903552e-05,
#   'cohabitation': 0.0,
#   'triggerman': 0.0,
#   'mchattie': 0.0,
#   'sodsri': 0.0,
#   'tonix': 0.0,
#   'exxonmobil': 1.3424981353338781e-06,
#   'exuviae': 4.5938985304898723e-07,
#   'finnegan': 0.0,
#   'sohna': 0.0,
#   'melrose': 0.0,
#   'demilitarization': 0.0,
#   'selhurst': 0.0,
#   'deciphers': 3.3562453383346953e-07,
#   'freewheeling': 0.0,
#   'intech': 0.0,
#   'hilden': 0.0,
#   'kmri': 0.0,
#   'systemc': 0.0,
#   'dowe': 0.0,
#   'voce': 0.0,
#   'viking': -2.2852100940692663e-06,
#   'shinzo': -7.312672301021651e-07,
#   'magnitude': -8.31816474241213e-06,
#   'chiruthaigal': 0.0,
#   'coy': 0.0,
#   'populist': 0.0,
#   'obstetrics': 1.118748446111565e-07,
#   'inactivity': 7.683198140251804e-07,
#   'earthworm': 1.0244264187002402e-06,
#   'elm': 1.118748446111565e-07,
#   'sunol': 9.187797060979745e-07,
#   'rathod': 4.5938985304898723e-07,
#   'liters': -1.4625344602043302e-06,
#   'reynold': 0.0,
#   'multichannelnews': 0.0,
#   'barren': 0.0,
#   'mutedly': 0.0,
#   'cross': -3.5740685871243325e-05,
#   'calty': 0.0,
#   'reyvateils': 0.0,
#   'edition': -5.758729437054551e-06,
#   'dss': 0.0,
#   'rucker': 0.0,
#   'medvinskaya': 0.0,
#   'soweto': 0.0,
#   'creenergy': 0.0,
#   'detulio': 0.0,
#   'intracluster': 0.0,
#   'schlitze': 0.0,
#   'fourier': 5.122132093501201e-07,
#   'khazaie': 0.0,
#   'hamid': 0.0,
#   'medimmune': 0.0,
#   'footner': 0.0,
#   'soleduck': 4.5938985304898723e-07,
#   'framerates': 0.0,
#   'lusk': 4.5938985304898723e-07,
#   'mavado': 0.0,
#   'poti': 0.0,
#   'kamvar': 0.0,
#   'transnational': -9.140840376277064e-08,
#   'bainca': 0.0,
#   'cruisetour': 0.0,
#   'deepika': 0.0,
#   'biggart': 0.0,
#   'securum': 0.0,
#   'solemnity': 0.0,
#   'openmind': 0.0,
#   'ehsan': 0.0,
#   'zaglebie': 0.0,
#   'woodchip': 0.0,
#   'exterior': -1.4625344602043302e-06,
#   'pascazi': 0.0,
#   'appakova': 0.0,
#   'caipirinhas': 0.0,
#   'herringbone': 0.0,
#   'henrion': 0.0,
#   'rescan': 0.0,
#   'extender': 0.0,
#   'saartjie': 0.0,
#   'behavioral': -6.032954648342863e-06,
#   'marlin': 1.118748446111565e-07,
#   'monetise': 0.0,
#   'rasta': 0.0,
#   'porsche': 6.712490676669391e-07,
#   'ganda': 0.0,
#   'quidditch': 0.0,
#   'brindle': 0.0,
#   'kingsford': 2.23749689222313e-07,
#   'heith': 0.0,
#   'electromigration': 0.0,
#   'neuromuscular': 1.0068736015004085e-06,
#   'deviled': 2.5610660467506006e-07,
#   'wagnerian': 0.0,
#   'matthea': 0.0,
#   'sbt': 0.0,
#   'prien': 0.0,
#   'ruell': 0.0,
#   'logi': 0.0,
#   'acessory': 0.0,
#   'harborfields': 0.0,
#   'vendetta': 0.0,
#   'oxnam': 0.0,
#   'kordestan': 0.0,
#   'gamekit': 0.0,
#   'chinese': -2.7879563147645044e-05,
#   'disengage': 0.0,
#   'ignornat': 0.0,
#   'bharatnatyam': 0.0,
#   'kambon': 0.0,
#   'anat': 0.0,
#   'dawei': 0.0,
#   'consol': 4.5938985304898723e-07,
#   'italcementi': 0.0,
#   'ta': -2.7422521128831194e-07,
#   'drobo': 0.0,
#   'lambaste': 0.0,
#   'kosmotras': 4.5938985304898723e-07,
#   'thioke': 1.5366396280503608e-06,
#   'gouri': 0.0,
#   'tizzy': 0.0,
#   'michelob': 0.0,
#   'maryland': -3.3821109392225136e-06,
#   'blithe': 0.0,
#   'ammar': 0.0,
#   'diario': 0.0,
#   'maathai': 0.0,
#   'coverboy': 0.0,
#   'madius': 0.0,
#   'epip': 0.0,
#   'nazko': 0.0,
#   'betters': 2.5610660467506006e-07,
#   'qtv': 0.0,
#   'mazuz': 0.0,
#   'ajavon': 0.0,
#   'jabber': 0.0,
#   'dereje': 0.0,
#   'dern': 0.0,
#   'mathewson': 0.0,
#   'vigilantism': 0.0,
#   'baton': -3.6563361505108256e-07,
#   'camilla': 0.0,
#   'ornamental': 0.0,
#   'specialty': -4.20478657308745e-06,
#   'creative': -1.0969008451532478e-06,
#   'msms': 0.0,
#   'arbuckle': 0.0,
#   'redpoint': 2.23749689222313e-07,
#   'zysblat': 0.0,
#   'saucedo': 0.0,
#   'grammy': 0.0,
#   'dorsey': 0.0,
#   'week': -5.8227153196884896e-05,
#   'ataturk': 0.0,
#   'romatic': 0.0,
#   'coppergate': 0.0,
#   'irresponsible': -9.140840376277064e-08,
#   'codex': 0.0,
#   'sartin': 2.5610660467506006e-07,
#   'hiura': 0.0,
#   'leprosarium': 0.0,
#   'loewe': 0.0,
#   'willett': 7.683198140251804e-07,
#   'taplejung': 0.0,
#   'embarrassing': -7.312672301021651e-07,
#   'bloopers': 0.0,
#   'linecard': 0.0,
#   'lahat': 0.0,
#   'legume': -7.312672301021651e-07,
#   'roberta': 0.0,
#   'pixeljunk': 0.0,
#   'haaren': 0.0,
#   'herein': 0.0,
#   'lenneth': 0.0,
#   'insulation': -4.479011784375762e-06,
#   'unaccountable': 0.0,
#   'kampyo': 0.0,
#   'undeserved': 0.0,
#   'campoz': 0.0,
#   'estelle': 0.0,
#   'awry': 0.0,
#   'weckerle': 0.0,
#   'pinyons': 0.0,
#   'dinovo': 0.0,
#   'polymath': 7.683198140251804e-07,
#   'guyana': 2.23749689222313e-07,
#   'gazpacho': 0.0,
#   'ldc': 0.0,
#   'inclues': 0.0,
#   'glogowski': 0.0,
#   'pixsense': 0.0,
#   'humm': 0.0,
#   'junho': 0.0,
#   'caesarea': 2.5610660467506006e-07,
#   'stackless': 0.0,
#   'masaoka': 0.0,
#   'crewmember': 5.122132093501201e-07,
#   'lothians': 0.0,
#   'robaina': 0.0,
#   'henrico': 0.0,
#   'aditya': 0.0,
#   'plaxce': 0.0,
#   'definition': -1.005492441390477e-06,
#   'kahaulelio': 0.0,
#   'next': -6.160926413610741e-05,
#   'elven': 0.0,
#   'heinous': -9.140840376277064e-08,
#   'collette': 0.0,
#   'stablemate': 0.0,
#   'aryeh': 0.0,
#   'ruc': 0.0,
#   'marsh': -2.4680269015948073e-06,
#   'vrm': 0.0,
#   'valenti': 0.0,
#   'segregationist': 0.0,
#   'bock': 0.0,
#   'voyageurs': 0.0,
#   'silverado': 0.0,
#   'gator': 0.0,
#   'cholesterol': -2.559435305357578e-06,
#   'ludwigshafen': 0.0,
#   'dupri': 0.0,
#   'underspend': 0.0,
#   'netstore': 0.0,
#   'backload': 0.0,
#   'isaak': 0.0,
#   'verbruggen': 0.0,
#   'princia': 0.0,
#   'donnington': 0.0,
#   'kabylie': 0.0,
#   'unevolved': 0.0,
#   'warlick': 0.0,
#   'librettist': 0.0,
#   'posen': 5.122132093501201e-07,
#   'robillard': 0.0,
#   'batsto': 0.0,
#   'hadless': 0.0,
#   'ragusa': 4.5938985304898723e-07,
#   'desalination': 0.0,
#   'impossibility': 0.0,
#   'impute': 0.0,
#   'readsoft': 0.0,
#   'rsalte': 0.0,
#   'resent': 0.0,
#   'regulation': -1.005492441390477e-05,
#   'cinemedia': 0.0,
#   'blend': -4.29619497685022e-06,
#   'acclamation': 0.0,
#   'safeway': 0.0,
#   'banoo': 0.0,
#   'overselling': 0.0,
#   'tif': 0.0,
#   'flyhalf': 0.0,
#   'sustainability': -2.010984882780954e-06,
#   'unflashy': 0.0,
#   'produce': -0.00017358455874550146,
#   'halili': 0.0,
#   'ince': 0.0,
#   'horacio': 0.0,
#   'mayberry': 0.0,
#   'cummins': -3.6563361505108256e-07,
#   'habitue': 0.0,
#   'showiest': 0.0,
#   'karamanlis': 0.0,
#   'dicko': 0.0,
#   'extrajudicial': 0.0,
#   'tatsuo': 0.0,
#   'retransmit': 2.5610660467506006e-07,
#   'redshift': 0.0,
#   'constructive': 0.0,
#   'shallot': 0.0,
#   'pray': -2.7422521128831194e-07,
#   'presimulation': 0.0,
#   'godspell': 0.0,
#   'fontlab': 0.0,
#   'glycerin': 0.0,
#   'aptly': 0.0,
#   'fonterra': 1.118748446111565e-07,
#   'wiesenthal': 0.0,
#   'tel': -4.844645399426845e-06,
#   'decryption': 0.0,
#   'morayfield': 0.0,
#   'brecker': 0.0,
#   'dishslayer': 0.0,
#   'bastian': 3.215728971342911e-06,
#   'socceroos': 0.0,
#   'bulldozer': 1.118748446111565e-07,
#   'gareth': -1.8281680752554128e-07,
#   'edyta': 0.0,
#   'acorn': -1.8281680752554128e-07,
#   'manitoulin': 5.122132093501201e-07,
#   'yelm': 0.0,
#   'km': -6.307179859631174e-06,
#   'troop': -5.118870610715156e-06,
#   'oilseed': 2.5610660467506006e-07,
#   'makhtar': 0.0,
#   'purmal': 0.0,
#   'sunley': 0.0,
#   'itacg': 0.0,
#   'spinned': 0.0,
#   'internist': 0.0,
#   'stabbings': 0.0,
#   'siem': 0.0,
#   'bursary': 4.47499378444626e-07,
#   'gaussianity': 4.5938985304898723e-07,
#   'thorp': 2.5610660467506006e-07,
#   'opos': 0.0,
#   'lenient': 0.0,
#   'nozick': 0.0,
#   'fillip': 0.0,
#   'nina': -2.9250689204086604e-06,
#   'conflate': 2.23749689222313e-07,
#   'anglican': 0.0,
#   'yadkin': 5.122132093501201e-07,
#   'equiment': 9.187797060979745e-07,
#   'dynamin': 0.0,
#   'adegokeorganizers': 0.0,
#   'endeavored': 0.0,
#   'tdk': 0.0,
#   'bot': 7.831239122780955e-07,
#   'crackle': 0.0,
#   'laureen': 0.0,
#   'wolfblock': 0.0,
#   'shatalin': 1.118748446111565e-07,
#   'snakeskin': 0.0,
#   'treacy': 0.0,
#   'firebomb': 0.0,
#   'invacare': 0.0,
#   'harpp': 0.0,
#   'hermia': 0.0,
#   'boroujerdi': 0.0,
#   'rosenblum': 0.0,
#   'istart': 0.0,
#   'qaraghuli': 0.0,
#   'centreman': 0.0,
#   'marvin': -1.8281680752554128e-07,
#   'dela': 0.0,
#   'clockspeed': 0.0,
#   'gozo': 0.0,
#   'pixielike': 0.0,
#   'supreses': 0.0,
#   'rubins': 0.0,
#   'sholom': 0.0,
#   'olea': 0.0,
#   'farzad': 0.0,
#   'uracan': 0.0,
#   'kiefer': 0.0,
#   'irrigate': -4.29619497685022e-06,
#   'wtttv': 0.0,
#   'dawood': 0.0,
#   'himatangi': 0.0,
#   'embark': -1.8281680752554129e-06,
#   'puri': 0.0,
#   'om': 0.0,
#   'buckcherry': 0.0,
#   'bray': -4.570420188138532e-07,
#   'scurato': 0.0,
#   'lldpe': 0.0,
#   'yesteday': 0.0,
#   'gonzales': -3.6563361505108256e-07,
#   'iroquois': 1.118748446111565e-07,
#   'margaux': 0.0,
#   'andha': 0.0,
#   'slithery': 4.5938985304898723e-07,
#   'flaw': -1.9195764790181834e-06,
#   'nihon': 0.0,
#   'sigman': 0.0,
#   'pram': 0.0,
#   'nachtmystium': 0.0,
#   'maxian': 0.0,
#   'mircosoft': 0.0,
#   'refresher': 0.0,
#   'hilary': -8.226756338649357e-07,
#   'betts': 1.118748446111565e-07,
#   'ebo': 4.5938985304898723e-07,
#   'susan': -9.140840376277064e-07,
#   'sciac': 0.0,
#   'perpendicularly': 9.187797060979745e-07,
#   'honcho': 0.0,
#   'embarassment': 0.0,
#   'darigold': 0.0,
#   'irrestible': 0.0,
#   'vito': 0.0,
#   'stempeutics': 0.0,
#   'saprang': 0.0,
#   'biohazard': 0.0,
#   'infoworld': 0.0,
#   'probibits': 0.0,
#   'kellyn': 0.0,
#   'maile': 0.0,
#   'hitchcock': 0.0,
#   'boepd': 4.5938985304898723e-07,
#   'pistola': 0.0,
#   'stancavage': 4.5938985304898723e-07,
#   'lockdown': 0.0,
#   'bogenschutz': 0.0,
#   'avelino': 9.187797060979745e-07,
#   'nclba': 0.0,
#   'appignanesi': 0.0,
#   'feldmayer': 0.0,
#   'crap': 0.0,
#   'zelda': 0.0,
#   'deficiency': -1.1883092489160183e-06,
#   'murder': -1.553942863967101e-06,
#   'collooney': 0.0,
#   'tunneling': 0.0,
#   'parramatta': 0.0,
#   'pbdes': 5.122132093501201e-07,
#   'zyvox': 0.0,
#   'strand': -6.215771455868404e-06,
#   'karsten': 0.0,
#   'talmud': 0.0,
#   'teterboro': 0.0,
#   'visavis': 0.0,
#   'macedon': 0.0,
#   'ichat': 0.0,
#   'mandak': 0.0,
#   'bhadrakumar': 0.0,
#   'levyatan': 2.5610660467506006e-07,
#   'insult': -7.312672301021651e-07,
#   'zulte': 9.187797060979745e-07,
#   'bristle': 0.0,
#   'comres': 0.0,
#   'langa': 0.0,
#   'mirvat': 0.0,
#   'jehovah': 0.0,
#   'aiglx': 0.0,
#   'maliciously': 0.0,
#   'burgh': 0.0,
#   'bhumibol': 2.5610660467506006e-07,
#   'attune': -8.226756338649357e-07,
#   'ogerman': 0.0,
#   'lasalle': 0.0,
#   'hyperinflation': 0.0,
#   'hydrochloride': 0.0,
#   'utterance': 1.118748446111565e-07,
#   'naxos': 0.0,
#   'ustream': 5.122132093501201e-07,
#   'qabalan': 0.0,
#   'trustedplaces': 0.0,
#   'burring': 0.0,
#   'unsheathing': 0.0,
#   'dft': 0.0,
#   'symposium': -1.005492441390477e-06,
#   'dhanush': 0.0,
#   'naqshbandi': 0.0,
#   'shoot': -8.135347934886586e-06,
#   'treadmill': 2.23749689222313e-07,
#   'okuda': 0.0,
#   'vlx': 0.0,
#   'seni': 0.0,
#   'quarterbacked': 0.0,
#   'sportsmanship': 0.0,
#   'rollerskate': 0.0,
#   'baskins': 0.0,
#   'vestas': 0.0,
#   'podemos': 0.0,
#   'synopsis': 0.0,
#   'abney': 0.0,
#   'timeless': 0.0,
#   'corn': -9.963516010141999e-06,
#   'macbu': 0.0,
#   'sajdak': 0.0,
#   'flea': -6.398588263393945e-07,
#   'guard': -1.1243233662820787e-05,
#   'nicealarm': 0.0,
#   'innopath': 0.0,
#   'avuncular': 0.0,
#   'cocula': 0.0,
#   'mandir': 4.5938985304898723e-07,
#   'claypool': 0.0,
#   'loehr': 0.0,
#   'marketising': 0.0,
#   'let': -2.605139507238963e-05,
#   'arraytrack': 0.0,
#   'naslund': 0.0,
#   'reporter': -7.952531127361045e-06,
#   'pedernales': 0.0,
#   'donnelley': 0.0,
#   'econ': 0.0,
#   'prospectivity': 0.0,
#   'fiftysomething': 0.0,
#   'metabolically': 5.122132093501201e-07,
#   'caner': 0.0,
#   'verisign': 0.0,
#   'nintendogs': 0.0,
#   'serologic': 0.0,
#   'constructively': 0.0,
#   'mahina': 0.0,
#   'cuthbert': 0.0,
#   'mesopotamia': 0.0,
#   'terso': 0.0,
#   'unmined': 0.0,
#   'sell': -5.4845042257662383e-05,
#   'magmatic': 4.5938985304898723e-07,
#   'telly': 0.0,
#   'dum': 0.0,
#   'ferrostaal': 0.0,
#   'minnelli': 0.0,
#   'talisman': 0.0,
#   'wadmalaw': 0.0,
#   'broadcaster': -4.570420188138532e-07,
#   'phosphatase': 0.0,
#   'extralegal': 0.0,
#   'opeth': 0.0,
#   'bai': 0.0,
#   'proffer': -1.8281680752554128e-07,
#   'neptune': 0.0,
#   'ifct': 0.0,
#   'kishkinta': 0.0,
#   'inexpense': 0.0,
#   'gratuity': 0.0,
#   'gosney': 0.0,
#   'iness': 0.0,
#   'ketke': 0.0,
#   'viroporins': 0.0,
#   'gor': 0.0,
#   'tanyard': 0.0,
#   'mailenable': 0.0,
#   'microholdings': 0.0,
#   'chipbond': 0.0,
#   'zhuang': 0.0,
#   'brygg': 0.0,
#   'yashvir': 0.0,
#   'pegritz': 0.0,
#   'yashomati': 0.0,
#   'degreed': 0.0,
#   'mobilinux': 0.0,
#   'cloepfil': 0.0,
#   'franjieh': 0.0,
#   'yaki': 0.0,
#   'aichi': 0.0,
#   'adderall': 0.0,
#   'anatomist': 4.47499378444626e-07,
#   'freespire': 0.0,
#   'klitschko': 0.0,
#   'tva': 8.94998756889252e-07,
#   'eetimes': 0.0,
#   'ulduar': 0.0,
#   'topix': 0.0,
#   'kennebec': 2.23749689222313e-07,
#   'hoolock': 0.0,
#   'multigeographic': 0.0,
#   'cambias': 0.0,
#   'sudhakar': 0.0,
#   'wenye': 0.0,
#   'lactational': 0.0,
#   'gimmicky': 0.0,
#   'batu': 0.0,
#   'maiwand': 0.0,
#   'fazakerley': 0.0,
#   'godtube': 0.0,
#   'jeff': -3.747744554273596e-06,
#   'divert': -4.661828591901302e-06,
#   'sanitising': 0.0,
#   'asiad': 0.0,
#   'baratta': 0.0,
#   'chancel': 0.0,
#   'microarrays': 4.47499378444626e-07,
#   'moraine': 0.0,
#   'toktogonova': 0.0,
#   'colly': 0.0,
#   'dixon': 0.0,
#   'capacity': -7.404080704784422e-06,
#   'vaiko': 0.0,
#   'gantry': 0.0,
#   'liaohe': 0.0,
#   'pieper': 5.122132093501201e-07,
#   'daria': 0.0,
#   'encysive': 0.0,
#   'indochina': 2.5610660467506006e-07,
#   'netevents': 0.0,
#   'ner': 0.0,
#   'caserta': 0.0,
#   'suddenly': -7.312672301021651e-07,
#   'pentium': 0.0,
#   'nobuyoshi': 0.0,
#   'gratifyingly': 0.0,
#   'briony': 0.0,
#   'ancestry': -3.6563361505108256e-07,
#   'rlc': 0.0,
#   'thiboust': 0.0,
#   'docusphere': 0.0,
#   'maori': -1.8281680752554128e-07,
#   'monarchical': 0.0,
#   'ettinger': 0.0,
#   'stickball': 0.0,
#   'edwards': -1.4899569813331614e-05,
#   'simpligrid': 0.0,
#   'berggruen': 0.0,
#   'warble': 0.0,
#   'der': -8.226756338649357e-07,
#   'positivity': 0.0,
#   'fixation': -3.6563361505108256e-07,
#   'poyner': 2.5610660467506006e-07,
#   'mundo': 0.0,
#   'teheran': 0.0,
#   'beehive': 0.0,
#   'janasakthi': 0.0,
#   'rickroll': 0.0,
#   'intermingle': 2.5610660467506006e-07,
#   'enterix': 0.0,
#   'outstrip': -1.7367596714926424e-06,
#   'mair': 1.118748446111565e-07,
#   'kittyhawk': 0.0,
#   'comcast': 0.0,
#   'artiste': 0.0,
#   'pinakapambatang': 0.0,
#   'crevasses': 4.5938985304898723e-07,
#   'braggart': 0.0,
#   'irate': 0.0,
#   'jaroslav': 0.0,
#   'departure': -1.0969008451532478e-06,
#   'indigestion': 0.0,
#   'florentine': 0.0,
#   'speers': 0.0,
#   'gorgeous': -2.7422521128831194e-07,
#   'treneman': 0.0,
#   'consuegra': 0.0,
#   'hymen': 0.0,
#   'gleason': 0.0,
#   'portelli': 0.0,
#   'maudlin': 0.0,
#   'dinarello': 0.0,
#   'jakim': 0.0,
#   'makakatrabaho': 0.0,
#   'randalls': 0.0,
#   'mannie': 0.0,
#   'borderless': 0.0,
#   'apg': 0.0,
#   'reserpine': 0.0,
#   'eilers': 5.122132093501201e-07,
#   'lieberman': 0.0,
#   'lorayne': 0.0,
#   'ravichandran': 0.0,
#   'platform': -1.1151825259058019e-05,
#   'curuenavuli': 0.0,
#   'intelligently': 1.118748446111565e-07,
#   'adenopathy': 0.0,
#   'benja': 0.0,
#   'christchuch': 0.0,
#   'misinformation': -1.8281680752554128e-07,
#   'melanie': 0.0,
#   'emacs': 0.0,
#   'inadvertent': -9.140840376277064e-08,
#   'googlemaps': 0.0,
#   'torino': 2.5610660467506006e-07,
#   'gamesradar': 0.0,
#   'rajput': 0.0,
#   'infiniteight': 0.0,
#   'ortman': 0.0,
#   'indiewire': 0.0,
#   'touchscreen': 0.0,
#   'woitasek': 0.0,
#   'amazonian': 0.0,
#   'tropic': 0.0,
#   'blindingly': 0.0,
#   'rtts': 0.0,
#   'voyager': 0.0,
#   'lime': 0.0,
#   'cubavera': 0.0,
#   'devise': -4.661828591901302e-06,
#   'nonprescription': 6.712490676669391e-07,
#   'maryo': 0.0,
#   'anthrax': 0.0,
#   'havering': 0.0,
#   'ummeed': 0.0,
#   'jolty': 0.0,
#   'tuong': 0.0,
#   'hibbs': 0.0,
#   'topbraid': 0.0,
#   'milgram': 0.0,
#   'diy': -5.484504225766239e-07,
#   'wahiawa': 0.0,
#   'million': -0.00013053120057323646,
#   'hrp': 0.0,
#   'iconography': 1.118748446111565e-07,
#   'banco': 0.0,
#   'brinksmanship': 0.0,
#   'callea': 0.0,
#   'freeform': 0.0,
#   'lapiga': 4.5938985304898723e-07,
#   'meeks': 0.0,
#   'immunocompatent': 0.0,
#   'hazily': 0.0,
#   'alpenfest': 0.0,
#   'warily': 5.122132093501201e-07,
#   'schlumberger': 0.0,
#   'traktor': 0.0,
#   'norwegian': -6.124363052105633e-06,
#   'panyu': 0.0,
#   'chiba': 1.0244264187002402e-06,
#   'inactivate': 4.47499378444626e-07,
#   'durability': -9.140840376277064e-08,
#   'surinder': 0.0,
#   'json': 0.0,
#   'grumpy': 1.118748446111565e-07,
#   'srimuang': 0.0,
#   'slipstitch': 0.0,
#   'saftoiu': 0.0,
#   'hwpen': 0.0,
#   'hozan': 0.0,
#   'printable': 0.0,
#   'distributary': 0.0,
#   'clouseau': 0.0,
#   'netvanta': 0.0,
#   'concepcion': 0.0,
#   'manacle': 0.0,
#   'hyaluronic': 0.0,
#   'aplindore': 0.0,
#   'tregs': 0.0,
#   'brentano': 0.0,
#   'pinnarayi': 0.0,
#   'neeta': 0.0,
#   'riaz': 0.0,
#   'bofors': 0.0,
#   'capitalist': -9.140840376277064e-08,
#   'rotation': -1.279717652678789e-06,
#   'evangelize': 0.0,
#   'schefter': 0.0,
#   'ccp': 2.23749689222313e-07,
#   'phosphorous': 0.0,
#   'manolo': 0.0,
#   'menu': -1.8281680752554129e-06,
#   'vcenter': 0.0,
#   'touchpad': 0.0,
#   'cheeburger': 0.0,
#   'unsightly': 0.0,
#   'botnet': 0.0,
#   'iab': 0.0,
#   'fathomless': 0.0,
#   'trainwreck': 0.0,
#   'wabo': 0.0,
#   'kong': -5.850137840817321e-06,
#   'nathaniel': 0.0,
#   'ruksun': 0.0,
#   'mcquivey': 0.0,
#   'colao': 0.0,
#   'newshour': 0.0,
#   'acca': 0.0,
#   'jodhpur': 0.0,
#   'unreturned': 0.0,
#   'chessplaying': 0.0,
#   'outcompete': 9.187797060979745e-07,
#   'inductive': 0.0,
#   'tracklist': 0.0,
#   'korban': 0.0,
#   'upmo': 0.0,
#   'documenta': 0.0,
#   'bog': -1.3711260564415597e-06,
#   'neustel': 0.0,
#   'omneon': 0.0,
#   'nemhiripiri': 0.0,
#   'tameika': 0.0,
#   'machinist': 0.0,
#   'dariya': 9.187797060979745e-07,
#   'workbook': 0.0,
#   'noice': 0.0,
#   'pivotal': 0.0,
#   'tarry': 0.0,
#   'hotwire': 0.0,
#   'toxicants': 2.5610660467506006e-07,
#   'lyne': 0.0,
#   'sharqiyah': 0.0,
#   'nema': 0.0,
#   'stn': 0.0,
#   'mcbain': 0.0,
#   'deftones': 0.0,
#   'outernational': 0.0,
#   'slasher': 0.0,
#   'lifestyle': -4.021969765561908e-06,
#   'marketable': 0.0,
#   'yesterdayover': 0.0,
#   'reconven': 0.0,
#   'maul': -5.484504225766239e-07,
#   'powerdsine': 0.0,
#   'insularisation': 0.0,
#   'marzuq': 0.0,
#   'sansho': 0.0,
#   'harass': -7.312672301021651e-07,
#   'durang': 0.0,
#   'mailroom': 0.0,
#   'silkcentral': 0.0,
#   'cra': 0.0,
#   'hdv': 0.0,
#   'extension': -6.398588263393945e-06,
#   'ingestion': 0.0,
#   'gatland': 0.0,
#   'misbegotten': 0.0,
#   'outside': -5.146293131843987e-05,
#   'tichenor': 0.0,
#   'citizenry': 5.122132093501201e-07,
#   'memorabilia': 0.0,
#   'guinn': 0.0,
#   'allard': -1.1883092489160183e-06,
#   'upmc': 0.0,
#   'sublimely': 0.0,
#   'sharifnia': 0.0,
#   'pfds': 5.122132093501201e-07,
#   'frock': 0.0,
#   'blackmailer': 0.0,
#   'racialised': 0.0,
#   'tae': 0.0,
#   'yeltsin': 0.0,
#   'childabuse': 0.0,
#   'bourdelle': 0.0,
#   'saluja': 0.0,
#   'noncorporate': 0.0,
#   'clerical': 0.0,
#   'urairat': 0.0,
#   'netvigil': 0.0,
#   'immerse': -1.279717652678789e-06,
#   'empathise': 0.0,
#   'abell': 2.23749689222313e-07,
#   'parasitic': -8.226756338649357e-07,
#   'conceptual': -1.005492441390477e-06,
#   'theosophical': 0.0,
#   'performicssearch': 0.0,
#   'medisec': 0.0,
#   'lonnquest': 0.0,
#   'powerbroker': 1.0244264187002402e-06,
#   'hr': -1.0969008451532478e-06,
#   'invariably': -2.7422521128831194e-07,
#   'pinout': 0.0,
#   'valerie': -9.140840376277064e-08,
#   'escapade': 0.0,
#   'lexi': 0.0,
#   'spot': -2.2120833710590495e-05,
#   'klebold': 0.0,
#   'peete': 0.0,
#   'jhumpa': 0.0,
#   'padmasree': 0.0,
#   'reconsider': -2.559435305357578e-06,
#   'jakovina': 0.0,
#   'koodankulam': 0.0,
#   'flac': 0.0,
#   'hurlbirt': 0.0,
#   'troublshooting': 0.0,
#   'hospitalist': 0.0,
#   'sheehan': 0.0,
#   'vine': 0.0,
#   'britian': 0.0,
#   'emoney': 0.0,
#   'hackler': 0.0,
#   'lavaca': 0.0,
#   'tyramine': 1.0244264187002402e-06,
#   'udhav': 0.0,
#   'osdl': 0.0,
#   'masonry': 0.0,
#   'nonnegotiable': 0.0,
#   'tibotec': 0.0,
#   'mimetic': 0.0,
#   'unmoved': 0.0,
#   'serialization': 0.0,
#   'doszip': 0.0,
#   'worldweaver': 0.0,
#   'ghteen': 4.5938985304898723e-07,
#   'baabda': 0.0,
#   'cutter': 0.0,
#   'tshwane': 0.0,
#   'opsware': 2.5610660467506006e-07,
#   'gad': 2.23749689222313e-07,
#   'orthofix': 0.0,
#   'gpt': 0.0,
#   'myoblast': 0.0,
#   'marine': -2.9342097607849376e-05,
#   'pronged': 0.0,
#   'acclimate': 1.837559412195949e-06,
#   'gloc': 0.0,
#   'sibanda': 0.0,
#   'grandparent': -9.140840376277064e-08,
#   'cipla': 0.0,
#   'pevion': 0.0,
#   'binj': 0.0,
#   'parekura': 0.0,
#   'castelli': 0.0,
#   'plot': -2.6508437091203487e-06,
#   'malign': 0.0,
#   'elektronik': 0.0,
#   'lesley': -9.140840376277064e-08,
#   'rivetting': 0.0,
#   'kakihara': 0.0,
#   'sideswipe': 0.0,
#   'vaporetto': 0.0,
#   'baig': 0.0,
#   'partnerfirst': 0.0,
#   'js': 0.0,
#   'minsheng': 0.0,
#   'pakistani': -1.1883092489160183e-06,
#   'softballs': 0.0,
#   'mancini': 0.0,
#   'saqr': 0.0,
#   'yorkdale': 0.0,
#   'violat': 0.0,
#   'contributory': 0.0,
#   'mediasense': 0.0,
#   'taiex': 0.0,
#   'ruk': 0.0,
#   'variational': 0.0,
#   'porchester': 0.0,
#   'hartney': 0.0,
#   ...},
#  'health': {'treason': 0.0,
#   'bayartsaihan': 0.0,
#   'lundeen': 0.0,
#   'addiction': -9.652023879025778e-06,
#   'orac': 0.0,
#   'cimo': 0.0,
#   'pingfederate': 0.0,
#   'bartlett': -2.487635020367469e-07,
#   'realignment': 0.0,
#   'txi': 1.7502898367821604e-06,
#   'curbside': 0.0,
#   'subrogated': 0.0,
#   'merger': -3.631947129736504e-06,
#   'yeast': 0.0,
#   'beltre': 0.0,
#   'futureheads': 0.0,
#   'roadcasting': 0.0,
#   'attract': -9.652023879025778e-06,
#   'jaipuria': 0.0,
#   'yeng': 0.0,
#   'propulsion': 0.0,
#   'creditable': 7.501242157637829e-07,
#   'mazzaro': 2.0003312420367546e-06,
#   'smo': 0.0,
#   'navigator': 0.0,
#   'gutless': 0.0,
#   'unknownst': 0.0,
#   'thurbert': 0.0,
#   'silas': 0.0,
#   'journalist': -2.4378823199601194e-06,
#   'cmss': 0.0,
#   'namedto': 0.0,
#   'allium': 1.0001656210183773e-06,
#   'nasa': -1.5920864130351802e-06,
#   'jdm': 0.0,
#   'bisphenol': 0.0,
#   'xmlhttp': 0.0,
#   'tompetty': 0.0,
#   'aurorae': 0.0,
#   'wilmerhale': 0.0,
#   'barrymore': 0.0,
#   'spiderland': 0.0,
#   'benigni': 0.0,
#   'ronald': -1.0945594089616863e-06,
#   'casahl': 0.0,
#   'allmon': 0.0,
#   'pnds': 0.0,
#   'dodea': 0.0,
#   'masaharu': 0.0,
#   'aleier': 0.0,
#   'ethicists': 1.3939632080011622e-07,
#   'ulrich': 0.0,
#   'portrait': -6.467851052955418e-07,
#   'segue': 0.0,
#   'oveta': 0.0,
#   'ivanchuk': 2.7879264160023245e-07,
#   'xoma': 2.7879264160023245e-07,
#   'filofax': 0.0,
#   'googleearth': 0.0,
#   'snowmelt': 0.0,
#   'veridigm': 0.0,
#   'radioed': 0.0,
# ...
#   'rosenblum': 1.0547174385061227e-07,
#   'istart': 0.0,
#   'qaraghuli': 0.0,
#   'centreman': 1.0547174385061227e-07,
#   'marvin': -1.3221520502875138e-06,
#   'dela': 2.4107899012696703e-06,
#   'clockspeed': 0.0,
#   'gozo': 2.939987684475208e-07,
#   'pixielike': 2.1094348770122454e-07,
#   'supreses': 0.0,
#   'rubins': 0.0,
#   'sholom': 4.218869754024491e-07,
#   'olea': 1.0547174385061227e-07,
#   'farzad': 0.0,
#   'uracan': 0.0,
#   'kiefer': 5.291977832055374e-07,
#   'irrigate': -6.295962144226256e-08,
#   'wtttv': 1.0547174385061227e-07,
#   'dawood': 0.0,
#   'himatangi': 0.0,
#   'embark': -2.45542523624824e-06,
#   'puri': 0.0,
#   'om': 9.246761884927415e-07,
#   'buckcherry': 4.218869754024491e-07,
#   'bray': -3.35784647692067e-07,
#   'scurato': 1.0547174385061227e-07,
#   'lldpe': 3.164152315518368e-07,
#   'yesteday': 0.0,
#   'gonzales': -3.147981072113128e-07,
#   'iroquois': 1.7979814776247752e-07,
#   'margaux': 0.0,
#   'andha': 2.1094348770122454e-07,
#   'slithery': 0.0,
#   'flaw': -1.112286645479972e-06,
#   'nihon': 0.0,
#   'sigman': 0.0,
#   'pram': 0.0,
#   'nachtmystium': 1.0547174385061227e-07,
#   'maxian': 1.0547174385061227e-07,
#   'mircosoft': 0.0,
#   'refresher': 1.7639926106851243e-07,
#   'hilary': -1.55300399557581e-06,
#   'betts': 1.0274179872141573e-07,
#   'ebo': 0.0,
#   'susan': -5.141702417784776e-06,
#   'sciac': 0.0,
#   'perpendicularly': 0.0,
#   'honcho': 0.0,
#   'embarassment': 0.0,
#   'darigold': 0.0,
#   'irrestible': 6.328304631036736e-07,
#   'vito': 0.0,
#   'stempeutics': 0.0,
#   'saprang': 0.0,
#   'biohazard': 1.175995073790083e-07,
#   'infoworld': 0.0,
#   'probibits': 0.0,
#   'kellyn': 9.492456946555104e-07,
#   'maile': 0.0,
#   'hitchcock': 0.0,
#   'boepd': 0.0,
#   'pistola': 3.164152315518368e-07,
#   'stancavage': 0.0,
#   'lockdown': 0.0,
#   'bogenschutz': 0.0,
#   'avelino': 0.0,
#   'nclba': 0.0,
#   'appignanesi': 1.0547174385061227e-07,
#   'feldmayer': 0.0,
#   'crap': 0.0,
#   'zelda': 9.995958127215706e-07,
#   'deficiency': -1.2591924288452512e-07,
#   'murder': -1.9475509566139886e-05,
#   'collooney': 0.0,
#   'tunneling': 0.0,
#   'parramatta': 0.0,
#   'pbdes': 0.0,
#   'zyvox': 0.0,
#   'strand': -1.9307617242293853e-06,
#   'karsten': 2.1094348770122454e-07,
#   'talmud': 2.1094348770122454e-07,
#   'teterboro': 0.0,
#   'visavis': 0.0,
#   'macedon': 1.0547174385061227e-07,
#   'ichat': 0.0,
#   'mandak': 2.1094348770122454e-07,
#   'bhadrakumar': 0.0,
#   'levyatan': 0.0,
#   'insult': -1.4480712931720389e-06,
#   'zulte': 0.0,
#   'bristle': 0.0,
#   'comres': 0.0,
#   'langa': 1.0547174385061227e-07,
#   'mirvat': 1.0547174385061227e-07,
#   'jehovah': 1.0547174385061227e-07,
#   'aiglx': 0.0,
#   'maliciously': 1.2842724840176966e-07,
#   'burgh': 1.175995073790083e-07,
#   'bhumibol': 0.0,
#   'attune': -1.469057833652793e-07,
#   'ogerman': 1.0547174385061227e-07,
#   'lasalle': 0.0,
#   'hyperinflation': 0.0,
#   'hydrochloride': 0.0,
#   'utterance': 5.1370899360707864e-08,
#   'naxos': 5.273587192530614e-07,
#   'ustream': 0.0,
#   'qabalan': 0.0,
#   'trustedplaces': 0.0,
#   'burring': 1.0547174385061227e-07,
#   'unsheathing': 1.0547174385061227e-07,
#   'dft': 0.0,
#   'symposium': -1.8887886432678766e-07,
#   'dhanush': 4.218869754024491e-07,
#   'naqshbandi': 0.0,
#   'shoot': -5.939190956053435e-05,
#   'treadmill': 1.0274179872141573e-07,
#   'okuda': 0.0,
#   'vlx': 0.0,
#   'seni': 1.175995073790083e-07,
#   'quarterbacked': 0.0,
#   'sportsmanship': 2.1094348770122454e-07,
#   'rollerskate': 1.0547174385061227e-07,
#   'baskins': 0.0,
#   'vestas': 0.0,
#   'podemos': 0.0,
#   'synopsis': 1.175995073790083e-07,
#   'abney': 0.0,
#   'timeless': 0.0,
#   'corn': -2.7912098839403065e-06,
#   'macbu': 0.0,
#   'sajdak': 2.1094348770122454e-07,
#   'flea': -3.777577286535753e-07,
#   'guard': -1.0094525971242765e-05,
#   'nicealarm': 0.0,
#   'innopath': 0.0,
#   'avuncular': 1.0547174385061227e-06,
#   'cocula': 5.273587192530614e-07,
#   'mandir': 0.0,
#   'claypool': 4.218869754024491e-07,
#   'loehr': 1.0547174385061227e-07,
#   'marketising': 0.0,
#   'let': -3.057738948045885e-05,
#   'arraytrack': 0.0,
#   'naslund': 4.218869754024491e-07,
#   'reporter': -1.057721640230011e-05,
#   'pedernales': 1.0547174385061227e-07,
#   'donnelley': 5.879975368950415e-08,
#   'econ': 0.0,
#   'prospectivity': 0.0,
#   'fiftysomething': 1.0547174385061227e-07,
#   'metabolically': 0.0,
#   'caner': 6.328304631036736e-07,
#   'verisign': 0.0,
#   'nintendogs': 0.0,
#   'serologic': 0.0,
#   'constructively': 0.0,
#   'mahina': 5.273587192530614e-07,
#   'cuthbert': 4.6233809424637077e-07,
#   'mesopotamia': 1.0547174385061227e-07,
#   'terso': 0.0,
#   'unmined': 1.0547174385061227e-07,
#   'sell': -9.685288431868057e-05,
#   'magmatic': 0.0,
#   'telly': 1.0274179872141573e-07,
#   'dum': 1.7639926106851243e-07,
#   'ferrostaal': 0.0,
#   'minnelli': 4.429813241725715e-06,
#   'talisman': 6.328304631036736e-07,
#   'wadmalaw': 2.1094348770122454e-07,
#   'broadcaster': -4.386186960477625e-06,
#   'phosphatase': 0.0,
#   'extralegal': 1.7639926106851243e-07,
#   'opeth': 1.0547174385061227e-07,
#   'bai': 0.0,
#   'proffer': -1.678923238460335e-07,
#   'neptune': 1.0274179872141573e-07,
#   'ifct': 0.0,
#   'kishkinta': 0.0,
#   'inexpense': 1.0547174385061227e-07,
#   'gratuity': 9.492456946555104e-07,
#   'gosney': 0.0,
#   'iness': 0.0,
#   'ketke': 1.0547174385061227e-07,
#   'viroporins': 0.0,
#   'gor': 1.0547174385061227e-07,
#   'tanyard': 0.0,
#   'mailenable': 0.0,
#   'microholdings': 0.0,
#   'chipbond': 0.0,
#   'zhuang': 4.218869754024491e-07,
#   'brygg': 0.0,
#   'yashvir': 0.0,
#   'pegritz': 0.0,
#   'yashomati': 0.0,
#   'degreed': 1.0547174385061227e-07,
#   'mobilinux': 0.0,
#   'cloepfil': 2.1094348770122454e-07,
#   'franjieh': 5.879975368950415e-08,
#   'yaki': 0.0,
#   'aichi': 0.0,
#   'adderall': 1.175995073790083e-07,
#   'anatomist': 3.5959629552495505e-07,
#   'freespire': 0.0,
#   'klitschko': 4.218869754024491e-07,
#   'tva': 0.0,
#   'eetimes': 0.0,
#   'ulduar': 1.0547174385061227e-07,
#   'topix': 0.0,
#   'kennebec': 6.421362420088483e-07,
#   'hoolock': 0.0,
#   'multigeographic': 0.0,
#   'cambias': 1.0547174385061227e-07,
#   'sudhakar': 0.0,
#   'wenye': 1.0547174385061227e-07,
#   'lactational': 0.0,
#   'gimmicky': 0.0,
#   'batu': 5.1370899360707864e-08,
#   'maiwand': 0.0,
#   'fazakerley': 0.0,
#   'godtube': 0.0,
#   'jeff': -8.793360461436004e-06,
#   'divert': -7.555154573071506e-07,
#   'sanitising': 0.0,
#   'asiad': 1.0547174385061227e-07,
#   'baratta': 0.0,
#   'chancel': 1.0547174385061227e-07,
#   'microarrays': 0.0,
#   'moraine': 2.7211709913457966e-05,
#   'toktogonova': 0.0,
#   'colly': 5.879975368950415e-08,
#   'dixon': 0.0,
#   'capacity': -2.2665463719214524e-06,
#   'vaiko': 0.0,
#   'gantry': 0.0,
#   'liaohe': 2.1094348770122454e-07,
#   'pieper': 0.0,
#   'daria': 2.1094348770122454e-07,
#   'encysive': 0.0,
#   'indochina': 0.0,
#   'netevents': 0.0,
#   'ner': 2.1094348770122454e-07,
#   'caserta': 0.0,
#   'suddenly': -4.3442138795161166e-06,
#   'pentium': 0.0,
#   'nobuyoshi': 1.0547174385061227e-07,
#   'gratifyingly': 3.164152315518368e-07,
#   'briony': 5.879975368950415e-08,
#   'ancestry': -4.197308096150837e-08,
#   'rlc': 0.0,
#   'thiboust': 1.0547174385061227e-07,
#   'docusphere': 0.0,
#   'maori': -1.2172193478837429e-06,
#   'monarchical': 0.0,
#   'ettinger': 0.0,
#   'stickball': 1.0547174385061227e-07,
#   'edwards': -3.6516580436512286e-06,
#   'simpligrid': 0.0,
#   'berggruen': 2.1094348770122454e-07,
#   'warble': 8.437739508048982e-07,
#   'der': -1.0703135645184634e-06,
#   'positivity': 5.273587192530614e-07,
#   'fixation': -4.197308096150837e-08,
#   'poyner': 0.0,
#   'mundo': 6.328304631036736e-07,
#   'teheran': 2.1094348770122454e-07,
#   'beehive': 0.0,
#   'janasakthi': 0.0,
#   'rickroll': 1.0547174385061227e-07,
#   'intermingle': 5.291977832055374e-07,
#   'enterix': 0.0,
#   'outstrip': -8.184750787494132e-07,
#   'mair': 0.0,
#   'kittyhawk': 0.0,
#   'comcast': 0.0,
#   'artiste': 1.3523943348585955e-06,
#   'pinakapambatang': 1.0547174385061227e-07,
#   'crevasses': 0.0,
#   'braggart': 1.0547174385061227e-07,
#   'irate': 0.0,
#   'jaroslav': 3.164152315518368e-07,
#   'departure': -2.2665463719214524e-06,
#   'indigestion': 5.879975368950415e-08,
#   'florentine': 3.164152315518368e-07,
#   'speers': 1.0547174385061227e-07,
#   'gorgeous': -2.20358675047919e-06,
#   'treneman': 0.0,
#   'consuegra': 1.0547174385061227e-07,
#   'hymen': 0.0,
#   'gleason': 2.0548359744283145e-07,
#   'portelli': 1.0547174385061227e-07,
#   'maudlin': 4.218869754024491e-07,
#   'dinarello': 0.0,
#   'jakim': 0.0,
#   'makakatrabaho': 2.1094348770122454e-07,
#   'randalls': 4.218869754024491e-07,
#   'mannie': 1.0547174385061227e-07,
#   'borderless': 0.0,
#   'apg': 2.1094348770122454e-07,
#   'reserpine': 0.0,
#   'eilers': 0.0,
#   'lieberman': 0.0,
#   'lorayne': 0.0,
#   'ravichandran': 2.1094348770122454e-07,
#   'platform': -6.233002522783994e-06,
#   'curuenavuli': 2.1094348770122454e-07,
#   'intelligently': 2.5685449680353932e-08,
#   'adenopathy': 0.0,
#   'benja': 1.0547174385061227e-07,
#   'christchuch': 0.0,
#   'misinformation': -2.0986540480754186e-08,
#   'melanie': 0.0,
#   'emacs': 0.0,
#   'inadvertent': -2.5183848576905024e-07,
#   'googlemaps': 1.0547174385061227e-07,
#   'torino': 4.703980295160332e-07,
#   'gamesradar': 3.164152315518368e-07,
#   'rajput': 2.1094348770122454e-07,
#   'infiniteight': 4.218869754024491e-07,
#   'ortman': 0.0,
#   'indiewire': 1.0547174385061227e-06,
#   'touchscreen': 0.0,
#   'woitasek': 0.0,
#   'amazonian': 0.0,
#   'tropic': 2.6367935962653068e-06,
#   'blindingly': 1.175995073790083e-07,
#   'rtts': 0.0,
#   'voyager': 0.0,
#   'lime': 0.0,
#   'cubavera': 1.0547174385061227e-07,
#   'devise': -5.981164037014943e-06,
#   'nonprescription': 0.0,
#   'maryo': 3.164152315518368e-07,
#   'anthrax': 0.0,
#   'havering': 0.0,
#   'ummeed': 0.0,
#   'jolty': 1.0547174385061227e-07,
#   'tuong': 3.164152315518368e-07,
#   'hibbs': 2.1094348770122454e-07,
#   'topbraid': 0.0,
#   'milgram': 0.0,
#   'diy': -5.666365929803631e-07,
#   'wahiawa': 0.0,
#   'million': -9.452337832531685e-05,
#   'hrp': 0.0,
#   'iconography': 1.541126980821236e-07,
#   'banco': 5.879975368950415e-08,
#   'brinksmanship': 0.0,
#   'callea': 1.0547174385061227e-07,
#   'freeform': 1.7639926106851243e-07,
#   'lapiga': 0.0,
#   'meeks': 0.0,
#   'immunocompatent': 0.0,
#   'hazily': 1.0547174385061227e-07,
#   'alpenfest': 1.6875479016097963e-06,
#   'warily': 1.7639926106851243e-07,
#   'schlumberger': 2.1094348770122454e-07,
#   'traktor': 2.351990147580166e-07,
#   'norwegian': -8.814347001916757e-07,
#   'panyu': 1.0547174385061227e-07,
#   'chiba': 1.7639926106851243e-07,
#   'inactivate': 0.0,
#   'durability': -8.394616192301674e-08,
#   'surinder': 5.879975368950415e-08,
#   'json': 0.0,
#   'grumpy': 1.7979814776247752e-07,
#   'srimuang': 0.0,
#   'slipstitch': 1.0547174385061227e-06,
#   'saftoiu': 0.0,
#   'hwpen': 0.0,
#   'hozan': 1.0547174385061227e-07,
#   'printable': 0.0,
#   'distributary': 2.1094348770122454e-07,
#   'clouseau': 1.0547174385061227e-07,
#   'netvanta': 0.0,
#   'concepcion': 5.273587192530614e-07,
#   'manacle': 3.164152315518368e-07,
#   'hyaluronic': 0.0,
#   'aplindore': 0.0,
#   'tregs': 0.0,
#   'brentano': 1.0547174385061227e-07,
#   'pinnarayi': 0.0,
#   'neeta': 2.351990147580166e-07,
#   'riaz': 0.0,
#   'bofors': 0.0,
#   'capitalist': -1.8887886432678766e-07,
#   'rotation': -1.2591924288452512e-07,
#   'evangelize': 0.0,
#   'schefter': 0.0,
#   'ccp': 2.3116904712318539e-07,
#   'phosphorous': 0.0,
#   'manolo': 0.0,
#   'menu': -5.708339010765139e-06,
#   'vcenter': 0.0,
#   'touchpad': 0.0,
#   'cheeburger': 1.6875479016097963e-06,
#   'unsightly': 0.0,
#   'botnet': 0.0,
#   'iab': 0.0,
#   'fathomless': 2.1094348770122454e-07,
#   'trainwreck': 5.273587192530614e-07,
#   'wabo': 2.1094348770122454e-07,
#   'kong': -7.324302627783211e-06,
#   'nathaniel': 5.393944432874325e-07,
#   'ruksun': 0.0,
#   'mcquivey': 0.0,
#   'colao': 0.0,
#   'newshour': 0.0,
#   'acca': 2.1094348770122454e-07,
#   'jodhpur': 5.879975368950415e-08,
#   'unreturned': 0.0,
#   'chessplaying': 2.1094348770122454e-07,
#   'outcompete': 0.0,
#   'inductive': 0.0,
#   'tracklist': 3.164152315518368e-07,
#   'korban': 3.164152315518368e-07,
#   'upmo': 0.0,
#   'documenta': 1.0547174385061227e-07,
#   'bog': -6.71569295384134e-07,
#   'neustel': 1.0547174385061227e-07,
#   'omneon': 0.0,
#   'nemhiripiri': 2.1094348770122454e-07,
#   'tameika': 0.0,
#   'machinist': 0.0,
#   'dariya': 0.0,
#   'workbook': 0.0,
#   'noice': 0.0,
#   'pivotal': 0.0,
#   'tarry': 0.0,
#   'hotwire': 0.0,
#   'toxicants': 0.0,
#   'lyne': 2.1094348770122454e-07,
#   'sharqiyah': 0.0,
#   'nema': 2.5685449680353932e-08,
#   'stn': 0.0,
#   'mcbain': 2.1094348770122454e-07,
#   'deftones': 2.1094348770122454e-07,
#   'outernational': 4.218869754024491e-07,
#   'slasher': 3.7969827786220417e-06,
#   'lifestyle': -1.3494345529124943e-05,
#   'marketable': 0.0,
#   'yesterdayover': 0.0,
#   'reconven': 5.1370899360707864e-08,
#   'maul': -7.345289168263966e-07,
#   'powerdsine': 0.0,
#   'insularisation': 0.0,
#   'marzuq': 1.0547174385061227e-07,
#   'sansho': 2.1094348770122454e-07,
#   'harass': -5.456500524996088e-07,
#   'durang': 1.0547174385061227e-07,
#   'mailroom': 1.541126980821236e-07,
#   'silkcentral': 0.0,
#   'cra': 0.0,
#   'hdv': 0.0,
#   'extension': -1.7208963194218434e-06,
#   'ingestion': 0.0,
#   'gatland': 0.0,
#   'misbegotten': 2.1094348770122454e-07,
#   'outside': -4.690491797448561e-05,
#   'tichenor': 2.1094348770122454e-07,
#   'citizenry': 0.0,
#   'memorabilia': 2.2089486725104382e-06,
#   'guinn': 3.5279852213702486e-07,
#   'allard': -1.2591924288452512e-07,
#   'upmc': 0.0,
#   'sublimely': 2.1094348770122454e-07,
#   'sharifnia': 0.0,
#   'pfds': 0.0,
#   'frock': 2.2931903938906616e-06,
#   'blackmailer': 1.0547174385061227e-07,
#   'racialised': 1.0547174385061227e-07,
#   'tae': 2.1094348770122454e-07,
#   'yeltsin': 0.0,
#   'childabuse': 0.0,
#   'bourdelle': 1.0547174385061227e-07,
#   'saluja': 1.0547174385061227e-07,
#   'noncorporate': 0.0,
#   'clerical': 0.0,
#   'urairat': 0.0,
#   'netvigil': 0.0,
#   'immerse': -1.238205888364497e-06,
#   'empathise': 2.1094348770122454e-07,
#   'abell': 2.5685449680353932e-08,
#   'parasitic': -2.3085194528829605e-07,
#   'conceptual': -9.443943216339384e-07,
#   'theosophical': 3.164152315518368e-07,
#   'performicssearch': 0.0,
#   'medisec': 0.0,
#   'lonnquest': 0.0,
#   'powerbroker': 0.0,
#   'hr': -9.234077811531842e-07,
#   'invariably': -5.036769715381005e-07,
#   'pinout': 0.0,
#   'valerie': -1.007353943076201e-06,
#   'escapade': 4.218869754024491e-07,
#   'lexi': 5.879975368950415e-08,
#   'spot': -2.6212189060461977e-05,
#   'klebold': 1.0583955664110747e-06,
#   'peete': 4.218869754024491e-07,
#   'jhumpa': 1.0547174385061227e-07,
#   'padmasree': 0.0,
#   'reconsider': -9.443943216339384e-07,
#   'jakovina': 4.218869754024491e-07,
#   'koodankulam': 0.0,
#   'flac': 0.0,
#   'hurlbirt': 2.1094348770122454e-07,
#   'troublshooting': 0.0,
#   'hospitalist': 0.0,
#   'sheehan': 0.0,
#   'vine': 0.0,
#   'britian': 2.1094348770122454e-07,
#   'emoney': 0.0,
#   'hackler': 0.0,
#   'lavaca': 0.0,
#   'tyramine': 0.0,
#   'udhav': 0.0,
#   'osdl': 0.0,
#   'masonry': 1.7639926106851243e-07,
#   'nonnegotiable': 2.1094348770122454e-07,
#   'tibotec': 0.0,
#   'mimetic': 3.164152315518368e-07,
#   'unmoved': 0.0,
#   'serialization': 0.0,
#   'doszip': 0.0,
#   'worldweaver': 1.0547174385061227e-07,
#   'ghteen': 0.0,
#   'baabda': 1.175995073790083e-07,
#   'cutter': 3.8528174520530903e-07,
#   'tshwane': 0.0,
#   'opsware': 0.0,
#   'gad': 7.962489400909718e-07,
#   'orthofix': 0.0,
#   'gpt': 0.0,
#   'myoblast': 0.0,
#   'marine': -3.147981072113128e-06,
#   'pronged': 0.0,
#   'acclimate': 0.0,
#   'gloc': 1.0547174385061227e-07,
#   'sibanda': 0.0,
#   'grandparent': -4.617038905765921e-07,
#   'cipla': 0.0,
#   'pevion': 0.0,
#   'binj': 2.1094348770122454e-07,
#   'parekura': 0.0,
#   'castelli': 1.0547174385061227e-07,
#   'plot': -6.023137117976451e-06,
#   'malign': 0.0,
#   'elektronik': 0.0,
#   'lesley': -6.086096739418714e-07,
#   'rivetting': 2.1094348770122454e-07,
#   'kakihara': 1.0547174385061227e-07,
#   'sideswipe': 1.0547174385061227e-07,
#   'vaporetto': 4.218869754024491e-07,
#   'baig': 0.0,
#   'partnerfirst': 0.0,
#   'js': 0.0,
#   'minsheng': 1.0547174385061227e-07,
#   'pakistani': -1.112286645479972e-06,
#   'softballs': 0.0,
#   'mancini': 8.437739508048982e-07,
#   'saqr': 0.0,
#   'yorkdale': 1.0547174385061227e-06,
#   'violat': 1.0547174385061227e-07,
#   'contributory': 0.0,
#   'mediasense': 0.0,
#   'taiex': 0.0,
#   'ruk': 4.218869754024491e-07,
#   'variational': 0.0,
#   'porchester': 2.1094348770122454e-07,
#   'hartney': 0.0,
#   ...}}
